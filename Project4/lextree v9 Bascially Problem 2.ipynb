# %% [markdown]
# # 定义 lexnode

# %%
from collections import Counter
class LexNode:
    def __init__(self, val):
        self.val = val
        self.children = []
        # set the property so that we can differentiate the start node, normal(between) node and end of word node
        # 0: normal node
        # 1: start node
        # 2: end-of-word node
        self.property = 0

    # pretty print tree in command line
    def pretty_str(self, level=0):
        #print(self.val, level)
        if self.property==0:
            ret = "--"+self.val
        elif self.property==2:
            ret="--"+self.val+"\n"
        else:
            ret=self.val
        num_children=len(self.children)
        for i in range(num_children):
            if level!=0:
                if num_children>=2 and i!=0:
                    ret += "|  "*level+"|"+self.children[i].pretty_str(level+1)
                elif num_children==1 and self.children[0].val=="*":
                    return ret
                else:
                    ret += self.children[i].pretty_str(level+1) 
            elif level==0:
                if num_children>=2 and i!=0:
                    ret += "|\n"+"|"+self.children[i].pretty_str(level+1)
                else:
                    ret += self.children[i].pretty_str(level+1)
            
        return ret
    
    def set_level(self, level=0):
        self.level=level
        for child in self.children:
            child.set_level(level + 1)
        return
    
    def get_max_level(self, level=0):
        if len(self.children) == 0:
            return level
        child_levels = [child.get_max_level(level=level + 1) for child in self.children]
        return max(child_levels)

# %% [markdown]
# # 定义建 lextree

# %%
class BuildLextree:
    def __init__(self, dic_file_path):
        self.txt2words(dic_file_path)
        self.tree=LexNode('*')
        # dummy symbol for the root of the tree
        self.tree.property = 1
        n_words = len(self.words)
        word_lens = [len(w) for w in self.words]
        #find the longest word in this dictionary
        self.max_word_len = max(word_lens)
        # pad the words to the same length using '$', in order to avoid index out of range
        for n in range(n_words):
            self.words[n] = self.words[n].ljust(self.max_word_len,'$')
        print("There are {} words in this dictionary".format(len(self.words)))
        
    def txt2words(self,file_path):
        self.words=[]
        dictionary= open (file_path, "r")
        words=dictionary.readlines()
        for word in words:
            self.words.append(word.strip('\n'))
        
    def append_lex_node(self,parent, child):
        #This function just append the child node to the paretn node
        #It would check whether the parent is a LexNode!
        assert type(parent) is LexNode and type(child) is LexNode
        parent.children.append(child)
    
    def build_lextree(self):
        #this is the function to build the lextree from the self.words and root node "*"
        self._build_lextree(self.tree, self.words,0)
        
        
    def _build_lextree(self,node, words, i):
        '''
        This function is to build the tree based on the specific node. It is the basic part of this class
        input: 
        1.the node that need to add children
        2.the words that need to be reviewed
        3. the index that the character on which need to be reviewed
        4. the legthn of the longthest word
        '''
        # once, it reach the longest word and finished that part, we should stop
        if i == self.max_word_len:
            print("The Lextree has been build")
        #record the words that have reached their end
        to_be_removed=[]
        for word in words:
            # if current character is the end of a word, add it as a separate node even if the same node can be shared. This
            # is to ensure that every leaf represent exactly one word.
            if (i + 1 < self.max_word_len and word[i + 1] =='$') or i == self.max_word_len - 1:
                child = LexNode(word[i])
                child.property = 2
                #add "*" at the end of the word
                child.children.append(self.tree)
                self.append_lex_node(node, child)
                to_be_removed.append(word)
        #Now, remove the word that have reached the end
        if len(to_be_removed)!=0:
            for word in to_be_removed:
                words.remove(word)
        #for the rest words, let's append their left characters        
        n_words = len(words)
        # get the characters in j-th position
        chars = [words[n][i] for n in range(n_words)]
        counts = Counter(chars)
        #print(counts)
        for character, count in counts.items():
            # we only focus on this single character here
            child = LexNode(character)
            self.append_lex_node(node, child)
            #get the words that the i th character is the current character we look at
            words_to_be_review_for_this_character = [word for idx, word in enumerate(words) if word[i] == character]
            self._build_lextree(child, words_to_be_review_for_this_character, i + 1)

# %% [markdown]
# # 读取字典

# %%
#dic_file_path="chr_dict.txt"
dic_file_path="dict_1.txt"

# %% [markdown]
# # 根据字典建树

# %%
buildlextree=BuildLextree(dic_file_path)
buildlextree.build_lextree()
lextree=buildlextree.tree
# Out:
# There are 6251 words in this dictionary

# %% [markdown]
# # 该字典最长的单词的长度是

# %%
longest_word_lenth=buildlextree.max_word_len

# %% [markdown]
# # 按照教授的要求 print 这个字典

# %%
print(lextree.pretty_str(0))
# Out:
# *--a
# |
# |--e
# |
# |--i
# |
# |--o
# |
# |--a--n
# |  |--m
# |  |--n
# |  |--s
# |  |--t
# |  |--b--a--n--d--o--n
# |  |  |--b--a--s
# |  |  |  |--r--e--v--i--a--t--i--o--n
# |  |  |--d--o--m--i--n--a--l
# |  |  |--e--l--a
# |  |  |  |--r--n--e--t--h--y
# |  |  |--i--d--e--s
# |  |  |--l--e
# |  |  |--o--l--i--s--h--i--n--g
# |  |  |  |--r--t--i--o--n--i--s--t--s
# |  |  |  |--u--t
# |  |  |--r--a--h--a--m
# |  |  |  |--i--d--g--e
# |  |  |--s--e--n--c--e--s
# |  |  |  |--o--l--v--e--d
# |  |  |  |--t--i--n--e--n--t
# |  |  |--u--n--d--a--n--t--l--y
# |  |--c--c--e--d--e--s
# |  |  |  |  |--n--t--u--a--t--i--n--g
# |  |  |  |  |--p--t
# |  |  |  |--i--d--e--n--t
# |  |  |  |--o--m--m--o--d--a--t--e--d
# |  |  |  |  |  |--p--a--n--y
# |  |  |  |  |  |  |--l--i--s--h--m--e--n--t
# |  |  |  |  |--r--d
# |  |  |  |  |--u--n--t--a--n--c--y
# |  |  |  |--r--u--e
# |  |  |  |--u--r--i--d--e
# |  |  |--e--r--o
# |  |  |--h--e--s
# |  |  |--k--e--r--'--s
# |  |  |  |--r--o--y--d
# |  |  |--q--u--a--i--n--t
# |  |  |  |  |--i--t
# |  |  |--r--o--n--y--m
# |  |  |  |  |--s--s
# |  |  |--t--i--v--a--t--e
# |  |  |  |--o--r--'--s
# |  |  |  |--u--a--l--l--y
# |  |  |--u--m--e--n
# |  |--d--a--c--h--i
# |  |  |  |--p--t--e--c
# |  |  |--d--i--s--o--n
# |  |  |--e--l--s--b--e--r--g--e--r
# |  |  |--i--r--o--n--d--a--c--k
# |  |  |--j--u--n--c--t--s
# |  |  |--m--i--r--a--b--l--e
# |  |  |  |  |--t--s
# |  |  |--o--l--f
# |  |  |  |--r--a--b--e--l--l--e
# |  |  |--r--e--n--a--l--i--n--e
# |  |  |--u--l--t
# |  |  |--v--a--n--t--a--g--e
# |  |  |  |--e--r--s--a--r--i--e--s
# |  |  |  |--i--l
# |  |  |  |  |--c--e
# |  |  |  |  |--s--e--d
# |  |  |  |--o--c--a--t--e
# |  |--e--r--o--n--a--u--t--i--c--a--l
# |  |  |--s--t--h--e--t--e
# |  |--f--f--a--i--r--s
# |  |  |  |--i--r--m--a--t--i--o--n--s
# |  |  |  |--l--u--e--n--t
# |  |  |--g--h--a--n--i--s--t--a--n--'--s
# |  |  |--r--i--c--a
# |  |  |--t--e--r
# |  |  |  |  |--r--e--f--f--e--c--t
# |  |--g--a--i--n
# |  |  |  |  |--n--s--t
# |  |  |--g--r--e--g--a--t--e--s
# |  |  |--i--l--i--t--y
# |  |  |--o--n--i--z--e--s
# |  |  |--r--e--e--d
# |  |  |  |  |  |--i--n--g
# |  |  |  |  |  |--m--e--n--t
# |  |  |  |--i--p--p--a
# |  |  |--u--i--l--e--r--a
# |  |--h--m--a--n--s--o--n
# |  |--i--r
# |  |  |--l--i--n--g
# |  |  |--m--e--e
# |  |  |--r--b--a--g--s
# |  |  |  |--e--d
# |  |  |  |--m--e--n
# |  |  |  |--t--o--u--c--h
# |  |--l--l
# |  |  |--a--i--n--e
# |  |  |  |--s--k--a--n
# |  |  |--b--a--n--y--'--s
# |  |  |  |--e--r--t--a
# |  |  |  |--i--o--n
# |  |  |--c--o--h--o--l--i--c
# |  |  |--d--e--r--i--d--g--e
# |  |  |  |--r--i--n
# |  |  |--g--o--r--i--t--h--m
# |  |  |--i--g--n--s
# |  |  |  |--s--t--a--i--r
# |  |  |--k--e--m--a
# |  |  |--l--a--y--s
# |  |  |  |  |  |--i--n--g
# |  |  |  |--e--n
# |  |  |  |--o--c--a--t--e
# |  |  |  |  |--t--r--o--p--e
# |  |  |  |--s--b--r--o--o--k
# |  |  |  |--u--r--e--d
# |  |  |--m--o--n--d
# |  |  |--p--a--c--a
# |  |  |--s--o
# |  |  |--t--a--i--c
# |  |  |  |--e--r--i--n--g
# |  |  |  |--h--o--u--s--e
# |  |  |--u--m
# |  |  |--v--a--r--a--d--o
# |  |  |  |--i--t--a
# |  |  |--z--a--d--o
# |  |--m--a--t--e--u--r--i--s--h
# |  |  |--b--i--g--u--i--t--i--e--s
# |  |  |  |--u--s--h--e--s
# |  |  |--e--l--i--n--e
# |  |  |--i--d--s--h--i--p--s
# |  |  |  |--s--h
# |  |  |--o--n--g
# |  |  |--p--h--i--b--i--o--u--s
# |  |  |  |--l--y
# |  |--n--d
# |  |  |--t
# |  |  |--a--g--r--a--m
# |  |  |  |--r--c--h--y
# |  |  |  |--t--o--m--i--s--t
# |  |  |--c--h--o--r--s
# |  |  |--d--e--r--b--e--r--g
# |  |  |  |--i--r--o--n
# |  |  |  |--r--e--s--s
# |  |  |--e--m--i--a
# |  |  |--g--e--l--i--n--a
# |  |  |  |--l--e
# |  |  |  |--o--l--a--'--s
# |  |  |  |--r--y
# |  |  |  |  |--i--l--y
# |  |  |  |--u--l--a--r
# |  |  |--i--m--a--l
# |  |  |  |  |  |--l--s
# |  |  |  |  |  |--t--i--o--n
# |  |  |--n--a--b--e--l
# |  |  |  |--e--s--e
# |  |  |  |--o--t--a--t--e--d
# |  |  |  |--u--a--l
# |  |  |--o--i--n--t--e--d
# |  |  |  |--n--y--m--i--t--y
# |  |  |  |--t--h--e--r
# |  |  |--s--w--e--r--e--d
# |  |  |--t--e
# |  |  |  |--e--s
# |  |  |  |--h--r--o--p--o--l--o--g--i--s--t--s
# |  |  |  |--i--c--i--p--a--t--e--d
# |  |  |  |  |--f--r--a--u--d
# |  |  |  |  |--o--n--e
# |  |  |  |  |--s--e--n--s--e
# |  |  |  |--l--e--r--s
# |  |  |--y--o--n--e
# |  |--o--r--t--i--c
# |  |--p--t
# |  |  |--h--i--d--s
# |  |  |--o--s--t--l--e
# |  |  |--p--a--r--e--l
# |  |  |  |--e--a--s--i--n--g
# |  |  |  |--l--e--b--y
# |  |  |  |  |--i--c--a--t--i--o--n
# |  |  |  |--o--r--t--i--o--n--e--d
# |  |  |  |--r--e--h--e--n--d
# |  |  |  |  |--o--a--c--h--e--d
# |  |  |  |  |  |--p--r--i--a--t--e--d
# |  |  |  |  |  |--x--i--m--a--t--e--s
# |  |--q--u--a--t--i--c
# |  |--r--e
# |  |  |--a--b--i--a
# |  |  |  |--p--a--h--o
# |  |  |--c--a--n--e
# |  |  |  |--h--i--b--a--l--d
# |  |  |  |  |--l--y
# |  |  |--d--o--r
# |  |  |--e--a
# |  |  |  |--n--a--'--s
# |  |  |--g--o--'--s
# |  |  |  |--u--m--e--n--t
# |  |  |--i--a--s--'--s
# |  |  |  |--s--t--e--d--e
# |  |  |--m--y
# |  |  |  |--a--d--i--l--l--o--s
# |  |  |  |--c--h--a--i--r--s
# |  |  |  |--o--n--d
# |  |  |--r--a--i--g--n--e--d
# |  |  |  |--i--v--e
# |  |  |  |--u--p--e
# |  |  |--t--s
# |  |  |  |--e--a--g--a
# |  |  |  |--h--u--r--i--a--n
# |  |  |  |--i--n--o
# |  |--s--h
# |  |  |--k
# |  |  |--h--a--m--e--d
# |  |  |  |--e--y
# |  |  |  |--t--o--n--'--s
# |  |  |--i--d--e
# |  |  |--k--e--d
# |  |  |  |--i--n--g
# |  |  |--p--a--r--t--a--m--e
# |  |  |  |--i--r--a--t--i--o--n--s
# |  |  |--s--a--i--l--s
# |  |  |  |--e--m--b--l--a--g--e
# |  |  |  |  |--r--t--i--o--n--s
# |  |  |  |--i--g--n
# |  |  |  |--o--c--i--a--t--e
# |  |  |  |--u--m--p--t--i--o--n
# |  |  |--t--e--r--o--i--d--s
# |  |  |  |--o--u--n--d
# |  |  |  |--r--o--l--o--g--e--r--s
# |  |  |  |  |  |--t--u--r--f
# |  |--t--h--e--n--i--a--n--s
# |  |  |--k--i--n
# |  |  |--l--a--s--'--s
# |  |  |--o--p
# |  |  |--t--a--c--k
# |  |  |  |  |  |--h--i--n--g
# |  |  |  |--e--n--d--s
# |  |  |  |--r--a--c--t--i--v--e
# |  |--u--d--i--b--l--e
# |  |  |  |  |--t--i--o--n
# |  |  |--g--m--e--n--t--e--d
# |  |  |--s--t--e--r--e--l--y
# |  |  |  |  |--r--i--a--n--s
# |  |  |--t--h--o--r--'--s
# |  |  |  |--i--s--m
# |  |  |  |--o--s
# |  |  |  |  |--g--r--a--p--h--s
# |  |  |  |  |--m--o--b--i--l--e--s
# |  |--v--a--i--l--a--b--i--l--i--t--i--e--s
# |  |  |--e--n--g--e--d
# |  |  |--i--o--n--i--c--s
# |  |  |--o--i--d--e--d
# |  |--w--a--y
# |  |  |  |--c--s
# |  |--x--l--e--s
# |
# |--A--i--k--e--n
# |  |--l--l--e--g--h--e--n--y
# |  |--r--l--i--n--g--t--o--n
# |
# |--b--e
# |  |--y
# |  |--a--d
# |  |  |--b--e
# |  |  |  |--i--t--a
# |  |  |  |--y--s--a--t
# |  |  |--c--k
# |  |  |  |--h--a--r--a--c--h
# |  |  |  |--k--e--r--'--s
# |  |  |  |  |--l--i--s--t
# |  |  |  |  |--s--l--a--s--h
# |  |  |  |  |--w--a--s--h
# |  |  |--d--l--y
# |  |  |--h--r--a--i--n--i
# |  |  |--i--l--e--r
# |  |  |  |  |--y--n
# |  |  |--l--l
# |  |  |  |--c--o--n--y
# |  |  |  |--i--n--e--s--e
# |  |  |  |--l--e
# |  |  |--n--k
# |  |  |  |--c--o
# |  |  |  |--d--a--g--e--s
# |  |  |  |  |--o--l--i--e--r--s
# |  |  |  |--f--i--e--l--d
# |  |  |  |--g--l--a--d--e--s--h--i
# |  |  |  |--k--i--n--g
# |  |  |  |  |--'--s
# |  |  |  |  |--s--h--a--r--e
# |  |  |--r--b--a--r--i--c
# |  |  |  |  |--e--r
# |  |  |  |  |  |--l--l--s
# |  |  |  |  |  |--r--s
# |  |  |  |  |--i--e--r--i
# |  |  |  |--c--e--l--o--n--a
# |  |  |  |--e--l--y
# |  |  |  |--o--n--e--t
# |  |  |  |--t--e--n--d--e--r
# |  |  |--s--e--m--e--n--t--s
# |  |  |  |--i--c
# |  |  |--t--h
# |  |  |  |--a--v--i--a
# |  |  |  |--h--e--s
# |  |  |  |--i--k
# |  |  |  |--t--a--l--i--o--n--s
# |  |  |--v--a--r--i--a--n
# |  |  |--y--r--e--u--t--h
# |  |--e--a--r
# |  |  |  |--c--h--e--s
# |  |  |  |--m--'--s
# |  |  |  |--r--d--e--d
# |  |  |  |--t--l--e--s--'
# |  |  |  |--u--t--i--f--u--l
# |  |  |--c--a--m--e
# |  |  |  |  |--u--s--e
# |  |  |  |--o--m--e
# |  |  |--d--b--u--g
# |  |  |--e--l--e--r
# |  |  |  |--r--y
# |  |  |  |--'--s
# |  |  |--g--a--n
# |  |  |  |  |--t
# |  |  |  |--g--a--r--s
# |  |  |  |--i--n--n--e--r--s
# |  |  |  |--u--n
# |  |  |  |  |--i--l--e--d
# |  |  |--h--e--s--t
# |  |  |  |--o--l--d--e--n
# |  |  |--l--i--e--v--e--d
# |  |  |  |--l--a--s
# |  |  |  |  |--u--c--c--i
# |  |  |  |--o--n--g--i--n--g
# |  |  |--m--u--s--e
# |  |  |--n--a--r--e--s
# |  |  |  |--d--e--r--'--s
# |  |  |  |--e--d--i--c--k
# |  |  |--r--t
# |  |  |  |--g--e--r
# |  |  |  |--i--n--g--e--r
# |  |  |  |--k--l--e--y
# |  |  |  |--l--i--n
# |  |  |  |--n--a--r--d--o--'--s
# |  |  |  |  |--h--a--r--d
# |  |  |  |  |--s--t--e--i--n--'--s
# |  |  |  |--t--r--a--n--d
# |  |  |--s--t
# |  |  |--t--t--e--r
# |  |  |  |  |  |--r--s
# |  |  |  |--w--e--e--n
# |  |--i--g
# |  |  |--t
# |  |  |--b--l--i--o--g--r--a--p--h--y
# |  |  |--c--y--c--l--i--n--g
# |  |  |--n--s
# |  |  |  |--d--e--r--s
# |  |  |--o--m--a--t--e--r--i--a--l
# |  |  |  |--t--e--c--h--n--o--l--o--g--y
# |  |  |--r--d--l--i--f--e
# |  |  |--t--u--m--e--n
# |  |  |--z--a--r--r--e
# |  |--l--a--c--k--b--e--r--r--i--e--s
# |  |  |  |  |  |--h--a--w--k
# |  |  |  |  |  |--w--e--l--l
# |  |  |  |--n--c--h
# |  |  |  |  |--d--l--y
# |  |  |  |  |--k--i--n--g
# |  |  |  |--s--e--r
# |  |  |  |  |--t--o--f--f
# |  |  |  |--u--v--e--l--t
# |  |  |--e--a--c--h--e--d
# |  |  |  |--c--k--e--r
# |  |  |  |--m--i--s--h--e--s
# |  |  |--i--n--d--e--r--'--s
# |  |  |  |--s--s
# |  |  |--o--c--k--a--g--e
# |  |  |  |--k--e--s
# |  |  |  |--o--p--e--r--s
# |  |  |--u--d--g--e--o--n
# |  |  |  |--e--s--t
# |  |  |  |--m--e--n--f--e--l--d
# |  |  |  |--n--t--i--n--g
# |  |  |  |--s--t--e--r
# |  |--o--a--r--d
# |  |  |  |--s--t
# |  |  |  |--t--s
# |  |  |--b--b--i--t--t
# |  |  |  |--r--o--w--s--k--i
# |  |  |--d--y
# |  |  |  |--h--i--s--a--t--t--a
# |  |  |--g--s
# |  |  |--i--l--i--n--g
# |  |  |--l--i--v--i--a
# |  |  |  |--l--i--n
# |  |  |  |--s--h--o--i--'--s
# |  |  |--m--b--e--d
# |  |  |--n--a--d--i--o
# |  |  |  |--d--a--g--e--d
# |  |  |  |--e--l--e--s--s
# |  |  |--o--n
# |  |  |  |--e--d
# |  |  |  |--k--i--n--g
# |  |  |  |  |--s--h--o--p
# |  |  |  |--m--i--n--g
# |  |  |  |--r--i--s--h--n--e--s--s
# |  |  |  |--t--h--b--y
# |  |  |  |--z--e
# |  |  |--r--d--e--r--'--s
# |  |  |  |--g--s--t--r--o--m
# |  |  |  |--n--e
# |  |  |  |--o--u--g--h--s
# |  |  |  |--r--o--w--e--r
# |  |  |  |--t--h
# |  |  |--s--s--e--d
# |  |  |--t--h
# |  |  |  |--k--i--n
# |  |  |  |--t--l--e
# |  |  |  |  |--r--e--l--l
# |  |  |--u--g--h
# |  |  |  |--l--d--e--r
# |  |  |  |--n--c--e--d
# |  |  |  |--q--u--e--t--s
# |  |  |--w--l
# |  |  |--x--e--r--s
# |  |  |--y--c--o--t--t--s
# |  |--r--a
# |  |  |--a--c--e--l--e--t--s
# |  |  |  |--d--s--h--e--r
# |  |  |  |--h--m--a--d--a--t--t--a
# |  |  |  |--i--d--s
# |  |  |  |  |--n--w--a--s--h--e--d
# |  |  |  |--n--d--o--n--'--s
# |  |  |  |--s--s--e--r--i--e
# |  |  |  |--t--w--u--r--s--t
# |  |  |  |--w--l--i--n--g
# |  |  |  |--z--e--n
# |  |  |--e--a--c--h--e--d
# |  |  |  |  |--k--e--r
# |  |  |  |  |--t--h--s
# |  |  |  |--e--z--e
# |  |  |  |--m--m--e--r
# |  |  |  |--y--e--r--'--s
# |  |  |--i--b--e--d
# |  |  |  |--d--e--s--m--a--i--d--'--s
# |  |  |  |--e--f--i--n--g--s
# |  |  |  |--g--h--t--o--n
# |  |  |  |--n--g
# |  |  |  |  |--g--s
# |  |  |  |--s--t--o--w
# |  |  |--o--a--d--c--a--s--t--e--r--s--'
# |  |  |  |  |  |--s--i--d--e--d
# |  |  |  |--d--e--r--i--c--k
# |  |  |  |--k--e--n-----w--i--n--d
# |  |  |  |--m--i--d--e
# |  |  |  |--o--d--e--d
# |  |  |  |  |--m--f--i--e--l--d
# |  |  |  |--t--h--e--r--s
# |  |  |  |--u--g--h--t
# |  |  |  |--w--n--i--e--s
# |  |  |  |  |--s--e--d
# |  |  |--u--c--e
# |  |  |  |--i--n
# |  |  |  |--m--l--e--y
# |  |  |  |--s--h--f--i--r--e--s
# |  |  |  |--t--a--l--i--t--i--e--s
# |  |  |--y--a--n--s
# |  |  |  |--s--o--n
# |  |--u--t
# |  |  |--b--k--a
# |  |  |--g--e--y--e--d
# |  |  |--h--l
# |  |  |--i--l--d--s
# |  |  |  |  |  |--i--n--g--'--s
# |  |  |--l--i--m--i--a
# |  |  |  |--l--d--o--z--i--n--g
# |  |  |  |  |--i--n--g--e--r
# |  |  |  |  |--w--i--n--k--l--e
# |  |  |--m--b--l--e
# |  |  |  |--p--y
# |  |  |--n--d--e--s--w--e--h--r
# |  |  |  |--g--e--r--t
# |  |  |  |--n--y
# |  |  |--r--p
# |  |  |  |--y
# |  |  |  |--f--o--r--d
# |  |  |  |--g--e--t--t
# |  |  |  |  |--o--m--a--s--t--e--r--'--s
# |  |  |  |--i--e--s
# |  |  |  |--n--a--b--y
# |  |  |  |--r--i--t--t
# |  |  |--s--h--e--l
# |  |  |  |--i--n--e--s--s
# |  |  |  |--s--i--n--g
# |  |  |  |--t--s
# |  |  |--t--s
# |  |  |  |--t--o--n--s
# |  |--y--l--a--n--d
# |  |  |--r--d
# |
# |--c--a--n
# |  |  |--b--b--i--e
# |  |  |  |--l--e
# |  |  |  |--o--o--s--e--s
# |  |  |--d--e--t--s
# |  |  |--g--n--e--y
# |  |  |--i--n
# |  |  |--k--e
# |  |  |--l--a--m--i--t--i--e--s
# |  |  |  |--l--s
# |  |  |  |  |--a--w--a--y
# |  |  |  |  |--e--d
# |  |  |  |  |--i--e
# |  |  |  |--m--s
# |  |  |  |--u--m--n--y
# |  |  |  |--v--e--d
# |  |  |  |  |--i--n--i--s--t
# |  |  |--m--e
# |  |  |  |--b--e--r
# |  |  |  |--c--o--r--d--e--r
# |  |  |  |--e--o
# |  |  |  |--p--g--r--o--u--n--d--s
# |  |  |--n--a--d--i--a--n
# |  |  |  |--d--i--d--a--c--y
# |  |  |  |--n--i--b--a--l--s
# |  |  |  |  |--o--t
# |  |  |  |--o--e--i--n--g
# |  |  |  |--s--t--a--r
# |  |  |  |--t--l--e--y
# |  |  |  |--u--p--p
# |  |  |--p--a--b--l--e
# |  |  |  |--e--l--'--s
# |  |  |  |--i--t--a--l--i--s--m--'--s
# |  |  |  |  |  |--u--l--a--t--i--o--n
# |  |  |  |--o--z--z--o--l--i
# |  |  |  |--p--y--'--s
# |  |  |  |--s--t--i--c--k
# |  |  |  |--t--u--r--e--d
# |  |  |--r--o
# |  |  |  |--p
# |  |  |  |--t
# |  |  |  |--a--c--c--i
# |  |  |  |  |--v--e--l--l--a
# |  |  |  |--b--o--n--a--r--a
# |  |  |  |  |--u--r--e--t--o--r
# |  |  |  |--d--e--n
# |  |  |  |  |--i--n--a--l--s--'
# |  |  |  |  |--o--z--a
# |  |  |  |--e--f--r--e--e
# |  |  |  |  |--s--s
# |  |  |  |--i--b--b--e--a--n
# |  |  |  |  |--n--g
# |  |  |  |--l--i--n--i
# |  |  |  |  |--o--w
# |  |  |  |  |--'--s
# |  |  |  |--m--a--c--k
# |  |  |  |  |--i--n--e
# |  |  |  |--n--e--g--i--e
# |  |  |  |--o--l--u--s
# |  |  |  |--p--i--n--o
# |  |  |  |--r--y
# |  |  |  |  |--e--i--r--a
# |  |  |  |  |--i--c--o
# |  |  |  |  |  |--n--o
# |  |  |  |  |--u--t--h
# |  |  |  |  |--y--i--n--g
# |  |  |  |--t--i--l--a--g--e
# |  |  |  |  |--u--s--c--i--e--l--l--o
# |  |  |  |--v--e--s
# |  |  |--s--e
# |  |  |  |--a--g--r--a--n--d--e
# |  |  |  |--e--s
# |  |  |  |--h--i--e--r
# |  |  |  |--i--m--i--r--o
# |  |  |  |--p--e--r--s
# |  |  |  |--s--e--d--y
# |  |  |  |  |--i--e
# |  |  |  |--t--i--n--g
# |  |  |  |  |--l--e--s
# |  |  |  |  |--r--a--t--e--s
# |  |  |  |--w--e--l--l
# |  |  |--t--o
# |  |  |  |--a--l--i--n--a
# |  |  |  |  |--m--o--u--n--t
# |  |  |  |--c--h
# |  |  |  |  |--a--l--l--s
# |  |  |  |--e--g--o--r--i--z--e--d
# |  |  |  |--h--a--r--i--n--e
# |  |  |  |  |--e--y
# |  |  |  |--t--l--e
# |  |  |--u--d--l--e
# |  |  |  |--g--h--t
# |  |  |  |--s--a--t--i--o--n
# |  |  |  |  |--i--n--g
# |  |  |  |--t--i--o--u--s
# |  |  |--v--a--n--a--h
# |  |  |  |--e--r--n--s
# |  |  |--w--t--h--o--n
# |  |  |--z--e--n--o--v--e
# |  |--e--a--s--e--r
# |  |  |--c--i
# |  |  |--d--e--s
# |  |  |--l--l
# |  |  |  |--a--n--e--s--e
# |  |  |  |--e--r--o--n
# |  |  |  |--l--s--t--a--r
# |  |  |--m--e--n--t
# |  |  |--n--s--o--r--i--n--g
# |  |  |  |--t--e--n--o
# |  |  |  |  |--i--m--e--s
# |  |  |  |  |--r--a--l--i--z--i--n--g
# |  |  |  |  |--u--r--i--e--s
# |  |  |--r--a--s--o--l--i
# |  |  |  |--i--n--o
# |  |  |  |--s--k--a
# |  |  |  |--t--a--i--n
# |  |  |  |  |  |  |--n--l--y
# |  |  |  |--u--s
# |  |  |--s--e--n--a
# |  |--h--a-----c--h--a--s
# |  |  |  |--d--l--i
# |  |  |  |--g--n--o--n
# |  |  |  |--i--r--i--n--g
# |  |  |  |--k--r--a--d--h--a--r--a
# |  |  |  |--l--f--i--n
# |  |  |  |  |--o--u--p--k--a
# |  |  |  |--m--b--o--n
# |  |  |  |  |--p--i--o--n--s--h--i--p--s
# |  |  |  |--n--d--e--l--i--e--r
# |  |  |  |  |--g--e--r--s
# |  |  |  |  |--t--i--n--g
# |  |  |  |--p--i--n
# |  |  |  |  |--t--e--r--s
# |  |  |  |--r--b--o--n--e--a--u
# |  |  |  |  |--g--i--t
# |  |  |  |  |--l--e
# |  |  |  |  |  |--o--t--t--e
# |  |  |  |  |--n--l--e--y
# |  |  |  |  |--t--i--n--g
# |  |  |  |--s--k--a
# |  |  |  |--t--i--c--h--a--i
# |  |  |  |  |--t--e--r--t--o--n--'--s
# |  |  |  |--u--n--c--e--y
# |  |  |  |--v--i--t--z
# |  |  |--e--a--p--e--s--t
# |  |  |  |--c--h--n--y--a--'--s
# |  |  |  |  |--k--o--u--t
# |  |  |  |--e--r
# |  |  |  |  |--s--i--e--s--t
# |  |  |  |--l--l
# |  |  |  |--m--i--e
# |  |  |  |--n--g-----c--h--u--n--g
# |  |  |  |--r--n
# |  |  |  |  |--r--y
# |  |  |  |--s--e--b--r--o--u--g--h
# |  |  |  |  |--t--e--r
# |  |  |  |--v--e--s
# |  |  |  |--w--i--n--g
# |  |  |--i--a--p--p--o--n--e
# |  |  |  |--c--a--n--o--s
# |  |  |  |--d--e--d
# |  |  |  |--g--g--e--r--s
# |  |  |  |--l--d--h--o--o--d
# |  |  |  |  |  |--r--e--n
# |  |  |  |  |--e--s--'--s
# |  |  |  |--m--e
# |  |  |  |--n--e--n
# |  |  |  |--p--c--o--m
# |  |  |  |--r--c--o
# |  |  |  |--s--m--a--n
# |  |  |  |--u--s--a--n--o
# |  |  |--l--o--r--o--f--l--u--o--r--o--c--a--r--b--o--n--s
# |  |  |--o--i--c--e
# |  |  |  |  |  |--e--r
# |  |  |  |--l--e--t
# |  |  |  |--o--s--e
# |  |  |  |--p--e--r
# |  |  |  |--r--d--a--t--e--s
# |  |  |  |  |--u--s--e--s
# |  |  |--r--i--b--o--n--i--k--o
# |  |  |  |  |--s--t--c--h--u--r--c--h
# |  |  |  |  |  |  |--i--a--n--n--a
# |  |  |  |  |  |  |--m--a--s--e--s
# |  |  |  |--o--b--a--k
# |  |  |  |  |--n--i--c--l--i--n--g
# |  |  |--s--e--i--n--g
# |  |  |--u--c--k--l--e--d
# |  |  |  |--m--m--y
# |  |  |  |--r--c--h--g--o--e--r--s
# |  |  |  |--t--e
# |  |--i--a--n--o
# |  |  |--c--c--o
# |  |  |--e--s--l--a--k
# |  |  |--l--e--n--t--o
# |  |  |--n--c--h
# |  |  |  |--e--m--a--t--o--g--r--a--p--h--y
# |  |  |--o--l--e--k
# |  |  |--r--c--u--i--t--'--s
# |  |  |  |  |  |--m--s--c--r--i--b--e
# |  |  |  |--i--e--l--l--o
# |  |  |--s--n--e--r--o--s
# |  |  |--t--y
# |  |  |  |--i--b--a--n--k
# |  |  |  |--r--i--n--e
# |  |  |--u--d--a--d
# |  |--l--a--r
# |  |  |  |--a--r
# |  |  |  |--i--b--o--r--n--e
# |  |  |  |--m--e--n
# |  |  |  |--n--g--i--n--g
# |  |  |  |--r--k
# |  |  |  |  |--i--f--i--c--a--t--i--o--n
# |  |  |  |--s--h--e--s
# |  |  |  |  |--s--i--f--i--c--a--t--i--o--n--s
# |  |  |  |--u--d--i--e
# |  |  |  |--v--e--t--t--e
# |  |  |  |--y--e--y
# |  |  |--e--a--n--l--i--n--e--s--s
# |  |  |  |  |--r--e--s--t
# |  |  |  |--e--k
# |  |  |  |--m--e--n--t
# |  |  |  |--n--d--e--n--e--n
# |  |  |  |--r--k
# |  |  |  |--v--i--t--e
# |  |  |--i--e--n--t--s--'
# |  |  |  |--m--a--t--i--c
# |  |  |  |  |--b--e--d
# |  |  |  |  |  |--i--n--g
# |  |  |  |--n--e
# |  |  |  |  |--k
# |  |  |  |--p--p--i--n--g--e--r
# |  |  |--o--s
# |  |  |  |--c--k--e--r--s
# |  |  |  |--m--i--p--r--a--m--i--n--e
# |  |  |  |--s--s--o--n
# |  |  |  |--t--h
# |  |  |  |  |--h--e--s
# |  |  |  |  |--t--e--d
# |  |  |  |--v--e--r--l--e--a--f
# |  |  |--u--m
# |  |  |  |--b--b--e--d
# |  |  |  |--s--t--e--r--s
# |  |  |  |--t--c--h
# |  |--o--n
# |  |  |--o
# |  |  |--a--g--u--l--a--t--i--n--g
# |  |  |  |--s--t--'--s
# |  |  |  |--t--n--e--y
# |  |  |--b--b--i--n--s
# |  |  |--c--k--e--d
# |  |  |  |--u--z--z--a
# |  |  |--d--e--s--a
# |  |  |--e--h--l--o
# |  |  |--f--o--u--n--d--e--r
# |  |  |--g--g--i--n--s
# |  |  |--h--a--n
# |  |  |  |--o--r--t--s
# |  |  |--i--n--c--i--d--e--n--c--e--s
# |  |  |--k--e--'--s
# |  |  |--l--d
# |  |  |  |--a--s
# |  |  |  |--e--e--n
# |  |  |  |--l--a--r--b--o--n--e
# |  |  |  |  |--e--c--t--i--n--g
# |  |  |  |  |  |--g--e--s
# |  |  |  |  |--i--n--s
# |  |  |  |  |--o--q--u--i--u--m
# |  |  |  |--m--e--r
# |  |  |  |--o--n--i--a--l--i--s--m
# |  |  |  |  |--r--a--d--a--n--s
# |  |  |  |--u--m--b--o
# |  |  |--m--a
# |  |  |  |--e
# |  |  |  |--b--e--d
# |  |  |  |--c--a--s--t--'--s
# |  |  |  |--e--s
# |  |  |  |  |--d--y
# |  |  |  |--f--i--n--a--n--c--e
# |  |  |  |  |--o--r--t--a--b--l--e
# |  |  |  |  |  |  |  |  |  |  |--y
# |  |  |  |--i--n--g
# |  |  |  |  |  |--o
# |  |  |  |--m--a--n--d--i--n--g
# |  |  |  |  |--e--n--d--a--b--l--e
# |  |  |  |  |  |--r--c--e--b--a--n--c--o--r--p
# |  |  |  |  |--i--t
# |  |  |  |  |  |--n--g--l--i--n--g
# |  |  |  |  |  |--t--m--e--n--t
# |  |  |  |  |--o--n--a--l--i--t--y
# |  |  |  |  |--u--n--i--c--a--t--i--o--n--'--s
# |  |  |  |  |  |  |  |--z--e
# |  |  |  |--p--a--n--i--o--n
# |  |  |  |  |  |--r--i--s--o--n--s
# |  |  |  |  |--e--l--l--i--n--g
# |  |  |  |  |  |--t--i--n--g
# |  |  |  |  |--l--a--c--e--n--c--y
# |  |  |  |  |  |--e--t--e--d
# |  |  |  |  |  |--i--c--a--t--i--o--n--s
# |  |  |  |  |--o--s--e--r--'--s
# |  |  |  |  |--r--e--h--e--n--d--i--n--g
# |  |  |  |  |  |--o--m--i--s--e--r
# |  |  |  |  |--u--m--a--t
# |  |  |  |  |  |--t--e--r--l--a--n--d--'--s
# |  |  |--n--s
# |  |  |  |--c--a--t--e--n--a--t--e
# |  |  |  |  |--e--i--v--e--d
# |  |  |  |  |  |--n--t--r--a--t--e--d
# |  |  |  |  |  |--r--t
# |  |  |  |  |--i--l--i--a--t--i--o--n
# |  |  |  |  |--o--m--i--t--a--n--t
# |  |  |  |  |--u--s--s--i--o--n--s
# |  |  |  |--d--i--e
# |  |  |  |  |--o--m--i--n--i--u--m--s
# |  |  |  |  |--u--c--t--e--d
# |  |  |  |--e--y
# |  |  |  |--f--e--r--e--n--c--e--s
# |  |  |  |  |--i--d--e--d
# |  |  |  |  |  |--n--e--s
# |  |  |  |  |--l--i--c--t
# |  |  |  |  |--r--o--n--t
# |  |  |  |--g--e--a--l
# |  |  |  |  |--r--a--t--u--l--a--t--i--o--n--s
# |  |  |  |  |  |--e--s--s--w--o--m--a--n
# |  |  |  |--j--u--g--a--l
# |  |  |  |--k--l--i--n
# |  |  |  |--n--e--c--t--e--r
# |  |  |  |  |  |--r--l--y
# |  |  |  |  |--o--r--s
# |  |  |  |--q--u--e--s--t--'--s
# |  |  |  |--s--e--c--u--t--i--v--e--l--y
# |  |  |  |  |  |--r--v--a--t--i--s--m
# |  |  |  |  |--i--d--e--r--a--t--i--o--n--s
# |  |  |  |  |--o--l--a--t--a
# |  |  |  |  |  |  |--i--n--g
# |  |  |  |  |  |--n--a--n--t--s
# |  |  |  |  |--p--i--r--a--c--i--e--s
# |  |  |  |  |--t--a--b--u--l--a--r--y
# |  |  |  |  |  |--i--p--a--t--e--d
# |  |  |  |  |  |--r--a--i--n--e--d
# |  |  |  |  |  |  |--u--c--t--i--v--e--l--y
# |  |  |  |  |--u--l--t
# |  |  |  |  |  |  |--t--a--t--i--v--e
# |  |  |  |  |  |  |  |--i--n--g
# |  |  |  |  |  |--m--m--a--t--i--o--n
# |  |  |  |--t--a--i--n--i--n--g
# |  |  |  |  |--e--m--p--o--r--a--n--e--o--u--s
# |  |  |  |  |  |--n--t--i--o--u--s
# |  |  |  |  |--i--n--e--n--t
# |  |  |  |  |  |  |--u--e--d
# |  |  |  |  |  |  |  |  |--s
# |  |  |  |  |--r--a--c--e--p--t--i--o--n
# |  |  |  |  |  |  |--d--i--c--t--i--o--n
# |  |  |  |  |  |--e--r--a--s
# |  |  |  |  |  |--o--l
# |  |  |  |  |  |  |--l--l--a--b--l--e
# |  |  |  |--v--a--l--e--s--c--e--n--t
# |  |  |  |  |--e--r--g--e--n--c--e
# |  |  |  |  |  |  |--t--i--b--i--l--i--t--y
# |  |  |  |  |--i--l--l--e
# |  |  |--o--l
# |  |  |  |--k--i--n--g--h--a--m
# |  |  |  |--l--i--d--g--e
# |  |  |  |--n--r--a--d--t
# |  |  |  |--p--e--r--r--i--d--e--r
# |  |  |  |--t--e
# |  |  |--p--e--l--i--n
# |  |  |  |--l--e--n
# |  |  |  |--p--e--r--h--e--a--d
# |  |  |  |--r--o--c--e--s--s--o--r
# |  |  |  |--y--w--r--i--t--e
# |  |  |--r--n
# |  |  |  |--y
# |  |  |  |--b--e--l--l
# |  |  |  |--d--a--y
# |  |  |  |  |--o--b--a
# |  |  |  |--e--l--l--a
# |  |  |  |--i--n--n--a
# |  |  |  |--k--w--o--o--d
# |  |  |  |--n--e--l--l
# |  |  |  |  |--f--o--r--t--h
# |  |  |  |  |--w--a--l--l--'--s
# |  |  |  |--p--.
# |  |  |  |  |--s--m--a--n
# |  |  |  |--r--e--c--t--i--o--n--s
# |  |  |  |  |  |--s--p--o--n--d--e--n--c--e
# |  |  |  |  |--o--b--o--r--a--t--e
# |  |  |  |  |--u--p--t--i--o--n
# |  |  |  |--s--i--n--i
# |  |  |  |--t--i--n--a
# |  |  |--s--i
# |  |  |  |--m--o--p--u--l--o--s
# |  |  |  |--t--a--b--i--l--e
# |  |  |  |  |--e--r
# |  |  |  |  |--u--m--e--s
# |  |  |--t--n--o--i--r
# |  |  |  |--t--o
# |  |  |--u--c--h--e--s
# |  |  |  |--l--d
# |  |  |  |  |--e--e
# |  |  |  |--n--i--h--a--n
# |  |  |  |  |--t--e--r
# |  |  |  |  |  |  |--r--f--e--i--t
# |  |  |  |  |  |  |  |--p--a--r--t--s
# |  |  |  |  |  |  |  |--w--e--i--g--h--t
# |  |  |  |--p--e--s
# |  |  |  |--r--a--n--t
# |  |  |  |  |--t--a--u--l--d--s
# |  |  |  |  |  |--r--i--g--h--t
# |  |  |  |--s--t--e--a--u
# |  |  |--v--e--l
# |  |  |  |  |--r--i--n--g
# |  |  |  |  |--t--s
# |  |  |  |--i--n--o
# |  |  |--w--d--e--r--y
# |  |  |  |--l--e--y
# |  |  |--x--e--n
# |  |  |--z--i--n--e--s--s
# |  |--r--o
# |  |  |--a--c--c--h--i--o--l--o
# |  |  |  |--d--e--r
# |  |  |  |--g--g--s
# |  |  |  |--m--b--l--i--t
# |  |  |  |--n--e
# |  |  |  |  |--m--o--r--e
# |  |  |  |--s--h--'--s
# |  |  |  |--v--e
# |  |  |  |--w--l--s
# |  |  |  |--z--i--n--e--s--s
# |  |  |--e--a--r
# |  |  |  |  |--t--o--l--o--g--i--s--t
# |  |  |  |  |  |--u--r--e--s
# |  |  |  |--d--i--t--b--a--n--k
# |  |  |  |--e--d--o--n
# |  |  |  |--g--a--n
# |  |  |  |--n--e--l--a--t--e
# |  |  |  |--s--c--i
# |  |  |  |  |--t--s
# |  |  |  |--w--m--e--n
# |  |  |--i--e--d
# |  |  |  |--g--g--e--r
# |  |  |  |--m--i--n--a--l--i--z--a--t--i--o--n
# |  |  |  |--n--g--e--s
# |  |  |  |--s--s
# |  |  |  |  |--e--s
# |  |  |  |  |--t--o--b--e--l
# |  |  |  |--t--i--c--i--z--e--s
# |  |  |--o--c
# |  |  |  |--c--k
# |  |  |  |  |--o--d--i--l--e
# |  |  |  |  |  |  |  |  |--e--'--s
# |  |  |  |--i--t--z--e--r
# |  |  |  |--n--e
# |  |  |  |--o--k
# |  |  |  |  |--k--l--y--n--'--s
# |  |  |  |--p--s--e--y
# |  |  |  |--s--s
# |  |  |  |  |--s--b--o--n--e--s
# |  |  |  |  |  |--m--a--n
# |  |  |  |  |--w--e--l--l
# |  |  |  |--u--t
# |  |  |  |--w--n
# |  |  |  |  |--i--n--g
# |  |  |  |  |--t--h--e--r--'--s
# |  |  |--u--d--e--l--e
# |  |  |  |--i--s--i--n--g
# |  |  |  |--m--p
# |  |  |  |--s--a--d--e--s
# |  |  |  |--t--c--h--e--r
# |  |  |--y--e
# |  |  |  |--s--t--a--l--l--o--g--r--a--p--h--e--r
# |  |--u--t
# |  |  |--b--b--i--e--s
# |  |  |--c--c--i--o
# |  |  |--d--n--e--y
# |  |  |--h--n--e--y
# |  |  |--l--l--e--n--s
# |  |  |  |  |--o--m
# |  |  |  |--t--'--s
# |  |  |  |--v--e--r
# |  |  |--m--m--i--n--g--t--o--n
# |  |  |--n--n--e--e--n
# |  |  |--p--i--t
# |  |  |--r--b--e--l--o
# |  |  |  |--i--e--l
# |  |  |  |--l--s
# |  |  |  |--r--e--r--i
# |  |  |  |--s--i--n--g
# |  |  |  |--t--n--e--r
# |  |  |  |--v--e
# |  |  |--s--h--i--o--n--e--d
# |  |  |  |--t--a--r--d
# |  |  |  |--u--m--a--n--o
# |  |  |--t--i--c--l--e
# |  |  |  |--s--h--a--w
# |  |--w--i--k
# |  |--y--b--i--l--l
# |  |  |--c--l--o--s--p--o--r--i--n--e
# |  |  |--n--i--c--a--l
# |  |  |--p--r--u--s
# |  |  |--t--o--p--l--a--s--m--i--c
# |  |--z--e--c--h--o--s--l--o--v--a--k--i--a--'--s
# |
# |--d--o
# |  |--a--h
# |  |  |--y
# |  |  |--b--b--s
# |  |  |--c--u--n--h--a
# |  |  |--d--y
# |  |  |--g--a--t--a
# |  |  |--h--m--e--n
# |  |  |--i--l
# |  |  |  |--l--y
# |  |  |  |--s--e--y
# |  |  |--l--a--l
# |  |  |  |--f--o--n--s--o
# |  |  |  |--l--e--y
# |  |  |  |--t--o
# |  |  |--m--a--g--e--d
# |  |  |  |  |--s--c--u--s--'--s
# |  |  |  |--i--c--o
# |  |  |  |--n--e--d
# |  |  |  |--p--s
# |  |  |--n--c--e--s
# |  |  |  |  |  |--r--'--s
# |  |  |  |--e--'--s
# |  |  |  |--g--l--e--d
# |  |  |  |--i--e--l--s--o--n
# |  |  |  |--n--a
# |  |  |  |--s--f--o--r--t--h--'--s
# |  |  |  |--v--e--r--s
# |  |  |--p--p
# |  |  |--r--d--i--c--k
# |  |  |  |--i--t--y
# |  |  |  |--l--i--n--g--s
# |  |  |  |--r--a--h
# |  |  |  |--t--h
# |  |  |--s--c--e--n--z--o
# |  |  |  |--h--w--o--o--d
# |  |  |--t--o
# |  |  |  |--a--m--e--t--r--i--c--s
# |  |  |--u--m
# |  |  |  |--e--n--h--a--u--e--r
# |  |  |--v--e--e
# |  |  |  |--i--d--s--o--n
# |  |  |  |--o--x
# |  |  |--w--s--o--n--'--s
# |  |  |--y--l--e--y
# |  |  |--z--z--l--e--d
# |  |--'--a--m--a--t--o
# |  |  |--o--e--u--v--r--e
# |  |--e--o
# |  |  |--a--r
# |  |  |  |--s
# |  |  |  |--d--e--r
# |  |  |  |--f--n--e--s--s
# |  |  |  |--l--i--n--g
# |  |  |  |--n--g--e--l--i--s
# |  |  |  |--t--h
# |  |  |  |--v--i--l--a
# |  |  |--b--a--t--e--r--s
# |  |  |  |--e--n--t--u--r--e
# |  |  |  |--o--a--r--d
# |  |  |  |--r--a--u--d--w--i--c--k
# |  |  |  |--t--s
# |  |  |--c--a--d--e--'--s
# |  |  |  |  |--p--i--t--a--t--i--o--n
# |  |  |  |--e--a--s--e
# |  |  |  |  |--i--v--e--d
# |  |  |  |  |--n--c--y
# |  |  |  |--h--e--n--e
# |  |  |  |--i--m--a--t--i--n--g
# |  |  |  |--k--m--a--n
# |  |  |  |--l--e--r--q--u--e
# |  |  |  |--o--m--p--o--s--e--d
# |  |  |  |  |--r--a--t--i--o--n
# |  |  |  |--r--a--n--e
# |  |  |  |--u--r--t--i--s
# |  |  |--d--r--i--c--k
# |  |  |--e--p
# |  |  |  |--d--s
# |  |  |  |--p--e--n--e--d
# |  |  |  |--t--z
# |  |  |--f--e--a--t--i--n--g
# |  |  |  |  |--n--d--a--n--t--s
# |  |  |  |  |--r--m--e--n--t
# |  |  |  |--i--c--i--t--'--s
# |  |  |  |--l--a--t--e
# |  |  |  |--o--r--e--s--t--a--t--i--o--n
# |  |  |  |--r--e--e--s
# |  |  |--g--a--r--m--o
# |  |  |  |--i--d--i--o
# |  |  |  |--r--a--v--e
# |  |  |--h--a--a--s
# |  |  |  |--y--d--r--a--t--e
# |  |  |--i--n--k--i--n--g
# |  |  |--j--a--g--e--r
# |  |  |--k--l--e--r--k--'--s
# |  |  |--l--a--i--n--e
# |  |  |  |  |--r--o--s--a
# |  |  |  |  |--w--a--r--i--a--n--s
# |  |  |  |--c--i--n--e
# |  |  |  |--e--o
# |  |  |  |--g--a--u--d--i--o
# |  |  |  |--i--b--e--r--a--t--i--o--n--s
# |  |  |  |  |--l--l--o
# |  |  |  |  |--s--t
# |  |  |  |--l--a--p--e--n--n--a
# |  |  |  |--m--e--d--'--s
# |  |  |  |--o--r--e--n--z--o
# |  |  |  |--p--i--n--o
# |  |  |  |--t--a--d--r--o--m--e--u--s
# |  |  |  |--u--s--i--o--n
# |  |  |--m--a--g--o--g--u--e--s
# |  |  |  |  |--r--e--e
# |  |  |  |  |--t--t--i--a
# |  |  |  |--e--n--t--e--d
# |  |  |  |--i--'--s
# |  |  |  |  |--s--e
# |  |  |  |--o--c--r--a--t--'--s
# |  |  |  |  |--l--i--s--h
# |  |  |  |  |--n--s--t--r--a--t--i--o--n
# |  |  |  |  |--t--i--o--n
# |  |  |  |--y--a--n
# |  |  |--n--b--o--e--r
# |  |  |  |--g--u--e
# |  |  |  |--i--r--o
# |  |  |  |--m--a--r--k
# |  |  |  |--n--y
# |  |  |  |--o--u--n--c--i--n--g
# |  |  |  |--t--i--n
# |  |  |  |--u--c--l--e--a--r--i--z--a--t--i--o--n
# |  |  |--p--a--r--t--m--e--n--t--'--s
# |  |  |  |--e--n--d--e--n--c--i--e--s
# |  |  |  |--i--n--t--o
# |  |  |  |--n--e--r
# |  |  |  |--o--s--i--t--i--o--n
# |  |  |  |--r--e--c--a--t--e
# |  |  |  |  |  |--s--s--i--o--n
# |  |  |  |--u--e
# |  |  |--r--c--h--i--n
# |  |  |  |--f--l--i--n--g--e--r
# |  |  |  |--i--v--a--t--i--o--n
# |  |  |  |--m--o--d--y
# |  |  |  |--o--y
# |  |  |  |--u--k--o
# |  |  |--s--a--n--t--i--s
# |  |  |  |--c--h
# |  |  |  |--e--c--r--a--t--i--o--n--s
# |  |  |  |  |--r--v--e--s
# |  |  |  |--i--g--n--a--t--e--s
# |  |  |  |  |--r--e
# |  |  |  |  |  |--a--b--i--l--i--t--y
# |  |  |  |--k--t--o--p--s
# |  |  |  |--p--a--i--r--e--d
# |  |  |  |  |--o--t--i--s--m
# |  |  |  |--t--i--n--a--t--i--o--n
# |  |  |  |--u--l--t--o--r--y
# |  |  |--t--e--c--t--a--b--l--e
# |  |  |  |  |--r--i--o--r--a--t--e--s
# |  |  |  |  |  |--m--i--n--i--s--t--i--c
# |  |  |  |--l--o--f--f
# |  |  |  |--r--a--c--t--o--r
# |  |  |  |--t--y
# |  |  |--u--t--s--c--h--e--m--a--r--k
# |  |  |--v--a--l--u--i--n--g
# |  |  |  |--e--l--o--p--e--d
# |  |  |  |  |--r--a
# |  |  |  |--i--l
# |  |  |  |  |--c--e--s
# |  |  |  |  |--n--n--e--y
# |  |  |  |--o--l--v--e--d
# |  |  |  |  |--u--r--i--n--g
# |  |  |--w--b--e--r--r--y
# |  |  |  |--i--t--z
# |  |  |--y--o
# |  |--h--o--l--e
# |  |  |  |--o--s--a--r--a--k--a
# |  |--i--e
# |  |  |--a--n
# |  |  |  |--g--n--o--s--e--s
# |  |  |  |--l--e--c--t--s
# |  |  |  |--m--o--n--d--s
# |  |  |  |--r--i--e--s
# |  |  |  |--t--r--i--b--e--s
# |  |  |--b--l--a--s--i
# |  |  |--c--e--s--a--r--e
# |  |  |  |--k--e--n--s--h--e--e--t--s
# |  |  |  |  |--m--e--y--e--r
# |  |  |  |--t--a--t--o--r--i--a--l
# |  |  |--d--i--o--n--'--s
# |  |  |--e--d
# |  |  |  |--f--e--n--d--o--r--f
# |  |  |  |--n--s--t
# |  |  |  |--t--e--l
# |  |  |  |  |--z--l--e--r
# |  |  |--f--f--e--r--e--n--t--i--a--t--e--s
# |  |  |  |--i--o--r--e
# |  |  |--g--e--s--t--i--o--n
# |  |  |  |--i--t
# |  |  |  |--r--e--g--o--r--i--o
# |  |  |--l--a--t--i--o--n
# |  |  |  |--i--g--e--n--c--e
# |  |  |  |--l--i--n
# |  |  |  |--t--i--a--z--e--m
# |  |  |--m--a--r--i--o
# |  |  |  |--e--r--c--u--r--i--o
# |  |  |  |--i--t--r--o--f--f
# |  |  |  |--s--d--a--l--e
# |  |  |--n--e--s--h
# |  |  |  |--g--y
# |  |  |  |--o--s--a--u--r
# |  |  |--o--g--u--a--r--d--i
# |  |  |--p--a--o--l--o
# |  |  |  |--p--e--d
# |  |  |--r--e--c--t--i--o--n--s
# |  |  |  |--g--e
# |  |  |--s---
# |  |  |  |--a--g--r--e--e
# |  |  |  |  |--p--p--e--a--r--e--d
# |  |  |  |  |--r--r--a--y
# |  |  |  |--b--e--l--i--e--v--i--n--g
# |  |  |  |--c--h--a--r--g--e
# |  |  |  |  |--l--a--i--m--s
# |  |  |  |  |--o--n--n--e--c--t--i--n--g
# |  |  |  |  |  |--u--n--t--i--n--g
# |  |  |  |  |--r--e--d--i--t--s
# |  |  |  |  |--u--s--s--i--n--g
# |  |  |  |--e--n--f--r--a--n--c--h--i--s--e--d
# |  |  |  |--g--r--a--c--e--f--u--l
# |  |  |  |--h--e--s
# |  |  |  |--i--l--l--u--s--i--o--n--m--e--n--t
# |  |  |  |  |--n--t--e--g--r--a--t--e--d
# |  |  |  |--l--i--k--i--n--g
# |  |  |  |--m--a--y--s
# |  |  |  |--o--b--e--d--i--e--n--c--e
# |  |  |  |--p--a--r--a--g--e
# |  |  |  |  |--e--l--l--i--n--g
# |  |  |  |  |--i--r--i--t--e--d
# |  |  |  |  |--o--s--e
# |  |  |  |  |--u--t--i--n--g
# |  |  |  |--r--e--s--p--e--c--t--i--n--g
# |  |  |  |--s--e--m--b--l--i--n--g
# |  |  |  |  |--i--n--g--e--r
# |  |  |  |  |--y--m--m--e--t--r--i--c
# |  |  |  |--t--i--l--l--a--t--e
# |  |  |  |  |  |--n--g--u--i--s--h
# |  |  |  |  |--r--e--s--s--e--d
# |  |  |  |  |  |--i--c--t--s
# |  |  |--t--c--h--i--n--g
# |  |  |  |--t--m--a--n--n
# |  |  |--v--a--s
# |  |  |  |--e--r--s--i--f--i--c--a--t--i--o--n
# |  |  |  |  |--s--t--i--t--u--r--e
# |  |  |  |--i--n--i--n--g
# |  |  |  |--o--r--c--e--e
# |  |  |--z--z--y
# |  |--o--a--n--n--a
# |  |  |--b--y
# |  |  |  |--l--e
# |  |  |--c--k--e--t
# |  |  |  |--t--o--r--a--t--e--s
# |  |  |--d--d
# |  |  |  |--s--o--n
# |  |  |--e--s
# |  |  |  |--r--s--a--m
# |  |  |--g--g--e--r--e--l
# |  |  |--h--e--n--y
# |  |  |--i--n--g--s
# |  |  |--l--l
# |  |  |  |--e--'--s
# |  |  |  |--l--o--p
# |  |  |--m--a--g--a--l--s--k--i
# |  |  |  |--e--k
# |  |  |  |  |--s--t--i--c
# |  |  |  |--i--n--a
# |  |  |  |  |  |--i
# |  |  |  |  |  |--u--s
# |  |  |--n--抰
# |  |  |  |--a--h--o--e
# |  |  |  |  |--t--e--s
# |  |  |  |--e--r
# |  |  |  |--k--e--y
# |  |  |  |  |  |--y--s
# |  |  |  |  |  |  |--抯
# |  |  |  |  |  |  |--'--s
# |  |  |  |--l--o--n
# |  |  |  |--n--y
# |  |  |  |--'--t
# |  |  |  |--u--t--s--'
# |  |  |--o--m--s
# |  |  |  |--r--n--a--i--l
# |  |  |--r--a--i--s
# |  |  |  |--e--t--t--e
# |  |  |  |--i--o--n
# |  |  |  |--n--a--n
# |  |  |  |--r--e--l--l
# |  |  |  |--t--m--u--n--d
# |  |  |--s--i--e--r
# |  |  |--t--a--n
# |  |  |--u--b
# |  |  |  |--r
# |  |  |  |--b--t--f--i--r--e--s
# |  |  |  |--g--h--e--r
# |  |  |--v--e--t--a--i--l--e--d
# |  |  |--w--e--l--s
# |  |  |  |--n--e--r
# |  |  |  |  |--p--a--y--m--e--n--t
# |  |  |  |  |--s--t--a--t--e
# |  |  |  |--t--y
# |  |--q--a--l--p--h--a
# |  |--r--y
# |  |  |--a--c--u--l--a
# |  |  |  |--g--g--e--d
# |  |  |  |--i--n
# |  |  |  |--m--a--t--i--z--a--t--i--o--n
# |  |  |  |--p--i--n--g
# |  |  |  |--w--d--o--w--n
# |  |  |--e--w
# |  |  |  |--a--d--i--n--g
# |  |  |  |--c--h--s--l--e--r
# |  |  |  |--n--c--h
# |  |  |  |--s--s--e--d
# |  |  |  |--w--s
# |  |  |--i--e--v--e--r
# |  |  |  |--f--t--e--d
# |  |  |  |--n--k
# |  |  |  |  |--a--'--s
# |  |  |  |--s--k--e--l--l
# |  |  |--o--b--n--y
# |  |  |  |--m--o--n
# |  |  |  |--p--o--u--t--s
# |  |  |  |--v--e--s
# |  |  |--u--c--k--e--r
# |  |  |  |--i--d--i--s--m
# |  |  |  |--n--k
# |  |  |--y--e--r--s
# |  |--u--g
# |  |  |--a--l--s
# |  |  |--b--e--r--s--t--e--i--n
# |  |  |  |--o--w
# |  |  |--c--e
# |  |  |  |--k--e--r
# |  |  |--d--a
# |  |  |  |--m--a--n
# |  |  |--e--n--s--i--n--g
# |  |  |--f--f--e--l--l
# |  |  |--h--a--r--t
# |  |  |--k--e--s
# |  |  |--l--i--n--g
# |  |  |--m--a--i--n--e
# |  |  |  |--l--e--r
# |  |  |  |--p--t--y
# |  |  |--n--k
# |  |  |  |--s
# |  |  |  |--d--e--e
# |  |  |  |--l--a--y
# |  |  |--p--e--d
# |  |  |  |--o--n--t
# |  |  |--r--a--m--e--d
# |  |  |  |--e--e
# |  |  |  |--i--s
# |  |  |  |--r--a--n--c--e
# |  |  |--s--h--a--n--e
# |  |  |  |--z--a
# |  |  |--t--t--o--n
# |  |--w--a--r--f--e--d
# |  |  |--e--l--l--i--n--g
# |  |  |--i--n--d--l--e
# |  |--y--k
# |  |  |--a--t--r--o--n
# |  |  |--n--a--m--i--c--s
# |  |  |  |  |--s--t--y
# |  |  |--s--f--u--n--c--t--i--o--n--a--l
# |
# |--e--v
# |  |--a--t
# |  |  |--g--e--r--n--e--s--s
# |  |  |--m--e--r
# |  |  |--r--s
# |  |  |  |--l--i--e--r
# |  |  |  |  |  |  |--r--'--s
# |  |  |  |--n--e--y
# |  |  |  |--t--h
# |  |  |  |  |--h--y
# |  |  |--s--t
# |  |  |  |--t--e--r--w--o--o--d
# |  |  |  |--u--d--e--s
# |  |  |--u--x
# |  |--b--b--i--n--g
# |  |  |--e--r--s--o--l--d
# |  |  |--u--l--l--i--e--n--t
# |  |--c--h--l--i--n--'--s
# |  |  |--k--e--n--f--e--l--d--e--r
# |  |  |  |--l--e--y
# |  |  |--o--l--o--g--i--c--a--l
# |  |  |  |--n--o--m--i--z--e
# |  |  |--s--t--a--s--y
# |  |  |--u--m--e--n--a
# |  |--d--d--s
# |  |  |--e--n--t--o--n
# |  |  |--g--e--w--i--s--e
# |  |  |--i--f--i--c--e
# |  |  |  |--t--i--o--n--'--s
# |  |  |--l--e--m--a--n
# |  |  |--m--o--n--s--o--n
# |  |  |--r--i--s
# |  |  |--w--a--r--d--'--s
# |  |--e--l--p--o--u--t--s
# |  |--f--f--e--c--t--i--v--e--l--y
# |  |  |  |  |--r--v--e--s--c--e--n--t
# |  |  |  |--o--r--t
# |  |  |  |--r--o--n--t--e--r--y
# |  |--g--o
# |  |  |--e--l--s--t--o--n
# |  |  |--g--p--l--a--n--t
# |  |--h--i--n--g--e--r
# |  |  |--r--e--t
# |  |--i--c--h--e--n--b--a--u--m
# |  |  |  |--k--h--o--l--t
# |  |  |--g--h--t--f--o--l--d
# |  |  |--l--e--y
# |  |  |--s--a--m--a--n
# |  |  |  |--e--n--h--o--w--e--r
# |  |  |  |--s--l--e--r
# |  |--k--e
# |  |--l--a
# |  |  |--a--s--t--o--m--e--r
# |  |  |--b--o--w--i--n--g
# |  |  |--d--e--r--s
# |  |  |  |--i--n
# |  |  |--e--c--t--a--b--i--l--i--t--y
# |  |  |  |  |  |--r--i--c--a--l
# |  |  |  |  |  |  |--o--n
# |  |  |  |  |  |  |  |--c--a--r--d--i--o--g--r--a--m--s
# |  |  |  |--g--a--n--c--e
# |  |  |  |--p--h--a--n--t
# |  |  |  |  |  |  |  |--t--s
# |  |  |--f--i--e
# |  |  |--i--a
# |  |  |  |--m--i--n--a--t--i--n--g
# |  |  |  |--t--e--s
# |  |  |--k--i--n--s
# |  |  |--l--e--n--b--e--r--g
# |  |  |  |  |--s--m--e--r--e
# |  |  |  |--i--n--w--o--o--d
# |  |  |  |--s--b--e--r--g--'--s
# |  |  |--m--o--o--t--a--z--b--e--l--l--a--h
# |  |  |--o--q--u--e--n--t
# |  |  |--s--e
# |  |  |  |--e--r
# |  |  |--t--z--r--o--t--h
# |  |  |--v--i--n--g--t--o--n
# |  |  |--y--s--i--u--m
# |  |--m--a--n--c--i--p--a--t--e
# |  |  |--b--a--r--k--i--n--g
# |  |  |  |--e--l--l--i--s--h--i--n--g
# |  |  |  |--l--e--r
# |  |  |  |--r--a--c--e
# |  |  |  |  |  |  |--e--d
# |  |  |  |  |--o--i--d--e--r
# |  |  |--d--r
# |  |  |--e--r--g--e--s
# |  |  |--i--g
# |  |  |  |--l--y--'--s
# |  |  |--l--e--r
# |  |  |--m--e--t--t
# |  |  |--o--t--i--o--n--a--l--l--y
# |  |  |--p--h--a--t--i--c--a--l--l--y
# |  |  |  |--l--o--y--e--r--'--s
# |  |  |  |--t--e--d
# |  |  |--u--l--a--t--e
# |  |--n--d
# |  |  |--a--m--e--l
# |  |  |--c--e--p--h--a--l--i--t--i--s
# |  |  |  |--l--a--v--e--s
# |  |  |  |--o--u--n--t--e--r--s
# |  |  |  |--y--c--l--i--c--a--l
# |  |  |--d--e--a--r--m--e--n--t
# |  |  |  |--i--c--o--t--t
# |  |  |  |--o--r--s--e--d
# |  |  |  |--r--e--s
# |  |  |--e--m--y--'--s
# |  |  |--f--i--n--g--e--r
# |  |  |--g--a--g--e--m--e--n--t--s
# |  |  |  |--e--l--m--a--n
# |  |  |  |--i--n--e--e--r--e--d
# |  |  |  |--l--e--s
# |  |  |  |--u--l--f
# |  |  |--i--t--t
# |  |  |--j--o--y
# |  |  |  |  |--y--i--n--g
# |  |  |--l--i--g--h--t--e--n
# |  |  |--m--i--t--y
# |  |  |--o--u--g--h
# |  |  |--q--u--e--s--o
# |  |  |--r--o
# |  |  |--s--e--y
# |  |  |  |--n--a--r--l--e--d
# |  |  |--t--a--n--g--l--e--d
# |  |  |  |--e--r
# |  |  |  |  |--r--p--r--i--s--e--s
# |  |  |  |--h--u--s--i--a--s--m
# |  |  |  |--i--t--l--e--m--e--n--t--s
# |  |  |  |--r--a--n--t
# |  |  |  |  |--e--p--r--e--n--e--u--r--i--a--l--i--s--m
# |  |  |--u--m--e--r--a--t--e--d
# |  |  |--v--i--r--o--n--m--e--n--t--'--s
# |  |  |  |--o--y
# |  |--o--s--'--s
# |  |--p--i--d--e--m--i--o--l--o--g--i--s--t--s
# |  |  |  |--s--t--e--m--e
# |  |  |--o--c--h--s
# |  |  |--r--o--m--s
# |  |--q--u--a--n--i--m--i--t--y
# |  |  |  |--i--o--n
# |  |  |  |  |--v--a--l--e--n--c--e
# |  |--r--k
# |  |  |--a--s
# |  |  |--b--y
# |  |  |--g--l--e
# |  |  |--i--c--s--o--n
# |  |  |--m--a--n
# |  |  |--n--s--t
# |  |  |--o--t--i--c--i--s--m
# |  |  |--r--o--r--s
# |  |  |--u--p--t--i--o--n
# |  |--s--h
# |  |  |--c--a--l--a--t--e--d
# |  |  |  |  |--p--e
# |  |  |  |  |  |--e--d
# |  |  |  |  |  |  |--s
# |  |  |  |--h--m--a--n--n
# |  |  |--m--e
# |  |  |--p--e--r--a--n--t--o
# |  |  |  |--r--e--s--s--o
# |  |  |--s--e
# |  |  |  |--o--n
# |  |  |--t--e--e
# |  |  |  |  |--v--e--z
# |  |  |  |--r--a--d--a
# |  |--t--c
# |  |  |--h--e--l--i--n--d--a
# |  |  |  |--i--c--s
# |  |  |  |--o--s
# |  |  |--t--i--e
# |  |--u--c--h--r--e--d
# |  |  |--l--o--g--i--z--e
# |  |  |--r--o
# |  |  |  |--o--m--a--r--k
# |  |  |  |  |--p--i--u--m
# |  |--v--e
# |  |  |--a--l--u--a--t--e--d
# |  |  |  |--n--g--i
# |  |  |--e--n
# |  |  |  |--n--s--o--n
# |  |  |  |--r--y
# |  |  |  |  |--e--t--t--e
# |  |  |  |  |--m--o--r--e
# |  |  |  |  |--y--t--h--i--n--g
# |  |  |  |  |  |  |  |  |  |--g--'--s
# |  |  |--i--l--d--o--e--r--s
# |  |  |--o--k--e--s
# |  |--w--e--l--l
# |  |--x--a--c--e--r--b--a--t--i--n--g
# |  |  |  |--l--t--s
# |  |  |  |--s--p--e--r--a--t--i--o--n--s
# |  |  |--c--e--l--'--s
# |  |  |  |  |--r--p--t--s
# |  |  |  |--i--t--a--b--l--e
# |  |  |  |--l--u--s--i--o--n
# |  |  |  |--r--u--c--i--a--t--i--n--g
# |  |  |--e--c--u--t--i--o--n--e--r--'--s
# |  |  |  |--m--p--t--e--d
# |  |  |--f--o--l--i--a--t--e
# |  |  |--h--i--b--i--t--o--r
# |  |  |--i--g--e--n--t
# |  |  |  |--l--e
# |  |  |  |--s--t
# |  |  |--l--i--n--e
# |  |  |--p--a--n--d--e--d
# |  |  |  |--e--c--t--a--t--i--o--n--s
# |  |  |  |  |--n--d--a--b--l--e
# |  |  |  |  |--r--i--e--n--c--e
# |  |  |  |  |  |  |--m--e--n--t--a--t--i--o--n
# |  |  |  |--i--r--y
# |  |  |  |--l--a--i--n
# |  |  |  |  |--o--i--t--a--t--i--v--e
# |  |  |  |  |  |--s--i--v--o--s
# |  |  |  |--o--s--i--t--i--o--n
# |  |  |  |--r--e--s--s--i--o--n--s
# |  |  |--t--e--n--d--e--d
# |  |  |  |  |--r--m--i--n--a--t--i--o--n
# |  |  |  |--o--r--t--e--d
# |  |  |  |--r--a
# |  |  |  |  |--a--n--e--o--u--s
# |  |  |  |  |--e--m--e--l--y
# |  |  |--u--d--e--s
# |  |--y--e
# |  |  |--e--d--r--o--p--p--e--r
# |  |  |  |--s--'
# |  |  |--t--o--n
# |
# |--f--a--b
# |  |  |--r
# |  |  |--w
# |  |  |--b--r--i--c--a--t--e
# |  |  |--c--c--h--i--n--i
# |  |  |  |--i--e
# |  |  |  |--t--e--a--u
# |  |  |  |--u--l--t--i--e--s
# |  |  |--e--t--h
# |  |  |--h--l--m--a--n
# |  |  |--i--l--e--d
# |  |  |  |  |--l--a
# |  |  |  |  |--u--r--e
# |  |  |  |--r--b--a--n--k
# |  |  |  |  |--l--a--w--n
# |  |  |  |--s--o--n
# |  |  |--l--a--r--d--e--a--u
# |  |  |  |--e--r
# |  |  |  |--l--s
# |  |  |  |  |--a--c--i--o--u--s
# |  |  |  |--t--e--r--i--n--g
# |  |  |--m--i--l--y
# |  |  |  |  |  |--i--a--r
# |  |  |  |  |  |  |  |--r--i--t--y
# |  |  |--n--a--t--i--c--s
# |  |  |  |--g--e--r
# |  |  |  |--t--a
# |  |  |  |--u--e--i--l
# |  |  |--r--b--e--n
# |  |  |  |--h--a--t
# |  |  |  |--l--e--r
# |  |  |  |--m--i--n--g
# |  |  |  |--n--h--a--m
# |  |  |  |--r--a--n--d
# |  |  |  |  |--o--w--i--n--g
# |  |  |--s--c--i--a--n--o
# |  |  |  |--o--n
# |  |  |  |--t--i--d--i--o--u--s
# |  |  |--t--h
# |  |  |  |--h--e--r
# |  |  |  |--i--m--a
# |  |  |--u--c--e--t
# |  |  |  |--l--k--n--e--r--'--s
# |  |  |  |--s--e--t--t
# |  |  |--v--a--t--a
# |  |  |--y--e--d
# |  |--e--a--g--i--n
# |  |  |  |--r--s
# |  |  |  |--s--t--e--r
# |  |  |  |--t--u--r--e--s
# |  |  |--d--a--k
# |  |  |  |--e--r--a--t--e
# |  |  |  |--l--e--r
# |  |  |--e--d
# |  |  |  |--t
# |  |  |  |--d--s
# |  |  |  |  |--i--n--g
# |  |  |  |--l--i--n--g
# |  |  |--i--g
# |  |  |  |--n--b--e--r--g
# |  |  |--l--l
# |  |  |  |--s
# |  |  |  |--b--a--t--o--l
# |  |  |  |--d--s--p--a--r
# |  |  |  |--i--z
# |  |  |  |--l--m--a--n
# |  |  |--m--a--l--e
# |  |  |  |  |  |--e--'--s
# |  |  |--n--d
# |  |  |  |--j--v--e--s
# |  |  |  |--s--t--e--r--s--t--o--c--k
# |  |  |--r--d
# |  |  |  |--n
# |  |  |  |--o
# |  |  |  |--g--u--s--o--n
# |  |  |  |--r--e
# |  |  |  |  |--i
# |  |  |  |  |--o--f--l--u--i--d--i--c
# |  |  |  |--t--i--l--e
# |  |  |--s--h--b--a--c--h
# |  |  |  |--t--i--v--i--t--y
# |  |  |--t--z
# |  |  |  |--n--e--r
# |  |  |--v--e--r--f--e--w
# |  |--i--g
# |  |  |--a--s--c--o
# |  |  |--b--r--o--i--d--s
# |  |  |--c--k--e--t--t
# |  |  |--d--d--l--e--r--s
# |  |  |  |--u--c--i--a--r--e--s
# |  |  |--e--l--d--e--d
# |  |  |  |--r--m--a--n
# |  |  |--f--t--h--s
# |  |  |--g--h--t
# |  |  |  |  |--t--e--r--'--s
# |  |  |  |--u--r--a
# |  |  |--l--a
# |  |  |  |--l
# |  |  |  |--e--t--s
# |  |  |  |--i--p--o--v--i--c
# |  |  |  |--l--e--y
# |  |  |  |--m--l--e--s--s
# |  |  |  |--t--r--a--t--i--o--n
# |  |  |--n--e
# |  |  |  |--k
# |  |  |  |--a--m--o--r--e
# |  |  |  |  |--n--z--a
# |  |  |  |--d--i--n--g--s
# |  |  |  |--e--s
# |  |  |  |--g--e--r--p--r--i--n--t--i--n--g
# |  |  |  |--l--a--n--d--i--z--a--t--i--o--n
# |  |  |  |--n--i--g--a--n
# |  |  |--o--r--e
# |  |  |--r--e--a--r--m--s
# |  |  |  |  |--f--i--g--h--t
# |  |  |  |  |--s--i--d--e
# |  |  |  |--m--a
# |  |  |  |--s--t
# |  |  |  |  |--t--i--e--r
# |  |  |--s--c--h--m--a--n
# |  |  |  |--h--e--l--l
# |  |  |  |--k--e--'--s
# |  |  |--t--a--k
# |  |  |  |--t--i--n--g--s
# |  |  |  |--z--r--o--y
# |  |  |--x--e--d
# |  |--l--a--n
# |  |  |  |--b--b--e--r--g--a--s--t--e--d
# |  |  |  |--g--s
# |  |  |  |--m--b--o--y--a--n--c--e
# |  |  |  |--n--n--e--r--y
# |  |  |  |--s--h--d--a--n--c--e
# |  |  |  |--t--e--n
# |  |  |  |  |--t--e--r--i--n--g
# |  |  |  |--v--o--r
# |  |  |--e--d
# |  |  |  |--a--g--l--e
# |  |  |  |--e--n--o--r
# |  |  |  |--i--s--h--m--a--n
# |  |  |  |--s--h
# |  |  |  |  |--h--e--d
# |  |  |  |--x--e--s
# |  |  |--i--e--d
# |  |  |  |--n--c--h--u--m
# |  |  |  |--p--p--e--n
# |  |  |--o--a--t--e--d
# |  |  |  |--o--d
# |  |  |  |--p--p--i--n--g
# |  |  |  |--r--e--s
# |  |  |  |  |--i--s--t
# |  |  |  |--u--n--d--e--r--s
# |  |  |  |--w--e--r--y
# |  |  |--u--e--g--g--e
# |  |  |  |--m--e
# |  |  |  |--o--r--i--n--e
# |  |  |  |--t--t--e--r
# |  |  |--y--w--a--y
# |  |--o--r
# |  |  |--c--u--s
# |  |  |--g--e--l--m--a--n
# |  |  |--i--l--e--d
# |  |  |--l--e--y
# |  |  |  |--k--r--o--c--k
# |  |  |  |--l--m--e--r
# |  |  |  |  |--o--w--e--d
# |  |  |  |  |  |  |--i--n--g
# |  |  |  |--w--e--l--l
# |  |  |--n--d--l--i--n--g
# |  |  |  |--t--e
# |  |  |--o--d
# |  |  |  |--l
# |  |  |  |--t
# |  |  |  |--k--s
# |  |  |  |--l--i--s--h
# |  |  |  |--t--b--a--l--l--'--s
# |  |  |  |  |--p--a--t--h
# |  |  |--r--a--n--d
# |  |  |  |--c--e--d
# |  |  |  |--e--a--r--m
# |  |  |  |  |--f--a--t--h--e--r
# |  |  |  |  |--m--a--n
# |  |  |  |  |--s--t
# |  |  |  |  |  |--h--a--d--o--w--s
# |  |  |  |  |--t--o--l--d
# |  |  |  |--g--e--t
# |  |  |  |  |  |--r--y
# |  |  |  |  |--o--e--s
# |  |  |  |--k--l--i--f--t
# |  |  |  |--m--a--n
# |  |  |  |  |--i--d--a--b--l--y
# |  |  |  |--n--e--y
# |  |  |  |--s--e--e
# |  |  |  |  |--y--t--h--e
# |  |  |  |--t--i--f--i--c--a--t--i--o--n
# |  |  |  |  |--r--e--s--s--e--s
# |  |  |  |--w--a--r--d--i--n--g
# |  |  |--s--s--e--n
# |  |  |--t--o--p--o--u--l--o--s
# |  |  |--u--r
# |  |  |  |--n--d--a--t--i--o--n--'--s
# |  |  |  |--r--m--a--n
# |  |  |  |--t--c--h
# |  |  |--x--h--o--l--e--s
# |  |--r--a--p
# |  |  |  |--b--l--e
# |  |  |  |--g--i--l--e
# |  |  |  |--i--m
# |  |  |  |--m--e
# |  |  |  |  |--e--s
# |  |  |  |  |  |--r--s--'
# |  |  |  |--n--c--e--s--c--h--i
# |  |  |  |  |  |--h--i--s--i--n--g
# |  |  |  |  |  |--k--o--w--i--a--k
# |  |  |  |  |--k--i--e--w--i--c--z
# |  |  |  |  |  |--'--s
# |  |  |  |  |--n--i--e
# |  |  |  |--t--e--r--n--a--l
# |  |  |  |--u--s--t--o
# |  |  |--e--a--k--i--n--g
# |  |  |  |--d--d--y--'--s
# |  |  |  |  |--i--a--n--i
# |  |  |  |--e--l
# |  |  |  |  |--b--u--r--n
# |  |  |  |  |--m--y--e--r
# |  |  |  |  |--w--i--n--g
# |  |  |  |--i--e--r
# |  |  |  |  |--t--a--s
# |  |  |  |--n--z--e--l
# |  |  |  |--s--h
# |  |  |  |  |--c--o--e--s
# |  |  |  |  |--h--w--a--t--e--r
# |  |  |  |--u--n--d--l--i--c--h
# |  |  |--i--b--o--u--r--g
# |  |  |  |--d--r--i--c--h
# |  |  |  |--e--d--l--e--y
# |  |  |  |  |--n--d
# |  |  |  |  |  |--d--s
# |  |  |  |  |  |  |--l--i--e--s--t
# |  |  |  |--g--a--t--e--'--s
# |  |  |  |--n--g--e
# |  |  |  |--s--k--y
# |  |  |  |--t--z--i
# |  |  |--o--m
# |  |  |  |--e--s--e
# |  |  |  |--m--a--n
# |  |  |  |--n--t--a--l
# |  |  |  |--s--t--b--a--n
# |  |  |  |--z--e--n
# |  |  |--u--i--t
# |  |  |  |  |--t--s
# |  |  |  |  |  |--l--e--s--s
# |  |  |  |--t--h
# |  |--u--c--h--s
# |  |  |--e--l--l--e--d
# |  |  |--g--u--e--s
# |  |  |--j--i--s
# |  |  |--l--l
# |  |  |  |--a--n--i
# |  |  |  |--l--y
# |  |  |--m--e
# |  |  |--n--c--t--i--o--n--a--r--y
# |  |  |  |--d--r--a--i--s--e--r
# |  |  |  |--k--e
# |  |  |--q--u--a--y
# |  |  |--r--y
# |  |  |  |--i--o--u--s
# |  |  |  |--n--i--s--h
# |  |  |  |--s--e
# |  |  |--s--s--i--n--g
# |  |  |--t--u--r--i--s--t--i--c
# |
# |--g--o
# |  |--a--l
# |  |  |--b--e--l
# |  |  |  |--r--i--e--l--l--a
# |  |  |--d--d--u--m
# |  |  |--e--b--e--l
# |  |  |--g--e
# |  |  |--h--n
# |  |  |--i--n--e--y
# |  |  |--l--a--s--s--o
# |  |  |  |--e--n
# |  |  |  |--i--e
# |  |  |  |--l--a--g--h--e--r
# |  |  |  |  |--e--o--n
# |  |  |  |  |--i--g--a--n
# |  |  |  |  |--o--p--e--d
# |  |  |  |--o--s--h--e--s
# |  |  |  |--v--e--z
# |  |  |--m--b--l--e
# |  |  |  |--e--l--i--n
# |  |  |  |--m--a--g--e
# |  |  |--n--d--a
# |  |  |  |--g--e
# |  |  |  |  |--e--s
# |  |  |  |--l--e--y
# |  |  |  |--t--o--s
# |  |  |--r--n
# |  |  |  |--o
# |  |  |  |--a--b--e--d--i--a--n
# |  |  |  |--b--e
# |  |  |  |--d--e--a
# |  |  |  |  |--n--e--r
# |  |  |  |--g--e--r
# |  |  |  |--l--a--n
# |  |  |  |--r--e--t
# |  |  |  |  |--i--t--a--n--o
# |  |  |  |--s--t
# |  |  |  |--t--s--i--d--e
# |  |  |--s--c--o--n
# |  |  |  |--k--e--y
# |  |  |  |--p--s
# |  |  |  |--t--o--n
# |  |  |--t--e--l--e--y
# |  |  |  |--i--e--n
# |  |  |  |--t--u--s--o
# |  |  |--u--d--i--n
# |  |  |  |--g--u--i--n
# |  |  |  |--n--t--t
# |  |  |--v--e
# |  |  |  |--e--l
# |  |  |--w--n--e
# |  |  |--y--m--o--n
# |  |  |--z--e--l--l--e--s
# |  |--e--t
# |  |  |--a--r--e--y
# |  |  |--c--k--o
# |  |  |--e--r--s
# |  |  |--h--m
# |  |  |--i--d--e--l
# |  |  |  |--s--l--e--r
# |  |  |--l--b--e--r
# |  |  |  |--m--a--n
# |  |  |--m--m--a
# |  |  |--n--d--e--r--s
# |  |  |  |--e--t
# |  |  |  |  |--r--a--l--e
# |  |  |  |  |  |  |--t--i--o--n
# |  |  |  |--i--e
# |  |  |  |--o--c--i--d--a--l
# |  |  |  |--s--k--e
# |  |  |  |--t--l--y
# |  |  |  |  |  |--e--m--e--n
# |  |  |  |--u--i--n--e--l--y
# |  |  |--o--g--r--a--p--h--i--c--'--s
# |  |  |  |--p--o--l--i--t--i--c
# |  |  |  |--r--g--i--a--n
# |  |  |--p--h--a--r--d--t--'--s
# |  |  |--r--a--s--h--c--h--e--n--k--o
# |  |  |  |--e--n
# |  |  |  |--i--n--g
# |  |  |  |--m--a--n--i--a
# |  |  |  |--n--e--r
# |  |  |  |--r--i--t--y
# |  |  |  |--s--t--e--n--b--e--r--g--e--r
# |  |  |  |--v--a--s--i--o
# |  |  |--s--t--a--t--e
# |  |  |--t--t--e--l
# |  |  |  |  |--i--n--g
# |  |  |--v--a
# |  |--h--a--s--t--l--i--n--e--s--s
# |  |  |--o--r--b--a--n--i--f--a--r
# |  |--i--a--c--o--m--e--t--t--i
# |  |  |  |--n--c--a--n--a
# |  |  |  |  |--o--t--t--i
# |  |  |--b--b--i--n--s
# |  |  |  |--o--n--e--y
# |  |  |--e--g--e--r--i--c--h
# |  |  |  |--s--e--r
# |  |  |--f--t--w--a--r--e
# |  |  |--g--a--n--t--i--c
# |  |  |  |--n--o--u--x
# |  |  |--l--b--o
# |  |  |  |--d--n--e--r
# |  |  |  |--l--a--m
# |  |  |  |  |--e--t--t--e
# |  |  |  |  |--i--n--g--h--a--m
# |  |  |  |--m--a--n
# |  |  |--m--m--e
# |  |  |--n--g--e--r--i--c--h
# |  |  |  |--s--b--e--r--g
# |  |  |--o--r--g--i
# |  |  |--r--l
# |  |  |  |--a--l--d--o
# |  |  |  |--o--z--e--n--t--r--a--l--e
# |  |  |--s--m--o--n--d--i
# |  |  |--t--t--o
# |  |  |--v--e
# |  |  |  |--e--n
# |  |  |  |  |--b--a--c--k--s
# |  |  |--z--z--a--r--d
# |  |--l--a--d--d--e--n
# |  |  |  |  |--s--t--o--n--e--s
# |  |  |  |--n--d--o--n
# |  |  |  |--s--g--o--w
# ...
# |  |  |  |--i--l--l--e--d
# |  |  |  |  |--v--e
# |  |  |  |--o--n--g--s
# |  |  |  |  |--u--g--h
# |  |  |  |  |  |  |--h--o--u--t
# |  |  |  |  |--w--s
# |  |  |--u--m--a
# |  |  |  |--n--d--e--r--b--o--l--t
# |  |  |  |--r--m--a--n
# |  |  |--w--a--r--t--e--d
# |  |--i--c
# |  |  |--a--n--o
# |  |  |--c--k--l--e--d
# |  |  |--d--i--n--g--s
# |  |  |--e--n--a--n--m--e--n
# |  |  |--f--f--i--n
# |  |  |--g--h--t--e--n--s
# |  |  |--l--b--u--r--y
# |  |  |  |--l--m--a--n
# |  |  |--m--e
# |  |  |  |--m
# |  |  |  |--b--e--r--l--a--n--d--s
# |  |  |  |--e--p--l--e--x
# |  |  |  |--p--a--n--i
# |  |  |--n--d--l--e
# |  |  |  |--k--e--r--e--r--s
# |  |  |  |--s--l--e--y
# |  |  |--p--p--e--r--a--r--y
# |  |  |  |--t--o--e
# |  |  |--r--i--n--g
# |  |  |--s--s--u--e--s
# |  |  |--t--l--e--d
# |  |--j--a--d--e--n
# |  |-----l--a--m
# |  |--o--o
# |  |  |--b--a--c--c--o--'--s
# |  |  |--c--c--i
# |  |  |--d--i--s--c--o
# |  |  |--f--u
# |  |  |--i--v--o--n--e--n
# |  |  |--l--d
# |  |  |  |--a--n--d
# |  |  |  |--e--s
# |  |  |  |--l--s
# |  |  |--m--a--s--e--l--l--i
# |  |  |  |  |--y--k--o
# |  |  |  |--i--c--h
# |  |  |  |--p--s--o--n
# |  |  |--n--e--s
# |  |  |  |--g--s
# |  |  |  |--k--o--v--i--c--h
# |  |  |  |--y--a--'--s
# |  |  |--o--l--m--a--k--e--r--s
# |  |  |  |--t--h--l--e--s--s
# |  |  |--p--s
# |  |  |  |--e--l
# |  |  |  |--p--e--r
# |  |  |--r--n
# |  |  |  |--y
# |  |  |  |--a--n
# |  |  |  |--g--e--s--o--n
# |  |  |  |--m--e--n--t--i--n--g
# |  |  |  |--p--e--d--o--e--d
# |  |  |  |--r--e--n--z--a--n--o
# |  |  |  |--t--i--l--l--a--s
# |  |  |--s--s--e--s
# |  |  |--t--a--l--s
# |  |  |  |  |  |--l--y
# |  |  |  |--t--o--n
# |  |  |--u--g--h--e--d
# |  |  |  |--r--e--t--z--k--y
# |  |  |  |--s--l--e--y
# |  |  |--w--n
# |  |  |  |--a--r--d--s
# |  |  |  |--b--o--a--t
# |  |  |  |--n--s--l--e--y
# |  |  |--y--a--m--a
# |  |  |--z--z--i
# |  |--r--a--c--i--e
# |  |  |  |  |--t--o--r--s
# |  |  |  |--d--e--s
# |  |  |  |--f--f--o--r--d
# |  |  |  |--i--l--e--r
# |  |  |  |  |--n--s
# |  |  |  |--m--m--e--l
# |  |  |  |--n--c--h--e--s
# |  |  |  |  |--s--a--m--e--r--i--c--a
# |  |  |  |  |  |--c--o--n--t--i--n--e--n--t--a--l
# |  |  |  |  |  |--f--e--r--e--d
# |  |  |  |  |  |  |--u--s--i--o--n
# |  |  |  |  |  |--i--t--i--o--n--s
# |  |  |  |  |  |--m--i--t--t--a--l
# |  |  |  |  |  |--p--i--r--e--s
# |  |  |  |  |  |--r--a--c--i--a--l
# |  |  |  |  |--z--o--n--i--c
# |  |  |  |--s--h--y
# |  |  |  |--u--t--w--e--i--n
# |  |  |  |--v--e--l--s
# |  |  |  |--w--i--c--k
# |  |  |--e--e
# |  |  |  |--a--d--m--i--l--l--s
# |  |  |  |  |--s--o--n
# |  |  |  |  |--t--a--b--l--e
# |  |  |  |--e--s
# |  |  |  |  |--t--o--p
# |  |  |  |--i--b--e--r
# |  |  |  |--m--b--l--e
# |  |  |  |--n--c--h--a--r--d
# |  |  |  |  |--t--m--a--n
# |  |  |  |--t--h--e--w--e--y
# |  |  |  |--z--z--a
# |  |  |--i--b--a--l
# |  |  |  |  |--u--n--a--l--s
# |  |  |  |--c--k--e--l
# |  |  |  |  |  |--s--t--e--r--s
# |  |  |  |--e--d
# |  |  |  |--g--o
# |  |  |  |--m--e--t--r--e--x--a--t--e
# |  |  |  |--n--o--v--a
# |  |  |  |--p--l--i--n--g
# |  |  |  |--s--h--a--'--s
# |  |  |  |--u--m--p--h--a--l
# |  |  |  |--z--e--c--'--s
# |  |  |--o--j--a--n
# |  |  |  |--n--c--o--s--o
# |  |  |  |--p--i--c--a--l
# |  |  |  |--t--t--e--n
# |  |  |  |--u--b--l--e
# |  |  |  |  |--n--c--i--n--g
# |  |  |  |--w--e--l
# |  |  |--u--e
# |  |  |  |--c--h--a--n
# |  |  |  |--d--g--e--d
# |  |  |  |--f--f--a--u--t
# |  |  |  |--m--b--u--l--l
# |  |  |  |--n--k--s
# |  |  |  |--s--t--c--o--r--p
# |  |  |  |  |  |--e--d
# |  |  |  |--t--h
# |  |  |  |--x--a--l
# |  |  |--y--i--n--g
# |  |  |--z--e--c--i--a--k
# |  |--s--i--n--g--t--a--o
# |  |--u--b--b--s
# |  |  |--c--k--e--d
# |  |  |--e--s--d--a--y--'--s
# |  |  |--g--w--e--l--l
# |  |  |--l--l--i--s
# |  |  |--m--b--l--i--n--g
# |  |  |--n--a--f--i--s--h
# |  |  |  |--i--c--a--t--e
# |  |  |--p--a
# |  |  |--r--b--i--n--e--s
# |  |  |  |--c--o
# |  |  |  |--k--i--n--g--t--o--n
# |  |  |  |--n--b--o--w
# |  |  |  |  |--o--v--e--r
# |  |  |  |--r--e--n--t--i--n--e
# |  |  |--s--c--a--n--y
# |  |  |--t--k--o
# |  |  |--x--f--o--r--d
# |  |--w--o
# |  |  |--e--a--k
# |  |  |  |--n--t--y--s--o--m--e--t--h--i--n--g
# |  |  |--i--n--e
# |  |  |  |--s--t
# |  |  |--o--n--s--h--e--i--n
# |  |--y--e--r
# |  |  |--n--e--r
# |  |  |--p--h--u--s
# |  |  |--r--e
# |
# |--u--l
# |  |--p
# |  |--s
# |  |--b--e--r
# |  |--d--v--e--r--h--y--e
# |  |--g--a--n--d--a
# |  |--h--l--e
# |  |--l--i--t--s--a
# |  |  |--r--i--c--h
# |  |  |--t--r--a--n--a--t--i--o--n--a--l--i--s--t--s
# |  |--m--b--e--r--t--o
# |  |  |--p--t--e--e--n
# |  |--n--a--b--l--e
# |  |  |  |--c--c--e--p--t--a--b--l--y
# |  |  |  |--l--l--o--c--a--t--e
# |  |  |  |--p--o--l--o--g--e--t--i--c
# |  |  |  |--v--a--i--l--a--b--i--l--i--t--y
# |  |  |--b--e--n--d--i--n--g
# |  |  |  |--u--t--t--o--n
# |  |  |--c--h--a--r--a--c--t--e--r--i--s--t--i--c--a--l--l--y
# |  |  |  |--l--e
# |  |  |  |--o--i--l--e--d
# |  |  |  |  |--n--d--i--t--i--o--n--a--l
# |  |  |  |  |  |--v--e--n--t--i--o--n--a--l
# |  |  |  |--r--i--t--i--c--a--l--l--y
# |  |  |--d--e--r
# |  |  |  |  |--r--a--c--h--i--e--v--e--r
# |  |  |  |  |  |--c--u--r--r--e--n--t--s
# |  |  |  |  |  |--f--o--o--t
# |  |  |  |  |  |--l--i--e
# |  |  |  |  |  |--p--a--n--t--s
# |  |  |  |  |  |  |--r--i--c--e--d
# |  |  |  |  |  |--s--e--r--v--e--d
# |  |  |  |  |  |  |--t--o--o--d
# |  |  |  |  |  |--v--a--l--u--e
# |  |  |  |  |  |--w--r--i--t--e--r--s--'
# |  |  |  |--i--l--u--t--e--d
# |  |  |  |--o--n--e
# |  |  |--e--c--o--n--o--m--i--c
# |  |  |  |--q--u--a--l
# |  |  |  |--x--p--l--o--d--e--d
# |  |  |--f--e--t--t--e--r--e--d
# |  |  |  |--o--r--m--e--d
# |  |  |--g--l--a--m--o--r--o--u--s
# |  |  |--h--e--s--i--t--a--t--i--n--g--l--y
# |  |  |--i--c--y--c--l--e--s
# |  |  |  |--l--a--t--e--r--a--l--i--s--m
# |  |  |  |--n--f--o--r--m--a--t--i--v--e
# |  |  |  |  |--v--i--t--i--n--g
# |  |  |  |--s--o--m
# |  |  |  |--t--e--l
# |  |  |  |--v--e--r--s--e--s
# |  |  |--k--n--o--w--n
# |  |  |--l--o--a--d
# |  |  |--m--e--n--t--i--o--n--e--d
# |  |  |--o--b--t--a--i--n--a--b--l--e
# |  |  |--p--a--r--a--l--l--e--l--e--d
# |  |  |  |--r--e--s--s--u--r--i--z--e--d
# |  |  |--q--u--e--s--t--i--o--n--a--b--l--e
# |  |  |--r--e--a--s--o--n--a--b--l--e
# |  |  |  |  |--l--i--a--b--i--l--i--t--y
# |  |  |  |--o--l--l
# |  |  |--s--c--r--a--m--b--l--e
# |  |  |  |--h--a--c--k--l--e
# |  |  |  |--p--e--c--i--f--i--e--d
# |  |  |  |--u--c--c--e--s--s--f--u--l
# |  |  |  |--y--m--p--a--t--h--e--t--i--c
# |  |  |--t--i--e--d--t
# |  |  |  |--r--u--t--h--f--u--l
# |  |  |--w--a--s--h--e--d
# |  |  |  |--o--r--k--a--b--l--e
# |  |--p--c--o--m--i--n--g
# |  |  |--h--e--l--d
# |  |  |--m--a--r--k--e--t
# |  |  |--o--n
# |  |  |--r--o--o--t--i--n--g
# |  |  |--s--t--r--e--a--m
# |  |--r--a--l
# |  |  |--b--a--n--i--t--e--s
# |  |  |--e--s--t--i
# |  |  |--i--a--s
# |  |  |--o--l--o--g--i--s--t--s
# |  |  |--s--y
# |  |--s--e--d
# |  |  |  |--l--e--s--s
# |  |  |--i--n--g
# |  |--t--e--c--h--t
# |  |  |--k--e
# |  |  |--t--e--r--e--d
# |  |  |--z--i--n--g--e--r
# |
# |--v--.
# |  |--a--c--a--v--i--l--l--e
# |  |  |  |--l--a--v
# |  |  |--g--e--l--o--s
# |  |  |--i--n--l--y
# |  |  |--l--d--i--v--i--a
# |  |  |  |--e--n--t--i--n
# |  |  |  |  |--r--y
# |  |  |  |--i--q--u--e--t--t--e
# |  |  |  |--l--e--t--t--e
# |  |  |  |--o--r
# |  |  |  |--u--i--n--g
# |  |  |--n--a--c--o--r--e
# |  |  |  |--b--e--r--g--e--n
# |  |  |  |--c--o--u--v--e--r--'--s
# |  |  |  |--d--e--h--e--y
# |  |  |  |  |  |--r--b--i--l--t
# |  |  |  |  |  |  |--l--i--n--d--e--n
# |  |  |  |  |  |  |--w--a--l
# |  |  |  |  |  |--w--a--l--k--e--r
# |  |  |  |  |--y--n--e
# |  |  |  |--g--e--l
# |  |  |  |--h--o--o--s--e
# |  |  |  |--i--s--h--i--n--g
# |  |  |  |--m--a--a--n--e--n
# |  |  |  |--n--o--r--t--w--i--c--k
# |  |  |  |--q--u--i--s--h
# |  |  |  |--s--l--o--o--t--e--n
# |  |  |  |--u--a--t--u
# |  |  |  |--w--h--y
# |  |  |--p--o--r--i--z--e--d
# |  |  |--r--i
# |  |  |  |--y
# |  |  |  |--i--n--a
# |  |  |  |--n--e--s
# |  |  |--s--t
# |  |  |  |--k--e
# |  |  |--u--g--h--n--'--s
# |  |  |--z--q--u--e--z
# |  |--e--d--a
# |  |  |--g--e--s--n--a
# |  |  |--h--i--c--l--e--s--'
# |  |  |--l--a--k--o--w--s--k--i
# |  |  |  |--l--u--c--c--i
# |  |  |--m--p--a--l--a
# |  |  |--n--t
# |  |  |  |--d--o--r--'--s
# |  |  |  |--g--e--f--u--l
# |  |  |  |--t--r--e--s--c--a
# |  |  |  |--u--s
# |  |  |--r--y
# |  |  |  |--b--i--a--g--e
# |  |  |  |--d--i--c--t--s
# |  |  |  |--g--e--s
# |  |  |  |--i--f--i--e--s
# |  |  |  |  |--l--y
# |  |  |  |--m--i--l--i--o--n
# |  |  |  |--n--i--e--r
# |  |  |  |--r--e--t
# |  |  |  |--s--i--o--n--s
# |  |  |  |--t--u--c--c--i
# |  |  |--s--s--e--l--'--s
# |  |  |  |--u--v--i--u--s
# |  |  |--t--s--c--h
# |  |--i--a--u
# |  |  |  |--b--l--e
# |  |  |--c--k
# |  |  |  |--a--r--i--o--u--s--l--y
# |  |  |  |--t--i--m--'--s
# |  |  |  |  |--o--r--i--o--u--s
# |  |  |--d--e--o--p--h--o--n--e
# |  |  |--e--s
# |  |  |  |--i--r--a
# |  |  |  |--w--p--o--i--n--t--s
# |  |  |--g--l--i--o--t--t--i
# |  |  |--k--i--n--g--s
# |  |  |--l--l--a--r
# |  |  |  |  |  |--g--e--r--s
# |  |  |  |  |--i--n--e--s
# |  |  |--n--t
# |  |  |  |--c--i
# |  |  |  |--g--m--e--d
# |  |  |--o--l--a--t--o--r--s
# |  |  |--p--o--n--t
# |  |  |--r--g--i--l--i--o
# |  |  |  |--o--l--o--g--i--s--t
# |  |  |--s--a
# |  |  |  |--i--b--l--y
# |  |  |  |--o--r
# |  |  |--t--o
# |  |  |  |--a--l--e
# |  |  |  |--u--l--l--i
# |  |  |--v--i--d--n--e--s--s
# |  |--l--a--d--'--s
# |  |--o--w
# |  |  |--c--a--l--t--e--c
# |  |  |--e--l--z
# |  |  |--h--s
# |  |  |--i--n--o--v--i--c--h
# |  |  |--l--c--k--e--r--'--s
# |  |  |  |--k--s--b--a--n--k
# |  |  |  |--n--e--y
# |  |  |  |--u--n--t--a--r--i--s--m
# |  |  |--n--a--l--l--m--e--n
# |  |  |  |--r--u--d--e--n
# |  |  |--r--n--a--d--o
# |  |  |--t--a--w
# |  |  |--y--n--a--v--i--c--h
# |  |--s--e--l
# |  |--u--l--t--u--r--e--s
# |
# |--w--e
# |  |--a--h
# |  |  |--s
# |  |  |--y
# |  |  |--a--s
# |  |  |--c--k
# |  |  |--d--s
# |  |  |  |--d--l--e
# |  |  |--g--a--m--a--n
# |  |  |  |--i--n--g
# |  |  |--i--f
# |  |  |  |--s--n--e--r
# |  |  |  |--t--i--n--g
# |  |  |  |  |--z--k--i--n
# |  |  |--k--i--n--g
# |  |  |--l--c--z--y--k
# |  |  |  |--d--i--n--g
# |  |  |  |  |--r--u--p
# |  |  |  |--i--z--e--r
# |  |  |  |--k--o--u--t
# |  |  |  |--l--e
# |  |  |  |  |--i--n--g
# |  |  |  |  |--s--e--n--d
# |  |  |  |--s--h
# |  |  |  |--t--m--a--n
# |  |  |--m--b--o--l--t
# |  |  |--n--t
# |  |  |  |--d--e--r--s
# |  |  |  |--g--l--e--r
# |  |  |  |--t--a
# |  |  |--r--m
# |  |  |  |--n
# |  |  |  |--b--u--r--g
# |  |  |  |--d--l--o--w
# |  |  |  |--f--o--r--d
# |  |  |  |--n--s
# |  |  |  |  |--e--d
# |  |  |  |--r--i--c--k
# |  |  |  |--t--h--e--n
# |  |  |--s--h
# |  |  |  |--p
# |  |  |  |--h--e--r--m--a--n
# |  |  |  |  |--o--e
# |  |  |  |--t--e--b--a--s--k--e--t--s
# |  |  |--t--c--h--e--r--s
# |  |  |  |--e--r
# |  |  |  |  |--r--f--a--l--l
# |  |  |  |  |  |--m--e--n
# |  |  |  |--f--o--r--d
# |  |  |  |--t--e--n--b--a--r--g--e--r
# |  |  |--v--e
# |  |  |--x--m--a--n
# |  |  |--y--s
# |  |--e--a--k
# |  |  |  |--k--l--a--n--d
# |  |  |  |--p--o--n--s--'
# |  |  |  |--t--h--e--r--'--s
# |  |  |  |  |  |  |  |--s--t--o--n--e
# |  |  |  |--v--e
# |  |  |  |  |--e--r
# |  |  |  |  |  |--r--'--s
# |  |  |  |  |--i--n--g
# |  |  |--b--b--s
# |  |  |--c--k--e--s--s--e--r
# |  |  |--d--g--e--w--o--o--d
# |  |  |--e--d--s
# |  |  |  |  |--i--n--g
# |  |  |  |--k--s
# |  |  |--g--m--a--n
# |  |  |--h--r--m--a--n
# |  |  |--i--d--e--n--b--a--c--h
# |  |  |  |--g--h--t
# |  |  |  |  |  |--i--n--g
# |  |  |  |--k--e--l
# |  |  |  |--n--b--a--u--m
# |  |  |  |  |--r--e--i--c--h
# |  |  |  |--r--d--n--e--s--s
# |  |  |  |--s--e--n--b--e--r--g--e--r
# |  |  |  |  |--s--e
# |  |  |  |--z--m--a--n
# |  |  |--l--l
# |  |  |  |--d--e--r--s
# |  |  |  |--l--b--r--o--c--k
# |  |  |  |  |--n--e--r
# |  |  |  |--t--e--r--w--e--i--g--h--t
# |  |  |--n--g
# |  |  |  |--t
# |  |  |  |--d--a
# |  |  |  |--s--b--e--r--g
# |  |  |--r--e
# |  |  |  |--b--e--r
# |  |  |  |--n--e
# |  |  |  |--t--h--e--i--m--e--r
# |  |  |--s--l--e--r
# |  |  |  |--s--l--i--n--g
# |  |  |  |--t--b--r--o--o--k--s
# |  |  |  |  |--e--r--f--i--e--l--d
# |  |  |  |  |  |  |--v--e--l--t
# |  |  |  |  |--l--u--n--d
# |  |  |  |  |--r--i--d--g--e
# |  |  |--t--h--e--r--l--y
# |  |  |  |--z--l--e--r
# |  |  |--y--l--i--n
# |  |--h--o
# |  |  |--y
# |  |  |--a--t
# |  |  |  |--l--i--n--g
# |  |  |  |--t--l--e--y
# |  |  |--e--n
# |  |  |  |--e--l--b--a--r--r--o--w--s
# |  |  |  |  |--z--e--s
# |  |  |  |--r--e
# |  |  |  |  |--e--u--p--o--n
# |  |  |  |  |  |--v--e--r
# |  |  |--i--c--h
# |  |  |  |  |--k--e--r
# |  |  |  |--l--e
# |  |  |  |--n--e--r--s
# |  |  |  |--p--s--a--w
# |  |  |  |--s--k--e--y--s
# |  |  |  |  |--t--o--n
# |  |  |  |--t--e--h--a--i--r
# |  |  |  |  |  |--n--e--r
# |  |  |  |  |--f--i--l--l
# |  |  |  |  |--m--i--r--e
# |  |  |  |  |--t--e--n--b--u--r--g
# |  |  |  |--z--z--e--s
# |  |  |--o--l--e
# |  |  |  |  |--e--s--a--l--e--r
# |  |  |  |--o--s--h
# |  |  |  |--s--e
# |  |--i--t
# |  |  |--a--n--t
# |  |  |--c--k
# |  |  |  |--k--l--a--n--d--e--r
# |  |  |--d--e
# |  |  |  |--e--l--l
# |  |  |  |--m--a--r
# |  |  |--e--n
# |  |  |  |--b--o--l--d
# |  |  |  |--d--m--e--y--e--r
# |  |  |  |--s--b--a--d--e--n
# |  |  |--f--e
# |  |  |--g--e--n
# |  |  |  |--l--e
# |  |  |--l--d
# |  |  |  |--l
# |  |  |  |--a--n--d
# |  |  |  |--c--z--e--k
# |  |  |  |--d--e--s
# |  |  |  |--e--e--n
# |  |  |  |--h--e--l--m
# |  |  |  |--k--e--n--s
# |  |  |  |--l--a--b--e--l--l--e
# |  |  |  |  |--e--n
# |  |  |  |  |--h--o--i--t--e
# |  |  |  |  |--i--n--g--e--r
# |  |  |  |  |--o--w
# |  |  |  |--m--e--t--t--e
# |  |  |  |--t--h--e--w
# |  |  |--m--m--e--r
# |  |  |--n--b--u--s--h
# |  |  |  |--d--t
# |  |  |  |  |--e--r
# |  |  |  |  |--m--i--l--l--e--r
# |  |  |  |--e--r
# |  |  |  |--g--e--r--s
# |  |  |  |--i--n--g--e--r
# |  |  |  |--n--a--b--l--e
# |  |  |  |  |--o--w--e--d
# |  |  |  |--s--o--r
# |  |  |  |--t--e--r--t--i--m--e
# |  |  |--p--e--d
# |  |  |--r--i--n--g
# |  |  |--s--e
# |  |  |  |--z
# |  |  |  |--e--c--r--a--c--k
# |  |  |  |--h--e--d
# |  |  |  |--n--i--e--w--s--k--i
# |  |  |--t--h
# |  |  |  |--s
# |  |  |  |--z
# |  |  |  |--h--d--r--a--w--a--l
# |  |  |  |  |--h--o--l--d--s
# |  |  |  |  |--o--u--t
# |  |  |  |--n--e--s--s--e--s
# |  |  |  |--t--i--g
# |  |--n--e--k
# |  |--o--e--l--f--e--l
# |  |  |--j--a--h--n
# |  |  |--l--a
# |  |  |  |--f--e--n--s--c--h--m--i--d--t
# |  |  |  |--g--e--m--u--t--h
# |  |  |  |--l--m--a--n
# |  |  |  |--v--e--n
# |  |  |--m--a--n
# |  |  |  |--e--n
# |  |  |--n--d--r--a
# |  |  |  |--'--t
# |  |  |--o--d
# |  |  |  |--l
# |  |  |  |--d--s
# |  |  |  |  |--b--y
# |  |  |  |  |--e--n
# |  |  |  |  |--h--a--m--s
# |  |  |  |  |--m--a--c
# |  |  |  |  |--s--o--n
# |  |  |  |--l--m--a--n
# |  |  |  |--t--e--n
# |  |  |--r--d
# |  |  |  |--n
# |  |  |  |--d--s--t--a--r
# |  |  |  |--k--g--r--o--u--p
# |  |  |  |  |--r--o--o--m
# |  |  |  |--l--d--l--y
# |  |  |  |--s--h--i--p
# |  |  |  |--t--h--i--e--r
# |  |  |--t--t--o--n
# |  |  |--u--l--d
# |  |  |--z--n--i--a--k
# |  |--r--a--p--p--i--n--g
# |  |  |--e--n--c--h
# |  |  |--i--g--h--t--s
# |  |  |  |--t--e--d--o--w--n
# |  |  |--o--n--a
# |  |  |--y--e
# |  |--u--n--d--e--r
# |  |  |--r--z--e--r
# |  |--y--d--e--n
# |  |  |--l--e--s
# |  |  |--n--o--n--a
# |
# |--x--.
# |  |--e--r--o--x
# |  |--i--n--h--u--a
# |  |--y--l--o--p--h--o--n--e
# |
# |--y--a--n
# |  |  |--c--h--t--s--m--a--n
# |  |  |--d--a--v--a
# |  |  |--h--o--o
# |  |  |--k--s--h--a
# |  |  |--m--a--g--a--t--a
# |  |  |--n--k
# |  |  |  |--o--f--s--k--y
# |  |  |--r--d
# |  |  |  |--o--s--h
# |  |  |--s--u--n--o--r--i
# |  |  |--w--n--s
# |  |--e--a--k--e--y
# |  |  |  |--r--l--y
# |  |  |  |--t--t--s
# |  |  |--l--l
# |  |  |  |--t--s--i--n--'--s
# |  |  |--r--b--y
# |  |  |--s--t--e--r--y--e--a--r
# |  |--i--e--l--d
# |  |--n--j--i--u--n
# |  |--o--u
# |  |  |--e--s--t
# |  |  |--k--l--e--y
# |  |  |--n--d--e--r
# |  |  |--r--b--a
# |  |  |--s--h--i--a--k--i
# |  |  |--u--r
# |  |  |  |--n--g
# |  |  |  |  |--g--e
# |  |  |  |  |--k--i--n
# |  |  |  |--r--s--e--l--f
# |  |  |  |--t--s--e--y
# |  |--u--c--k
# |  |  |--d--h--i--s--h--t--i--r--a
# |  |  |--k--o--n
# |  |  |--p--p--i--e--s
# |  |  |--t--z--y
# |
# |--z--a--b--o--w--s
# |  |  |--c--h--m--a--n
# |  |  |--f--t--i--g--'--s
# |  |  |--h--n--i--s--e--r
# |  |  |--j--d--e--l
# |  |  |--l--e--y--'--s
# |  |  |--m--o--r--a
# |  |  |--n--g--a--r--i
# |  |  |--p--a--t--i--s--t--a
# |  |  |--r--a--t--e
# |  |  |  |--t--m--a--n
# |  |  |--w--a--c--k--i
# |  |--e--h
# |  |  |--a--l--a--n--d
# |  |  |--c--k--e--n--d--o--r--f
# |  |  |--i--n--e--r
# |  |  |--l--e
# |  |  |  |--l--e--r--b--a--c--h
# |  |  |--m--e--c--k--i--s
# |  |  |--n--i--t--h
# |  |  |--p--e--d--a
# |  |  |--r--o--s
# |  |--h--a--o
# |  |--i--c--k--e--f--o--o--s--e
# |  |  |--e--m--e--r
# |  |  |--g--l--e--r
# |  |  |--l--l--i--o--n--s
# |  |  |--m--n--y
# |  |  |--n--n
# |  |  |--p--f--e--l
# |  |  |--r--c--o--n--s
# |  |  |--y--a--d
# |  |--o--e--l--l--e--r
# |  |  |--l--p
# |  |  |--o--m--s
# |  |  |--s--s
# |  |--u--c--c--h--i--n--i
# |  |  |--g--a--n--o--v--'--s
# |  |  |--m--m--o
# |  |  |--r--i--c--h--'--s
# |  |--w--i--c--k--y
# |  |--y--u--g--a--n--o--v--'--s

# %% [markdown]
# # spell checker的定义

# %%
import numpy as np
import copy
class SpellChecker:
    def __init__(self,beam,longest_word_lenth=45,tolerate_num_of_error=2):
        self.beam = int(beam)
        self.lextree=None
        self.dist_fun=lambda *args: int(args[0] != args[1])
        self.longest_word_lenth=longest_word_lenth
        self.tolerate_num_of_error=tolerate_num_of_error

    def fit(self,lextree):
        self.lextree=lextree
        assert type(self.lextree) is LexNode
        self.nodes = []
        self.get_nodes(self.lextree)
        # get self.transitions
        self.transitions = {}
        self.get_children={}
        to_children={}
        n_nodes = len(self.nodes)
        self.word_ends = []
        # record the end idx of each words, therefore, at the end of the vertibe , we can get the costs of each word
        for i in range(n_nodes):
            n = self.nodes[i]
            #print(str(i)+"    "+n.val)
            if n.property == 2:
                self.word_ends.append(i)
            self.get_children[i]=[]
            # add transition if there is any. to get the parent node of current node
            if len(n.children) > 0:
                for child in n.children:
                    self.get_children[i].append(self.nodes.index(child))
                    self.transitions[self.nodes.index(child)] = i
        self.transitions[0]=0 # "start point repeating"
        #print(self.word_ends)

    def mute_nodes(self,r):
        self.muted_nodes[r]=1
        #mute it children
        to_mute_children=self.get_children[r]
        #print(to_mute_children)
        if len(to_mute_children)!=0:
            for child_idx in to_mute_children:
                if child_idx!=0:
                    self.mute_nodes(child_idx)
                
    def get_nodes(self, lexnode):
        self.nodes.append(lexnode)
        if lexnode.property==2:
            return
        for child in lexnode.children:
            self.get_nodes(child)
    
    def text_vertibe(self,x,longest=True,get_string=True):
        #initialize the input x by adding "*" at the beginning of x. 
        x = '*' + x
        # initialize cost matrix
        n_cols = len(x)
        n_rows = len(self.nodes)
        costs = np.full((n_rows, n_cols), np.inf)
        costs[0,:]=range(n_cols)
        
        n_nodes = len(self.nodes)
        self.muted_nodes=np.zeros([n_nodes])

        # fill cost matrix
        for c in range(n_cols):
            for r in range(1,n_rows):
                if not self.muted_nodes[r]:
                    current_cost=self.dist_fun(self.nodes[r].val,x[c])
                    if c==0:#if it is the initialization.
                        if self.transitions[r]==0:
                            costs[r,c]=current_cost
                        else:
                            #if it is the middle nodes, then the cost is based on it previous node
                            costs[r,c]=costs[self.transitions[r],c]+current_cost
                    elif c==1:
                        if current_cost==0:
                            to_check=[costs[r,c-1]+1, # repeat the node from previous state
                                      costs[self.transitions[r],c-1],#get the node from previous state
                                     ] 
                        else:
                            to_check=[costs[r,c-1], # repeat the node from previous state
                                      costs[self.transitions[r],c-1],#get the node from previous state
                                     ] 
                        nnn=np.argmin(to_check)
                        costs[r,c]=to_check[nnn]+current_cost
                    else:
                        if current_cost==0:
                            to_check=[costs[r,c-1]+1, # repeat the node from previous state
                                      costs[self.transitions[r],c-1],#get the node from previous state
                                      costs[self.transitions[r],c-2]+1 # the c-1 is assumed as the insertion
                                     ]
                        else:
                            #that means they are different
                            to_check=[costs[r,c-1], # repeat the node from previous state
                                      costs[self.transitions[r],c-1],#get the node from previous state
                                      costs[self.transitions[r],c],#update from current state previous node
                                      costs[self.transitions[r],c-2]+1 # the c-1 is assumed as the insertion
                                     ]
                        nnn=np.argmin(to_check)
                        costs[r,c]=to_check[nnn]+current_cost


                    if costs[r,c]>=self.tolerate_num_of_error+len(x):
                        self.mute_nodes(r)
            #print(costs[:25,c])
        
        
        #find the minimum cost at the end of each word
        costs_for_words=[]
        for end_idx in self.word_ends:
            costs_for_words.append(costs[end_idx,-1])
        #print(costs_for_words[0:40])
        
        min_cost=min(costs_for_words)
        #print(min_cost)
        #get the index of minimum cost
        min_idxs=np.where(costs_for_words==min_cost)[0]
        #print(min_idxs)
        if get_string:
            result=self.nodes_to_word(min_idxs,longest=longest)
            return result
        else:
            return min_idxs, min_cost
    
    def nodes_to_word(self,nodes,longest=True):
        results=[]
        for idx in nodes:
            #get the real index of the end of the word
            idx=self.word_ends[idx]
            #if the min cost is the real end node, then we can get a real word
            result=""
            while self.transitions[idx]!=0:
                result=self.nodes[idx].val+result
                #print(self.nodes[idx].val)
                idx=self.transitions[idx]
            result=self.nodes[idx].val+result
            results.append(result)
            #print(results)
        if longest:
            #return the longest word in the candidate
            res = max(results, key=len, default='')
            return res
        return results
    
    
    def get_nodes_from_token(self,tokens,end_token):
        nodes=[]
        time=tokens[0]
        value=tokens[1]
        previous=tokens[2]
        previous_time=end_token[-1]
        nodes.append(end_token[1])
        while previous_time!=0:
            idxs=np.where(time==previous_time)[0]
            previous_time=previous[idxs[0]]
            nodes.insert(0,value[idxs[0]])
        return nodes
    
    def nodes_to_sentence(self,nodes):
        '''
        input [0,1,2]
        ouput a an ann
        '''
        sentence=""
        for idx in nodes:
            #if the min cost is the real end node, then we can get a real word
            result=""
            while self.transitions[idx]!=0:
                result=self.nodes[idx].val+result
                #print(self.nodes[idx].val)
                idx=self.transitions[idx]
            result=self.nodes[idx].val+result
            sentence+=result+" "
        
        return  sentence
    
    
    def nodes_list_to_sentences(self,nodes_list):
        words_list=self.nodes_list_to_words(nodes_list)
        num_words_in_each_words_list=list(map(len, words_list))
        num_possible_sentences=np.product(num_words_in_each_words_list)
        print("there are {} possible sentences".format(num_possible_sentences))
        padded_words_list=[]
        for words in words_list:
            if len(words)==0:
                continue
            repeat_time=int(num_possible_sentences/len(words))
            aaa_words_list=[]
            for i in range(repeat_time):
                aaa_words_list+=words
            padded_words_list.append(aaa_words_list)
        #print(padded_words_list)
        
        padded_words_list=np.array(padded_words_list)
        padded_words_list=np.column_stack(padded_words_list)
        sentences=[]
        for i in padded_words_list:
            sentence=""
            for word in i:
                sentence+=word +" "
            sentences.append(sentence)
        
        return sentences
    
    
    
    
    def nodes_list_to_words(self,nodes_list):
        '''
        input [[0],[],[1,2],[2]]
        ouput [["a"],["an", "ann"],["ann"]]
        '''
        all_words=[]
        for current_word_idxs in nodes_list:
            if len(current_word_idxs)==0:
                continue
            else:
                current_words=[]
                for idx in current_word_idxs:
                    #if the min cost is the real end node, then we can get a real word
                    result=""
                    while self.transitions[idx]!=0:
                        result=self.nodes[idx].val+result
                        #print(self.nodes[idx].val)
                        idx=self.transitions[idx]
                    result=self.nodes[idx].val+result
                    current_words.append(result)
                all_words.append(current_words)
        #print(all_words)
        return all_words
    
    def check_end_of_words(self,costs):
        costs_for_words=[]
        for end_idx in self.word_ends:
            costs_for_words.append(costs[end_idx])
        min_cost=min(costs_for_words)
#         print("minimum cost at this point is")
#         print(min_cost)
        #get the index of minimum cost
        min_idxs=np.where(costs_for_words==min_cost)[0]
        # delete the "*" where its cost is always 0
        min_idxs = min_idxs[min_idxs != 0]
        return min_cost,min_idxs
  
    def unsegment_text_vertibe(self,x,longest=True,n_best=10,get_sentence=True,loop_cost=0.002):
        #set different types of cost
        deletion_cost = 1.0
        self.diagonal_cost= 1.0 # 如果单词不符合就会是这样哦
        insertion_cost = 1.0
        match_cost = 0.0
        space_cost = 0.0
        loop_cost = loop_cost
        
        self.n_best=n_best
        # initialize cost matrix
        n_cols = len(x)
        n_rows = len(self.nodes)
        costs = np.full(n_rows, np.inf)
        # * to all other nodes
        initial_cost=np.zeros(n_rows)
        for r in range(n_rows):
            current_cost=1
            if self.transitions[r]==0:
                initial_cost[r]=current_cost
            else:
                #if it is the middle nodes, then the cost is based on it previous node
                initial_cost[r]=initial_cost[self.transitions[r]]+current_cost
        initial_cost[0]=0
        #print(initial_cost)
        #we allow one insertion and one deletion in each word
        initial_nodes=self.get_children[0]
        next_to_check_nodes=[]
        for node in initial_nodes:
            next_to_check_nodes.append(node)
            next_to_check_nodes+=self.get_children[node]
        # we allow the deletion. therefore, each time, we update the current node and its child node
        initial_nodes=next_to_check_nodes
        
        
#         print("initial to check nodes are ")
#         print(initial_nodes)
        y_level=[]
        y_level.append(initial_nodes)
        result_level=[[]]
        
        z_level=[]
        z_level.append(copy.deepcopy(initial_cost))
        # fill cost matrix
        for c in range(n_cols):
            next_result_level=[]
            next_z_level=[]
            next_y_level=[]
           
            next_result_level_filtered=[]
            next_z_level_filtered=[]
            next_y_level_filtered=[]
            
            temp_min_cost_level=[]
            
            #here, Huangrui get the num_nodes in each path
            num_nodes_in_each_path=list(map(len, result_level))
            #print("num of nodes in current sentences in  each path is {}".format(num_nodes_in_each_path))
            #here is the mean of the num_nodes_in_each_path
            mean_num_nodes=int(np.median(num_nodes_in_each_path))
            #print("median num of nodes in current sentences in  each path is {}".format(mean_num_nodes))
            
            print("dealing with the {} th input character".format(c+1))
            #here, Huangrui get the num_nodes in each path
            num_nodes_in_each_path=list(map(len, result_level))
            #print("num of nodes in current sentences in  each path is {}".format(num_nodes_in_each_path))
            #here is the mean of the num_nodes_in_each_path
            mean_num_nodes=int(np.median(num_nodes_in_each_path))
            #print("median num of nodes in current sentences in  each path is {}".format(mean_num_nodes))
            for current_possible_choice in range(len(z_level)):
                next_to_check_nodes=[]
                current_nodes=y_level[current_possible_choice]
                #print(current_nodes)
                z_column=z_level[current_possible_choice]
                current_result=result_level[current_possible_choice]
                temp_cost_column=copy.deepcopy(costs)
                
                #Huangrui try pruning here, basicly  for a sentence, i want some words
                #so i would compare the current "words count" of "each sentence"
            
                for r in current_nodes:
                    #print("updating {} th node ".format(r))
                    next_to_check_nodes+=self.get_children[r]
                    if self.nodes[r].val==x[c]:
                        diagonal_cost=match_cost
                    else:
                        diagonal_cost=self.diagonal_cost
                        
                    #print("current diagonal_cost is {}".format(diagonal_cost))
                    to_check=[z_column[r]+ insertion_cost, # 从左往右 相当于insertion 
                             z_column[self.transitions[r]]+diagonal_cost,#斜对角 
                             temp_cost_column[self.transitions[r]]+deletion_cost#there is a deletion of previous charactor
                            ]
                    #先更新所有的点的cost
                    temp_cost_column[r]= min(to_check)
                    
                #check the end of the words after each updata
                min_cost=min(temp_cost_column[self.word_ends])
                #print(min_cost)
                temp_min_cost_level.append(min_cost)
                #print(temp_min_cost_level)
                next_result_level.append(current_result)
                next_z_level.append(temp_cost_column)                
                next_y_level.append(sorted(list(set(next_to_check_nodes)),reverse=False))
            #print("before filtering there are {} paths".format(len(next_z_level)))
            #now filtering the temp_min_cost
            sorted_temp_min_cost_level=sorted(temp_min_cost_level)
            if len(sorted_temp_min_cost_level)<self.n_best:
                upfloor_min_cost=sorted_temp_min_cost_level[-1]
            else:
                upfloor_min_cost=sorted_temp_min_cost_level[n_best-1]
            
            #print("temp_min_cost_level is {}".format(temp_min_cost_level))
#             print(len(next_y_level))
#             print(len(next_z_level))
            global_min_path_cost=min(temp_min_cost_level)
            print(global_min_path_cost)
            if c==n_cols-1:
                #print("at this point the results are {}".format(len(next_result_level_filtered)))
                for choice in range(len(temp_min_cost_level)):
                    current_min_cost=temp_min_cost_level[choice]
#                     print("reach the end")
#                     print(current_min_cost)
                    min_idxs=np.where(next_z_level[choice][self.word_ends]==current_min_cost)[0]
                    current_possible_words=[]
                    for end_idx in min_idxs:
                        end_idx=self.word_ends[end_idx]
                        current_possible_words.append(end_idx)   
#                     print(current_possible_words)
                    aaa_result=copy.deepcopy(next_result_level[choice])
                    aaa_result.append(current_possible_words)
                    next_z_level_filtered.append(aaa_initial_cost)
                    next_result_level_filtered.append(aaa_result)
                    continue
                #print("at this point the results are {}".format(len(next_result_level_filtered)))
            
            else:
                for choice in range(len(temp_min_cost_level)):
                    current_min_cost=temp_min_cost_level[choice]
                    if current_min_cost<=upfloor_min_cost:
                    #we need to prepare the "new path" here
                        if (current_min_cost<=self.tolerate_num_of_error*(mean_num_nodes+1)):
                            #we find possible new path:
#                            print("current_Min_cost is {}".format(current_min_cost))
#                             print(next_z_level[choice])
                            min_idxs=np.where(next_z_level[choice][self.word_ends]==current_min_cost)[0]
#                             print("current_min_idxs are {}".format(min_idxs))
                            current_possible_words=[]
                            for end_idx in min_idxs:
                                end_idx=self.word_ends[end_idx]
                                current_possible_words.append(end_idx)   
                            #print(current_possible_words)
                            aaa_result=copy.deepcopy(next_result_level[choice])
                            aaa_result.append(current_possible_words)
                            # now add the initial cost with min_cost and loop cost
                            aaa_initial_cost=copy.deepcopy(initial_cost)
                            aaa_initial_cost+=current_min_cost
                            aaa_initial_cost+=loop_cost
                            next_y_level_filtered.append(initial_nodes)
                            next_z_level_filtered.append(aaa_initial_cost)
                            next_result_level_filtered.append(aaa_result)


                        next_y_level_filtered.append(next_y_level[choice])
                        next_z_level_filtered.append(next_z_level[choice])
                        next_result_level_filtered.append(next_result_level[choice])
                     
            #print("after filtering there are {} paths".format(len(next_z_level_filtered)))  
            z_level=next_z_level_filtered
            y_level=next_y_level_filtered
            result_level=next_result_level_filtered

            #print(result_level)
            
        #now, we have reach the end of the input unsegmented sentence, let's review every sentence we could have
#         print("Huangrui has reach the end of the unsegmented sentence!")
#         print(temp_min_cost_level)
#         print(len(temp_min_cost_level))
#         print(len(result_level))
        min_sentence_cost=min(temp_min_cost_level)
#         print("minimum cost at this point is")
#         print(min_sentence_cost)
#         print()
        if get_sentence:
            sentences=[]
            final_results_node_list=[]
            #get the index of minimum cost
            min_sentence_idxs=np.where(temp_min_cost_level==min_sentence_cost)[0]
            for min_sentence_idx in min_sentence_idxs:
                #print(min_sentence_idx)
                result=result_level[min_sentence_idx]
                #print(result)
                final_results_node_list.append(result)
                if get_sentence:
                    current_sentence=self.nodes_list_to_sentences(result)
                    #print(current_sentence)
                    sentences.append(current_sentence)
                return sentences,final_results_node_list,min_sentence_cost
        else:
            return min_sentence_cost

# %% [markdown]
# # initialized the Spellchecker and load lextress to this Spellchecker

# %%
spellchecker=SpellChecker(3,longest_word_lenth=9,tolerate_num_of_error=2)
spellchecker.fit(lextree)

# %% [markdown]
# # Test spellchecker
#
# unsegment part, n_best means the beam, just the first n best path Huangrui has found
#
# for word correction, this version only use pruning because Huangrui prefers accuracy rather than time efficeincy

# %%
# x="axn"
# spellchecker.text_vertibe(x,True)

# %%
x="byhookorbycrooksherepliedhemustbecaughtifidon'tgethimishalldie"
sentences,final_results_node_list,min_sentence_cost=spellchecker.unsegment_text_vertibe(x,n_best=10)
# Out:
# dealing with the 1 th input character
# 1.0
# dealing with the 2 th input character
# 0.0
# dealing with the 3 th input character
# 1.0
# dealing with the 4 th input character
# 1.002
# dealing with the 5 th input character
# 1.002
# dealing with the 6 th input character
# 0.002
# dealing with the 7 th input character
# 0.004
# dealing with the 8 th input character
# 0.004
# dealing with the 9 th input character
# 1.004
# dealing with the 10 th input character
# 0.006
# dealing with the 11 th input character
# 1.006
# dealing with the 12 th input character
# 1.008
# dealing with the 13 th input character
# 0.008
# dealing with the 14 th input character
# 0.01
# dealing with the 15 th input character
# 0.008
# dealing with the 16 th input character
# 1.008
# dealing with the 17 th input character
# 1.01
# dealing with the 18 th input character
# 0.01
# dealing with the 19 th input character
# 1.01
# dealing with the 20 th input character
# 1.01
# dealing with the 21 th input character
# 1.012
# dealing with the 22 th input character
# 2.012
# dealing with the 23 th input character
# 2.014
# dealing with the 24 th input character
# 2.0140000000000002
# dealing with the 25 th input character
# 2.014
# dealing with the 26 th input character
# 3.014
# dealing with the 27 th input character
# 2.0159999999999996
# dealing with the 28 th input character
# 3.0159999999999996
# dealing with the 29 th input character
# 3.0179999999999993
# dealing with the 30 th input character
# 3.0159999999999996
# dealing with the 31 th input character
# 2.0179999999999993
# dealing with the 32 th input character
# 3.0179999999999993
# dealing with the 33 th input character
# 2.019999999999999
# dealing with the 34 th input character
# 3.019999999999999
# dealing with the 35 th input character
# 3.021999999999999
# dealing with the 36 th input character
# 3.021999999999999
# dealing with the 37 th input character
# 4.02
# dealing with the 38 th input character
# 3.021999999999999
# dealing with the 39 th input character
# 2.021999999999999
# dealing with the 40 th input character
# 2.0239999999999987
# dealing with the 41 th input character
# 2.0239999999999987
# dealing with the 42 th input character
# 2.0259999999999985
# dealing with the 43 th input character
# 3.0239999999999987
# dealing with the 44 th input character
# 2.0279999999999982
# dealing with the 45 th input character
# 3.0259999999999985
# dealing with the 46 th input character
# 3.0279999999999982
# dealing with the 47 th input character
# 2.0279999999999982
# dealing with the 48 th input character
# 3.0279999999999982
# dealing with the 49 th input character
# 3.029999999999998
# dealing with the 50 th input character
# 2.029999999999998
# dealing with the 51 th input character
# 3.029999999999998
# dealing with the 52 th input character
# 3.029999999999998
# dealing with the 53 th input character
# 2.031999999999998
# dealing with the 54 th input character
# 2.0339999999999976
# dealing with the 55 th input character
# 2.0339999999999976
# dealing with the 56 th input character
# 3.0339999999999976
# dealing with the 57 th input character
# 3.0359999999999974
# dealing with the 58 th input character
# 3.0359999999999974
# dealing with the 59 th input character
# 2.0359999999999974
# dealing with the 60 th input character
# 3.0359999999999974
# dealing with the 61 th input character
# 3.037999999999997
# dealing with the 62 th input character
# 2.037999999999997
# there are 2 possible sentences

# %%
min_sentence_cost

# %%
sentences[0][1]
# Out:
# "by hook or by crook she rev flied he must be caught if i don't get him i shall die "

# %% [markdown]
# # read  typo.txt and correc the word

# %%
# file=open("typos.txt","r").readlines()
# sentences=[]
# for sentence in file:
#     words=sentence.strip('\n').split(" ")
#     if len(words)==1:
#         #which means it is an empty line
#         continue
#     corrected_sentence=""
#     for word in words:
#         corrected_word=spellchecker.text_vertibe(word)
#         print(corrected_word)
#         corrected_sentence+=corrected_word+" "
#     print(corrected_sentence)
#     sentences.append(corrected_sentence)

# %% [markdown]
# # For Problem 1 accuracy please refer to another note book

# %%
# file=open("segmented.txt","r").readlines()
# correct_seg=[]
# for sentence in file:
#     words=sentence.strip('\n').split(" ")
#     if len(words)==1:
#         #which means it is an empty line
#         continue
#     for word in words:
#         correct_seg.append(word)




# def accuracy_cal(result, correct_seg):
#     result = result.split()
#     d1 = abs(len(result) - len(correct_seg))
#     d2 = 0
#     for i in result:
#         if i not in correct_seg:
#             d2 += 1
#     return d1 + d2
# accuracy = accuracy_cal(result, correct_seg)
# print("accuracy: ", accuracy)
# accuracy_lst.append(accuracy)

# %% [markdown]
# # Read the unsegmented0.txt and segment it

# %%
n_best=10

file=open("unsegmented0.txt","r").readlines()
total_cost=0
for sentence in file:
    sentence=sentence.strip('\n')
    min_sentence_cost=spellchecker.unsegment_text_vertibe(sentence,n_best=n_best,get_sentence=False,loop_cost=0.00001)
    print("the min cost for this sentence is {}".format(min_sentence_cost))
    total_cost+=min_sentence_cost
print("Over all cost for this file with n_best equal to {} is {}".format(n_best,total_cost))
# Out:
# dealing with the 1 th input character
# 0.0
# dealing with the 2 th input character
# 0.0
# dealing with the 3 th input character
# 1.0
# dealing with the 4 th input character
# 0.0
# dealing with the 5 th input character
# 1.0
# dealing with the 6 th input character
# 1e-05
# dealing with the 7 th input character
# 2e-05
# dealing with the 8 th input character
# 1e-05
# dealing with the 9 th input character
# 2e-05
# dealing with the 10 th input character
# 2e-05
# dealing with the 11 th input character
# 3.0000000000000004e-05
# dealing with the 12 th input character
# 1.00003
# dealing with the 13 th input character
# 3.0000000000000004e-05
# dealing with the 14 th input character
# 4e-05
# dealing with the 15 th input character
# 1.00004
# dealing with the 16 th input character
# 1.00004
# dealing with the 17 th input character
# 1.00004
# dealing with the 18 th input character
# 4e-05
# dealing with the 19 th input character
# 1.00004
# dealing with the 20 th input character
# 1.00005
# dealing with the 21 th input character
# 5e-05
# dealing with the 22 th input character
# 1.00005
# dealing with the 23 th input character
# 1.00006
# dealing with the 24 th input character
# 1.00006
# dealing with the 25 th input character
# 1.00006
# dealing with the 26 th input character
# 1.00007
# dealing with the 27 th input character
# 1.00007
# dealing with the 28 th input character
# 2.00007
# dealing with the 29 th input character
# 2.00007
# dealing with the 30 th input character
# 2.00008
# dealing with the 31 th input character
# 2.00009
# dealing with the 32 th input character
# 2.00008
# dealing with the 33 th input character
# 2.00009
# dealing with the 34 th input character
# 2.0001
# dealing with the 35 th input character
# 2.0001
# dealing with the 36 th input character
# 2.00009
# dealing with the 37 th input character
# 2.0001
# dealing with the 38 th input character
# 2.0001
# dealing with the 39 th input character
# 3.0001
# dealing with the 40 th input character
# 2.0001100000000003
# dealing with the 41 th input character
# 3.0001100000000003
# dealing with the 42 th input character
# 3.0001200000000003
# dealing with the 43 th input character
# 3.0001100000000003
# dealing with the 44 th input character
# 3.0001100000000003
# dealing with the 45 th input character
# 2.0001100000000003
# dealing with the 46 th input character
# 3.0001100000000003
# dealing with the 47 th input character
# 3.0001200000000003
# dealing with the 48 th input character
# 2.0001200000000003
# dealing with the 49 th input character
# 3.0001200000000003
# dealing with the 50 th input character
# 3.0001300000000004
# dealing with the 51 th input character
# 3.0001300000000004
# dealing with the 52 th input character
# 3.0001300000000004
# dealing with the 53 th input character
# 3.0001400000000005
# dealing with the 54 th input character
# 3.0001400000000005
# dealing with the 55 th input character
# 3.0001500000000005
# dealing with the 56 th input character
# 3.0001500000000005
# dealing with the 57 th input character
# 4.00014
# dealing with the 58 th input character
# 4.00015
# dealing with the 59 th input character
# 4.0001500000000005
# dealing with the 60 th input character
# 4.0001500000000005
# dealing with the 61 th input character
# 4.00016
# dealing with the 62 th input character
# 4.00017
# dealing with the 63 th input character
# 5.00016
# dealing with the 64 th input character
# 5.00017
# dealing with the 65 th input character
# 6.00017
# dealing with the 66 th input character
# 6.00017
# dealing with the 67 th input character
# 7.00017
# dealing with the 68 th input character
# 6.00017
# dealing with the 69 th input character
# 6.000179999999999
# dealing with the 70 th input character
# 6.000179999999999
# dealing with the 71 th input character
# 7.000179999999999
# dealing with the 72 th input character
# 7.000189999999999
# dealing with the 73 th input character
# 6.000189999999999
# dealing with the 74 th input character
# 7.000189999999999
# dealing with the 75 th input character
# 7.000199999999999
# dealing with the 76 th input character
# 7.000199999999999
# dealing with the 77 th input character
# 6.000199999999999
# dealing with the 78 th input character
# 6.000209999999998
# dealing with the 79 th input character
# 6.000209999999998
# dealing with the 80 th input character
# 7.000209999999998
# dealing with the 81 th input character
# 7.000219999999998
# dealing with the 82 th input character
# 6.000219999999998
# dealing with the 83 th input character
# 7.000219999999998
# dealing with the 84 th input character
# 7.0002299999999975
# dealing with the 85 th input character
# 6.0002299999999975
# dealing with the 86 th input character
# 6.000239999999997
# dealing with the 87 th input character
# 7.000239999999997
# dealing with the 88 th input character
# 7.000239999999997
# dealing with the 89 th input character
# 7.000239999999997
# dealing with the 90 th input character
# 7.000249999999997
# dealing with the 91 th input character
# 7.000249999999997
# dealing with the 92 th input character
# 7.000259999999996
# dealing with the 93 th input character
# 7.000259999999996
# dealing with the 94 th input character
# 7.000269999999996
# dealing with the 95 th input character
# 7.000269999999996
# dealing with the 96 th input character
# 7.000279999999996
# dealing with the 97 th input character
# 7.000279999999996
# dealing with the 98 th input character
# 8.000279999999997
# dealing with the 99 th input character
# 8.000279999999997
# dealing with the 100 th input character
# 8.000279999999997
# dealing with the 101 th input character
# 9.000279999999997
# dealing with the 102 th input character
# 9.000289999999996
# dealing with the 103 th input character
# 10.000289999999996
# dealing with the 104 th input character
# 10.000289999999996
# dealing with the 105 th input character
# 10.000299999999996
# dealing with the 106 th input character
# 11.000299999999996
# dealing with the 107 th input character
# 11.000299999999996
# dealing with the 108 th input character
# 11.000299999999996
# dealing with the 109 th input character
# 12.000299999999996
# dealing with the 110 th input character
# 12.000309999999995
# dealing with the 111 th input character
# 12.000309999999995
# dealing with the 112 th input character
# 13.000309999999995
# dealing with the 113 th input character
# 13.000319999999995
# dealing with the 114 th input character
# 13.000319999999995
# dealing with the 115 th input character
# 13.000319999999995
# dealing with the 116 th input character
# 14.000319999999995
# dealing with the 117 th input character
# 15.000319999999995
# dealing with the 118 th input character
# 16.000319999999995
# dealing with the 119 th input character
# 16.000319999999995
# dealing with the 120 th input character
# 16.000319999999995
# dealing with the 121 th input character
# 16.000319999999995
# dealing with the 122 th input character
# 17.000319999999995
# dealing with the 123 th input character
# 17.000329999999995
# dealing with the 124 th input character
# 18.000329999999995
# dealing with the 125 th input character
# 17.000329999999995
# dealing with the 126 th input character
# 18.000329999999995
# dealing with the 127 th input character
# 19.000329999999995
# dealing with the 128 th input character
# 20.000329999999995
# dealing with the 129 th input character
# 20.000329999999995
# dealing with the 130 th input character
# 21.000329999999995
# dealing with the 131 th input character
# 21.000329999999995
# dealing with the 132 th input character
# 22.000329999999995
# dealing with the 133 th input character
# 22.000339999999994
# dealing with the 134 th input character
# 23.000339999999994
# dealing with the 135 th input character
# 23.000339999999994
# dealing with the 136 th input character
# 24.000339999999994
# dealing with the 137 th input character
# 24.000339999999994
# dealing with the 138 th input character
# 25.000339999999994
# dealing with the 139 th input character
# 25.000349999999994
# dealing with the 140 th input character
# 25.000359999999993
# dealing with the 141 th input character
# 25.000359999999993
# dealing with the 142 th input character
# 25.000359999999993
# dealing with the 143 th input character
# 26.000359999999993
# dealing with the 144 th input character
# 26.000369999999993
# dealing with the 145 th input character
# 27.000369999999993
# dealing with the 146 th input character
# 27.000369999999993
# dealing with the 147 th input character
# 27.000369999999993
# dealing with the 148 th input character
# 28.000369999999993
# dealing with the 149 th input character
# 29.000369999999993
# dealing with the 150 th input character
# 29.000369999999993
# dealing with the 151 th input character
# 30.000369999999993
# dealing with the 152 th input character
# 31.000369999999993
# dealing with the 153 th input character
# 31.000369999999993
# dealing with the 154 th input character
# 32.00036999999999
# dealing with the 155 th input character
# 32.00037999999999
# dealing with the 156 th input character
# 32.000389999999996
# dealing with the 157 th input character
# 32.000389999999996
# dealing with the 158 th input character
# 33.000389999999996
# dealing with the 159 th input character
# 34.000389999999996
# dealing with the 160 th input character
# 33.000389999999996
# dealing with the 161 th input character
# 33.000389999999996
# dealing with the 162 th input character
# 33.0004
# dealing with the 163 th input character
# 34.0004
# dealing with the 164 th input character
# 34.0004
# dealing with the 165 th input character
# 34.0004
# dealing with the 166 th input character
# 35.0004
# dealing with the 167 th input character
# 35.00041
# dealing with the 168 th input character
# 35.00041
# dealing with the 169 th input character
# 36.00041
# dealing with the 170 th input character
# 36.00041
# dealing with the 171 th input character
# 36.00041
# dealing with the 172 th input character
# 36.000420000000005
# dealing with the 173 th input character
# 36.000420000000005
# dealing with the 174 th input character
# 36.00043000000001
# dealing with the 175 th input character
# 37.00043000000001
# dealing with the 176 th input character
# 37.00044000000001
# dealing with the 177 th input character
# 37.00044000000001
# dealing with the 178 th input character
# 37.000450000000015
# dealing with the 179 th input character
# 38.000450000000015
# dealing with the 180 th input character
# 38.000450000000015
# dealing with the 181 th input character
# 38.000450000000015
# dealing with the 182 th input character
# 38.00046000000002
# dealing with the 183 th input character
# 39.00046000000002
# dealing with the 184 th input character
# 39.00046000000002
# dealing with the 185 th input character
# 39.00046000000002
# dealing with the 186 th input character
# 40.00046000000002
# dealing with the 187 th input character
# 40.00047000000002
# dealing with the 188 th input character
# 41.00047000000002
# dealing with the 189 th input character
# 41.00047000000002
# dealing with the 190 th input character
# 42.00047000000002
# dealing with the 191 th input character
# 42.00047000000002
# dealing with the 192 th input character
# 42.00047000000002
# dealing with the 193 th input character
# 42.000480000000024
# dealing with the 194 th input character
# 42.000480000000024
# dealing with the 195 th input character
# 43.000480000000024
# dealing with the 196 th input character
# 43.00049000000003
# dealing with the 197 th input character
# 44.00049000000003
# dealing with the 198 th input character
# 44.00049000000003
# dealing with the 199 th input character
# 44.00049000000003
# dealing with the 200 th input character
# 45.00049000000003
# dealing with the 201 th input character
# 45.00049000000003
# dealing with the 202 th input character
# 45.00049000000003
# dealing with the 203 th input character
# 45.00050000000003
# dealing with the 204 th input character
# 46.00050000000003
# dealing with the 205 th input character
# 46.00050000000003
# dealing with the 206 th input character
# 46.00050000000003
# dealing with the 207 th input character
# 46.000510000000034
# dealing with the 208 th input character
# 47.000510000000034
# dealing with the 209 th input character
# 47.000510000000034
# dealing with the 210 th input character
# 47.000510000000034
# dealing with the 211 th input character
# 47.000510000000034
# dealing with the 212 th input character
# 47.00052000000004
# dealing with the 213 th input character
# 48.00052000000004
# dealing with the 214 th input character
# 48.00053000000004
# dealing with the 215 th input character
# 49.00053000000004
# dealing with the 216 th input character
# 49.00053000000004
# dealing with the 217 th input character
# 49.00053000000004
# dealing with the 218 th input character
# 50.00053000000004
# dealing with the 219 th input character
# 50.00054000000004
# dealing with the 220 th input character
# 51.00054000000004
# dealing with the 221 th input character
# 51.00054000000004
# dealing with the 222 th input character
# 51.00055000000005
# dealing with the 223 th input character
# 51.00055000000005
# dealing with the 224 th input character
# 51.00055000000005
# dealing with the 225 th input character
# 51.00056000000005
# dealing with the 226 th input character
# 51.00056000000005
# dealing with the 227 th input character
# 52.00056000000005
# dealing with the 228 th input character
# 52.00056000000005
# dealing with the 229 th input character
# 52.00056000000005
# dealing with the 230 th input character
# 53.00056000000005
# dealing with the 231 th input character
# 53.00057000000005
# dealing with the 232 th input character
# 53.00057000000005
# dealing with the 233 th input character
# 54.00057000000005
# dealing with the 234 th input character
# 54.00057000000005
# dealing with the 235 th input character
# 54.00057000000005
# dealing with the 236 th input character
# 55.00057000000005
# dealing with the 237 th input character
# 56.00057000000005
# dealing with the 238 th input character
# 56.00057000000005
# dealing with the 239 th input character
# 56.00057000000005
# dealing with the 240 th input character
# 57.00057000000005
# dealing with the 241 th input character
# 57.000580000000056
# dealing with the 242 th input character
# 58.000580000000056
# dealing with the 243 th input character
# 58.00059000000006
# dealing with the 244 th input character
# 59.00059000000006
# dealing with the 245 th input character
# 59.00060000000006
# dealing with the 246 th input character
# 60.00060000000006
# dealing with the 247 th input character
# 60.00060000000006
# dealing with the 248 th input character
# 61.00060000000006
# dealing with the 249 th input character
# 61.00060000000006
# dealing with the 250 th input character
# 62.00060000000006
# dealing with the 251 th input character
# 62.00060000000006
# dealing with the 252 th input character
# 63.00060000000006
# dealing with the 253 th input character
# 63.00060000000006
# dealing with the 254 th input character
# 63.00060000000006
# dealing with the 255 th input character
# 63.000610000000066
# dealing with the 256 th input character
# 64.00061000000007
# dealing with the 257 th input character
# 64.00061000000007
# dealing with the 258 th input character
# 65.00061000000007
# dealing with the 259 th input character
# 65.00061000000007
# dealing with the 260 th input character
# 65.00061000000007
# dealing with the 261 th input character
# 65.00061000000007
# dealing with the 262 th input character
# 65.00062000000007
# dealing with the 263 th input character
# 65.00063000000007
# dealing with the 264 th input character
# 65.00063000000007
# dealing with the 265 th input character
# 66.00063000000007
# dealing with the 266 th input character
# 67.00063000000007
# dealing with the 267 th input character
# 67.00064000000008
# dealing with the 268 th input character
# 67.00064000000008
# dealing with the 269 th input character
# 67.00065000000008
# dealing with the 270 th input character
# 67.00066000000008
# dealing with the 271 th input character
# 67.00066000000008
# dealing with the 272 th input character
# 68.00066000000008
# dealing with the 273 th input character
# 69.00066000000008
# dealing with the 274 th input character
# 68.00066000000008
# dealing with the 275 th input character
# 69.00066000000008
# dealing with the 276 th input character
# 69.00067000000008
# dealing with the 277 th input character
# 69.00067000000008
# dealing with the 278 th input character
# 70.00067000000008
# dealing with the 279 th input character
# 70.00067000000008
# dealing with the 280 th input character
# 70.00067000000008
# dealing with the 281 th input character
# 70.00068000000009
# dealing with the 282 th input character
# 70.00068000000009
# dealing with the 283 th input character
# 70.00068000000009
# dealing with the 284 th input character
# 71.00068000000009
# dealing with the 285 th input character
# 72.00068000000009
# dealing with the 286 th input character
# 72.00069000000009
# dealing with the 287 th input character
# 73.00069000000009
# dealing with the 288 th input character
# 73.00069000000009
# dealing with the 289 th input character
# 73.00069000000009
# dealing with the 290 th input character
# 73.00069000000009
# dealing with the 291 th input character
# 73.0007000000001
# dealing with the 292 th input character
# 73.0007100000001
# dealing with the 293 th input character
# 74.0007100000001
# dealing with the 294 th input character
# 74.0007100000001
# dealing with the 295 th input character
# 74.0007100000001
# dealing with the 296 th input character
# 74.0007100000001
# dealing with the 297 th input character
# 75.0007100000001
# dealing with the 298 th input character
# 75.0007200000001
# dealing with the 299 th input character
# 75.0007200000001
# dealing with the 300 th input character
# 76.0007200000001
# dealing with the 301 th input character
# 76.0007300000001
# dealing with the 302 th input character
# 76.0007300000001
# dealing with the 303 th input character
# 76.0007300000001
# dealing with the 304 th input character
# 77.0007300000001
# dealing with the 305 th input character
# 77.0007300000001
# dealing with the 306 th input character
# 77.0007400000001
# dealing with the 307 th input character
# 77.00075000000011
# dealing with the 308 th input character
# 77.00075000000011
# dealing with the 309 th input character
# 78.00075000000011
# dealing with the 310 th input character
# 78.00076000000011
# dealing with the 311 th input character
# 78.00076000000011
# dealing with the 312 th input character
# 79.00076000000011
# dealing with the 313 th input character
# 79.00076000000011
# dealing with the 314 th input character
# 79.00077000000012
# dealing with the 315 th input character
# 80.00077000000012
# dealing with the 316 th input character
# 80.00077000000012
# dealing with the 317 th input character
# 79.00077000000012
# dealing with the 318 th input character
# 79.00078000000012
# dealing with the 319 th input character
# 80.00078000000012
# dealing with the 320 th input character
# 80.00078000000012
# dealing with the 321 th input character
# 80.00078000000012
# dealing with the 322 th input character
# 81.00078000000012
# dealing with the 323 th input character
# 81.00078000000012
# dealing with the 324 th input character
# 81.00079000000012
# dealing with the 325 th input character
# 82.00079000000012
# dealing with the 326 th input character
# 82.00079000000012
# dealing with the 327 th input character
# 82.00079000000012
# dealing with the 328 th input character
# 83.00079000000012
# dealing with the 329 th input character
# 83.00080000000013
# dealing with the 330 th input character
# 84.00080000000013
# dealing with the 331 th input character
# 84.00080000000013
# dealing with the 332 th input character
# 84.00080000000013
# dealing with the 333 th input character
# 85.00080000000013
# dealing with the 334 th input character
# 85.00080000000013
# dealing with the 335 th input character
# 85.00080000000013
# dealing with the 336 th input character
# 85.00081000000013
# dealing with the 337 th input character
# 86.00081000000013
# dealing with the 338 th input character
# 86.00082000000013
# dealing with the 339 th input character
# 87.00082000000013
# dealing with the 340 th input character
# 87.00082000000013
# dealing with the 341 th input character
# 87.00082000000013
# dealing with the 342 th input character
# 87.00083000000014
# dealing with the 343 th input character
# 88.00083000000014
# dealing with the 344 th input character
# 88.00083000000014
# dealing with the 345 th input character
# 88.00083000000014
# dealing with the 346 th input character
# 88.00084000000014
# dealing with the 347 th input character
# 88.00085000000014
# dealing with the 348 th input character
# 88.00086000000015
# dealing with the 349 th input character
# 88.00086000000015
# dealing with the 350 th input character
# 89.00086000000015
# dealing with the 351 th input character
# 90.00086000000015
# dealing with the 352 th input character
# 90.00086000000015
# dealing with the 353 th input character
# 90.00086000000015
# dealing with the 354 th input character
# 90.00087000000015
# dealing with the 355 th input character
# 90.00088000000015
# dealing with the 356 th input character
# 91.00088000000015
# dealing with the 357 th input character
# 91.00088000000015
# dealing with the 358 th input character
# 91.00088000000015
# dealing with the 359 th input character
# 92.00088000000015
# dealing with the 360 th input character
# 93.00088000000015
# dealing with the 361 th input character
# 93.00088000000015
# dealing with the 362 th input character
# 93.00089000000015
# dealing with the 363 th input character
# 93.00089000000015
# dealing with the 364 th input character
# 94.00089000000015
# dealing with the 365 th input character
# 95.00089000000015
# dealing with the 366 th input character
# 95.00089000000015
# dealing with the 367 th input character
# 95.00089000000015
# dealing with the 368 th input character
# 95.00089000000015
# dealing with the 369 th input character
# 96.00089000000015
# dealing with the 370 th input character
# 96.00090000000016
# dealing with the 371 th input character
# 96.00090000000016
# dealing with the 372 th input character
# 96.00090000000016
# dealing with the 373 th input character
# 96.00091000000016
# dealing with the 374 th input character
# 96.00091000000016
# dealing with the 375 th input character
# 97.00091000000016
# dealing with the 376 th input character
# 98.00091000000016
# dealing with the 377 th input character
# 97.00091000000016
# dealing with the 378 th input character
# 98.00091000000016
# dealing with the 379 th input character
# 98.00092000000016
# dealing with the 380 th input character
# 98.00092000000016
# dealing with the 381 th input character
# 99.00092000000016
# dealing with the 382 th input character
# 99.00092000000016
# dealing with the 383 th input character
# 99.00092000000016
# dealing with the 384 th input character
# 99.00092000000016
# dealing with the 385 th input character
# 100.00092000000016
# the min cost for this sentence is 100.00092000000016
# dealing with the 1 th input character
# 1.0
# dealing with the 2 th input character
# 0.0
# dealing with the 3 th input character
# 1e-05
# dealing with the 4 th input character
# 0.0
# dealing with the 5 th input character
# 1.0
# dealing with the 6 th input character
# 1.00001
# dealing with the 7 th input character
# 1.00001
# dealing with the 8 th input character
# 1e-05
# dealing with the 9 th input character
# 1.00001
# dealing with the 10 th input character
# 1.00002
# dealing with the 11 th input character
# 1.00002
# dealing with the 12 th input character
# 2e-05
# dealing with the 13 th input character
# 1.00002
# dealing with the 14 th input character
# 1.00003
# dealing with the 15 th input character
# 3.0000000000000004e-05
# dealing with the 16 th input character
# 1.00003
# dealing with the 17 th input character
# 1.00003
# dealing with the 18 th input character
# 4e-05
# dealing with the 19 th input character
# 4e-05
# dealing with the 20 th input character
# 5e-05
# dealing with the 21 th input character
# 1.00005
# dealing with the 22 th input character
# 1.00005
# dealing with the 23 th input character
# 1.00006
# dealing with the 24 th input character
# 1.00006
# dealing with the 25 th input character
# 1.00007
# dealing with the 26 th input character
# 2.00006
# dealing with the 27 th input character
# 2.00007
# dealing with the 28 th input character
# 2.00008
# dealing with the 29 th input character
# 1.00008
# dealing with the 30 th input character
# 1.0000900000000001
# dealing with the 31 th input character
# 1.0000900000000001
# dealing with the 32 th input character
# 2.00009
# dealing with the 33 th input character
# 2.00009
# dealing with the 34 th input character
# 1.0001000000000002
# dealing with the 35 th input character
# 2.0001
# dealing with the 36 th input character
# 2.0001100000000003
# dealing with the 37 th input character
# 2.0001100000000003
# dealing with the 38 th input character
# 2.0001100000000003
# dealing with the 39 th input character
# 1.0001100000000003
# dealing with the 40 th input character
# 1.0001200000000003
# dealing with the 41 th input character
# 1.0001200000000003
# dealing with the 42 th input character
# 1.0001200000000003
# dealing with the 43 th input character
# 2.0001200000000003
# dealing with the 44 th input character
# 1.0001300000000004
# dealing with the 45 th input character
# 2.0001300000000004
# dealing with the 46 th input character
# 2.0001300000000004
# dealing with the 47 th input character
# 2.0001400000000005
# dealing with the 48 th input character
# 1.0001400000000005
# dealing with the 49 th input character
# 1.0001400000000005
# dealing with the 50 th input character
# 1.0001500000000005
# dealing with the 51 th input character
# 1.0001500000000005
# dealing with the 52 th input character
# 2.0001500000000005
# dealing with the 53 th input character
# 2.0001600000000006
# dealing with the 54 th input character
# 1.0001600000000006
# dealing with the 55 th input character
# 2.0001600000000006
# dealing with the 56 th input character
# 2.0001700000000007
# dealing with the 57 th input character
# 2.0001600000000006
# dealing with the 58 th input character
# 1.0001700000000007
# dealing with the 59 th input character
# 2.0001700000000007
# dealing with the 60 th input character
# 2.0001800000000007
# dealing with the 61 th input character
# 1.0001800000000007
# dealing with the 62 th input character
# 2.0001800000000007
# dealing with the 63 th input character
# 2.000190000000001
# dealing with the 64 th input character
# 1.0001900000000008
# dealing with the 65 th input character
# 2.000190000000001
# dealing with the 66 th input character
# 1.0002000000000009
# dealing with the 67 th input character
# 2.000200000000001
# dealing with the 68 th input character
# 2.000210000000001
# dealing with the 69 th input character
# 2.000210000000001
# dealing with the 70 th input character
# 2.000210000000001
# dealing with the 71 th input character
# 1.000210000000001
# dealing with the 72 th input character
# 2.000210000000001
# dealing with the 73 th input character
# 2.000220000000001
# dealing with the 74 th input character
# 1.000220000000001
# the min cost for this sentence is 1.000220000000001
# dealing with the 1 th input character
# 1.0
# dealing with the 2 th input character
# 0.0
# dealing with the 3 th input character
# 1.0
# dealing with the 4 th input character
# 1.00001
# dealing with the 5 th input character
# 1.00001
# dealing with the 6 th input character
# 1e-05
# dealing with the 7 th input character
# 2e-05
# dealing with the 8 th input character
# 2e-05
# dealing with the 9 th input character
# 1.00002
# dealing with the 10 th input character
# 3.0000000000000004e-05
# dealing with the 11 th input character
# 1.00003
# dealing with the 12 th input character
# 1.00004
# dealing with the 13 th input character
# 4e-05
# dealing with the 14 th input character
# 5e-05
# dealing with the 15 th input character
# 4e-05
# dealing with the 16 th input character
# 1.00004
# dealing with the 17 th input character
# 1.00005
# dealing with the 18 th input character
# 5e-05
# dealing with the 19 th input character
# 1.00005
# dealing with the 20 th input character
# 1.00005
# dealing with the 21 th input character
# 1.00006
# dealing with the 22 th input character
# 2.00006
# dealing with the 23 th input character
# 2.00007
# dealing with the 24 th input character
# 2.00007
# dealing with the 25 th input character
# 2.00007
# dealing with the 26 th input character
# 3.00007
# dealing with the 27 th input character
# 2.00008
# dealing with the 28 th input character
# 3.00008
# dealing with the 29 th input character
# 3.00009
# dealing with the 30 th input character
# 3.00008
# dealing with the 31 th input character
# 2.00009
# dealing with the 32 th input character
# 3.00009
# dealing with the 33 th input character
# 2.0001
# dealing with the 34 th input character
# 3.0001
# dealing with the 35 th input character
# 3.0001100000000003
# dealing with the 36 th input character
# 3.0001100000000003
# dealing with the 37 th input character
# 4.0001
# dealing with the 38 th input character
# 3.0001100000000003
# dealing with the 39 th input character
# 2.0001100000000003
# dealing with the 40 th input character
# 2.0001200000000003
# dealing with the 41 th input character
# 2.0001200000000003
# dealing with the 42 th input character
# 2.0001300000000004
# dealing with the 43 th input character
# 3.0001200000000003
# dealing with the 44 th input character
# 2.0001400000000005
# dealing with the 45 th input character
# 3.0001300000000004
# dealing with the 46 th input character
# 3.0001400000000005
# dealing with the 47 th input character
# 2.0001400000000005
# dealing with the 48 th input character
# 3.0001400000000005
# dealing with the 49 th input character
# 3.0001500000000005
# dealing with the 50 th input character
# 2.0001500000000005
# dealing with the 51 th input character
# 3.0001500000000005
# dealing with the 52 th input character
# 3.0001500000000005
# dealing with the 53 th input character
# 2.0001600000000006
# dealing with the 54 th input character
# 2.0001700000000007
# dealing with the 55 th input character
# 2.0001700000000007
# dealing with the 56 th input character
# 3.0001700000000007
# dealing with the 57 th input character
# 3.0001800000000007
# dealing with the 58 th input character
# 3.0001800000000007
# dealing with the 59 th input character
# 2.0001800000000007
# dealing with the 60 th input character
# 3.0001800000000007
# dealing with the 61 th input character
# 3.000190000000001
# dealing with the 62 th input character
# 2.000190000000001
# the min cost for this sentence is 2.000190000000001
# dealing with the 1 th input character
# 0.0
# dealing with the 2 th input character
# 1.0
# dealing with the 3 th input character
# 0.0
# dealing with the 4 th input character
# 1.0
# dealing with the 5 th input character
# 1.00001
# dealing with the 6 th input character
# 1.00001
# dealing with the 7 th input character
# 1.00001
# dealing with the 8 th input character
# 1e-05
# dealing with the 9 th input character
# 2e-05
# dealing with the 10 th input character
# 2e-05
# dealing with the 11 th input character
# 1.00002
# dealing with the 12 th input character
# 1.00003
# dealing with the 13 th input character
# 1.00003
# dealing with the 14 th input character
# 1.00003
# dealing with the 15 th input character
# 1.00003
# dealing with the 16 th input character
# 1.00003
# dealing with the 17 th input character
# 2.0000299999999998
# dealing with the 18 th input character
# 2.0000400000000003
# dealing with the 19 th input character
# 1.00004
# dealing with the 20 th input character
# 2.0000400000000003
# dealing with the 21 th input character
# 2.0000400000000003
# dealing with the 22 th input character
# 1.00005
# dealing with the 23 th input character
# 1.00005
# dealing with the 24 th input character
# 1.0000600000000002
# dealing with the 25 th input character
# 2.00006
# dealing with the 26 th input character
# 2.0000600000000004
# dealing with the 27 th input character
# 2.00007
# dealing with the 28 th input character
# 2.00007
# dealing with the 29 th input character
# 3.0000600000000004
# dealing with the 30 th input character
# 3.00007
# dealing with the 31 th input character
# 2.00008
# dealing with the 32 th input character
# 2.00008
# dealing with the 33 th input character
# 2.00009
# dealing with the 34 th input character
# 3.00009
# dealing with the 35 th input character
# 3.00009
# dealing with the 36 th input character
# 3.00009
# dealing with the 37 th input character
# 3.00009
# dealing with the 38 th input character
# 4.00009
# dealing with the 39 th input character
# 3.0001
# dealing with the 40 th input character
# 3.0001
# dealing with the 41 th input character
# 4.0001
# dealing with the 42 th input character
# 3.0001100000000003
# dealing with the 43 th input character
# 4.000109999999999
# dealing with the 44 th input character
# 4.00011
# dealing with the 45 th input character
# 3.0001100000000003
# dealing with the 46 th input character
# 4.00011
# dealing with the 47 th input character
# 4.000120000000001
# dealing with the 48 th input character
# 4.000120000000001
# dealing with the 49 th input character
# 5.00012
# dealing with the 50 th input character
# 5.00012
# dealing with the 51 th input character
# 4.000120000000001
# dealing with the 52 th input character
# 3.0001200000000003
# dealing with the 53 th input character
# 4.000120000000001
# dealing with the 54 th input character
# 4.00013
# dealing with the 55 th input character
# 3.0001300000000004
# dealing with the 56 th input character
# 3.0001300000000004
# dealing with the 57 th input character
# 4.00013
# dealing with the 58 th input character
# 4.00014
# dealing with the 59 th input character
# 4.00013
# dealing with the 60 th input character
# 3.0001300000000004
# dealing with the 61 th input character
# 3.0001400000000005
# dealing with the 62 th input character
# 4.00014
# dealing with the 63 th input character
# 4.00015
# dealing with the 64 th input character
# 4.0001500000000005
# dealing with the 65 th input character
# 3.0001500000000005
# dealing with the 66 th input character
# 3.0001600000000006
# dealing with the 67 th input character
# 4.000160000000001
# dealing with the 68 th input character
# 4.000160000000001
# dealing with the 69 th input character
# 4.000170000000001
# dealing with the 70 th input character
# 3.0001700000000007
# dealing with the 71 th input character
# 3.0001800000000007
# dealing with the 72 th input character
# 4.00018
# dealing with the 73 th input character
# 4.00019
# dealing with the 74 th input character
# 4.00018
# dealing with the 75 th input character
# 3.000190000000001
# dealing with the 76 th input character
# 4.000190000000001
# dealing with the 77 th input character
# 4.0002
# dealing with the 78 th input character
# 4.000200000000001
# dealing with the 79 th input character
# 3.000200000000001
# dealing with the 80 th input character
# 4.000200000000001
# dealing with the 81 th input character
# 4.000210000000001
# dealing with the 82 th input character
# 3.000210000000001
# dealing with the 83 th input character
# 4.000210000000001
# dealing with the 84 th input character
# 4.0002200000000006
# dealing with the 85 th input character
# 3.000220000000001
# dealing with the 86 th input character
# 4.0002200000000006
# dealing with the 87 th input character
# 3.000230000000001
# dealing with the 88 th input character
# 3.000240000000001
# dealing with the 89 th input character
# 4.000230000000001
# dealing with the 90 th input character
# 3.000230000000001
# dealing with the 91 th input character
# 4.000230000000001
# dealing with the 92 th input character
# 3.000240000000001
# dealing with the 93 th input character
# 3.000250000000001
# dealing with the 94 th input character
# 3.0002600000000013
# dealing with the 95 th input character
# 3.000250000000001
# the min cost for this sentence is 3.000250000000001
# Over all cost for this file with n_best equal to 10 is 106.00158000000016

# %%
total_cost
# Out:
# 106.00158000000016

# %% [markdown]
# # Read the Unsegment.txt and segment and correct it

# %%
n_best=10

file=open("unsegmented.txt","r").readlines()
total_cost=0
for sentence in file:
    sentence=sentence.strip('\n')
    min_sentence_cost=spellchecker.unsegment_text_vertibe(sentence,n_best=n_best,get_sentence=False,loop_cost=0.00001)
    print("the min cost for this sentence is {}".format(min_sentence_cost))
    total_cost+=min_sentence_cost
print("Over all cost for this file with n_best equal to {} is {}".format(n_best,total_cost))
# Out:
# dealing with the 1 th input character
# 0.0
# dealing with the 2 th input character
# 0.0
# dealing with the 3 th input character
# 1.0
# dealing with the 4 th input character
# 1.0
# dealing with the 5 th input character
# 1e-05
# dealing with the 6 th input character
# 1.00001
# dealing with the 7 th input character
# 2e-05
# dealing with the 8 th input character
# 1.00002
# dealing with the 9 th input character
# 1.00002
# dealing with the 10 th input character
# 1.00003
# dealing with the 11 th input character
# 2.00002
# dealing with the 12 th input character
# 2.0000299999999998
# dealing with the 13 th input character
# 2.0000299999999998
# dealing with the 14 th input character
# 2.00003
# dealing with the 15 th input character
# 2.0000400000000003
# dealing with the 16 th input character
# 3.00004
# dealing with the 17 th input character
# 2.0000500000000003
# dealing with the 18 th input character
# 3.0000500000000003
# dealing with the 19 th input character
# 3.0000600000000004
# dealing with the 20 th input character
# 3.0000600000000004
# dealing with the 21 th input character
# 3.0000700000000005
# dealing with the 22 th input character
# 3.0000800000000005
# dealing with the 23 th input character
# 4.0000800000000005
# dealing with the 24 th input character
# 4.00009
# dealing with the 25 th input character
# 4.00009
# dealing with the 26 th input character
# 4.00009
# dealing with the 27 th input character
# 4.00009
# dealing with the 28 th input character
# 5.00009
# dealing with the 29 th input character
# 5.0001
# dealing with the 30 th input character
# 5.0001
# dealing with the 31 th input character
# 6.0001
# dealing with the 32 th input character
# 6.0001
# dealing with the 33 th input character
# 6.000109999999999
# dealing with the 34 th input character
# 6.000109999999999
# dealing with the 35 th input character
# 7.000109999999999
# dealing with the 36 th input character
# 6.000119999999999
# dealing with the 37 th input character
# 7.000119999999999
# dealing with the 38 th input character
# 7.000129999999999
# dealing with the 39 th input character
# 7.000129999999999
# dealing with the 40 th input character
# 7.000129999999999
# dealing with the 41 th input character
# 8.000129999999999
# dealing with the 42 th input character
# 8.000129999999999
# dealing with the 43 th input character
# 8.000139999999998
# dealing with the 44 th input character
# 9.000139999999998
# dealing with the 45 th input character
# 9.000139999999998
# dealing with the 46 th input character
# 9.000149999999998
# dealing with the 47 th input character
# 9.000159999999997
# dealing with the 48 th input character
# 9.000159999999997
# dealing with the 49 th input character
# 9.000169999999997
# dealing with the 50 th input character
# 9.000169999999997
# dealing with the 51 th input character
# 9.000179999999997
# dealing with the 52 th input character
# 10.000179999999997
# dealing with the 53 th input character
# 10.000189999999996
# dealing with the 54 th input character
# 10.000189999999996
# dealing with the 55 th input character
# 10.000199999999996
# dealing with the 56 th input character
# 11.000199999999996
# dealing with the 57 th input character
# 11.000199999999996
# dealing with the 58 th input character
# 12.000199999999996
# dealing with the 59 th input character
# 12.000199999999996
# dealing with the 60 th input character
# 13.000199999999996
# dealing with the 61 th input character
# 13.000199999999996
# dealing with the 62 th input character
# 14.000199999999996
# dealing with the 63 th input character
# 15.000199999999996
# dealing with the 64 th input character
# 15.000199999999996
# dealing with the 65 th input character
# 16.000199999999996
# dealing with the 66 th input character
# 16.000209999999996
# dealing with the 67 th input character
# 16.000219999999995
# dealing with the 68 th input character
# 17.000219999999995
# dealing with the 69 th input character
# 17.000219999999995
# dealing with the 70 th input character
# 18.000219999999995
# dealing with the 71 th input character
# 18.000219999999995
# dealing with the 72 th input character
# 18.000229999999995
# dealing with the 73 th input character
# 19.000229999999995
# dealing with the 74 th input character
# 19.000239999999994
# dealing with the 75 th input character
# 20.000239999999994
# dealing with the 76 th input character
# 21.000239999999994
# dealing with the 77 th input character
# 21.000239999999994
# dealing with the 78 th input character
# 21.000239999999994
# dealing with the 79 th input character
# 21.000239999999994
# dealing with the 80 th input character
# 21.000249999999994
# dealing with the 81 th input character
# 21.000249999999994
# dealing with the 82 th input character
# 21.000259999999994
# dealing with the 83 th input character
# 22.000259999999994
# dealing with the 84 th input character
# 22.000269999999993
# dealing with the 85 th input character
# 22.000269999999993
# dealing with the 86 th input character
# 23.000269999999993
# dealing with the 87 th input character
# 23.000269999999993
# dealing with the 88 th input character
# 23.000269999999993
# dealing with the 89 th input character
# 24.000269999999993
# dealing with the 90 th input character
# 24.000279999999993
# dealing with the 91 th input character
# 25.000279999999993
# dealing with the 92 th input character
# 25.000279999999993
# dealing with the 93 th input character
# 25.000289999999993
# dealing with the 94 th input character
# 25.000299999999992
# dealing with the 95 th input character
# 26.000299999999992
# dealing with the 96 th input character
# 26.000299999999992
# dealing with the 97 th input character
# 27.000299999999992
# dealing with the 98 th input character
# 27.000299999999992
# dealing with the 99 th input character
# 27.000299999999992
# dealing with the 100 th input character
# 26.000299999999992
# dealing with the 101 th input character
# 26.000309999999992
# dealing with the 102 th input character
# 26.00031999999999
# dealing with the 103 th input character
# 26.00031999999999
# dealing with the 104 th input character
# 26.00031999999999
# dealing with the 105 th input character
# 27.00031999999999
# dealing with the 106 th input character
# 28.00031999999999
# dealing with the 107 th input character
# 29.00031999999999
# dealing with the 108 th input character
# 29.00031999999999
# dealing with the 109 th input character
# 29.00031999999999
# dealing with the 110 th input character
# 29.00032999999999
# dealing with the 111 th input character
# 29.00033999999999
# dealing with the 112 th input character
# 30.00033999999999
# dealing with the 113 th input character
# 30.00034999999999
# dealing with the 114 th input character
# 31.00034999999999
# dealing with the 115 th input character
# 30.00034999999999
# dealing with the 116 th input character
# 31.00034999999999
# dealing with the 117 th input character
# 32.00034999999999
# dealing with the 118 th input character
# 33.00034999999999
# dealing with the 119 th input character
# 33.00034999999999
# dealing with the 120 th input character
# 33.00035999999999
# dealing with the 121 th input character
# 34.00035999999999
# dealing with the 122 th input character
# 35.00035999999999
# dealing with the 123 th input character
# 35.00035999999999
# dealing with the 124 th input character
# 35.00035999999999
# dealing with the 125 th input character
# 34.00035999999999
# dealing with the 126 th input character
# 35.00035999999999
# dealing with the 127 th input character
# 35.00037
# dealing with the 128 th input character
# 36.00037
# dealing with the 129 th input character
# 36.00037
# dealing with the 130 th input character
# 36.00037
# dealing with the 131 th input character
# 37.00037
# dealing with the 132 th input character
# 38.00037
# dealing with the 133 th input character
# 38.00037
# dealing with the 134 th input character
# 39.00037
# dealing with the 135 th input character
# 39.00038
# dealing with the 136 th input character
# 40.00038
# dealing with the 137 th input character
# 40.00038
# dealing with the 138 th input character
# 41.00038
# dealing with the 139 th input character
# 41.00038
# dealing with the 140 th input character
# 41.00039
# dealing with the 141 th input character
# 42.00039
# dealing with the 142 th input character
# 42.00039
# dealing with the 143 th input character
# 43.00039
# dealing with the 144 th input character
# 43.00039
# dealing with the 145 th input character
# 44.00039
# dealing with the 146 th input character
# 44.00039
# dealing with the 147 th input character
# 44.000400000000006
# dealing with the 148 th input character
# 44.000400000000006
# dealing with the 149 th input character
# 45.000400000000006
# dealing with the 150 th input character
# 46.000400000000006
# dealing with the 151 th input character
# 46.000400000000006
# dealing with the 152 th input character
# 46.000400000000006
# dealing with the 153 th input character
# 47.000400000000006
# dealing with the 154 th input character
# 47.000400000000006
# dealing with the 155 th input character
# 47.000400000000006
# dealing with the 156 th input character
# 48.000400000000006
# dealing with the 157 th input character
# 48.00041000000001
# dealing with the 158 th input character
# 48.00041000000001
# dealing with the 159 th input character
# 49.00041000000001
# dealing with the 160 th input character
# 49.00041000000001
# dealing with the 161 th input character
# 49.00041000000001
# dealing with the 162 th input character
# 49.00041000000001
# dealing with the 163 th input character
# 49.00042000000001
# dealing with the 164 th input character
# 49.00042000000001
# dealing with the 165 th input character
# 49.000430000000016
# dealing with the 166 th input character
# 50.000430000000016
# dealing with the 167 th input character
# 50.00044000000002
# dealing with the 168 th input character
# 50.00044000000002
# dealing with the 169 th input character
# 51.00044000000002
# dealing with the 170 th input character
# 51.00045000000002
# dealing with the 171 th input character
# 52.00045000000002
# dealing with the 172 th input character
# 52.00045000000002
# dealing with the 173 th input character
# 52.00045000000002
# dealing with the 174 th input character
# 52.000460000000025
# dealing with the 175 th input character
# 53.000460000000025
# dealing with the 176 th input character
# 53.000460000000025
# dealing with the 177 th input character
# 53.000460000000025
# dealing with the 178 th input character
# 54.000460000000025
# dealing with the 179 th input character
# 54.00047000000003
# dealing with the 180 th input character
# 55.00047000000003
# dealing with the 181 th input character
# 55.00047000000003
# dealing with the 182 th input character
# 56.00047000000003
# dealing with the 183 th input character
# 56.00047000000003
# dealing with the 184 th input character
# 56.00047000000003
# dealing with the 185 th input character
# 56.00048000000003
# dealing with the 186 th input character
# 56.00048000000003
# dealing with the 187 th input character
# 57.00048000000003
# dealing with the 188 th input character
# 57.00048000000003
# dealing with the 189 th input character
# 58.00048000000003
# dealing with the 190 th input character
# 59.00048000000003
# dealing with the 191 th input character
# 60.00048000000003
# dealing with the 192 th input character
# 60.000490000000035
# dealing with the 193 th input character
# 61.000490000000035
# dealing with the 194 th input character
# 61.000490000000035
# dealing with the 195 th input character
# 61.000490000000035
# dealing with the 196 th input character
# 61.00050000000004
# dealing with the 197 th input character
# 61.00050000000004
# dealing with the 198 th input character
# 61.00051000000004
# dealing with the 199 th input character
# 62.00051000000004
# dealing with the 200 th input character
# 62.00051000000004
# dealing with the 201 th input character
# 62.00051000000004
# dealing with the 202 th input character
# 63.00051000000004
# dealing with the 203 th input character
# 63.00051000000004
# dealing with the 204 th input character
# 64.00051000000005
# dealing with the 205 th input character
# 65.00051000000005
# dealing with the 206 th input character
# 65.00051000000005
# dealing with the 207 th input character
# 65.00051000000005
# dealing with the 208 th input character
# 65.00051000000005
# dealing with the 209 th input character
# 66.00051000000005
# dealing with the 210 th input character
# 67.00051000000005
# dealing with the 211 th input character
# 67.00052000000005
# dealing with the 212 th input character
# 68.00052000000005
# dealing with the 213 th input character
# 68.00052000000005
# dealing with the 214 th input character
# 68.00052000000005
# dealing with the 215 th input character
# 69.00052000000005
# dealing with the 216 th input character
# 69.00052000000005
# dealing with the 217 th input character
# 69.00052000000005
# dealing with the 218 th input character
# 70.00052000000005
# dealing with the 219 th input character
# 70.00052000000005
# dealing with the 220 th input character
# 71.00052000000005
# dealing with the 221 th input character
# 72.00052000000005
# dealing with the 222 th input character
# 73.00052000000005
# dealing with the 223 th input character
# 73.00052000000005
# dealing with the 224 th input character
# 73.00053000000005
# dealing with the 225 th input character
# 74.00053000000005
# dealing with the 226 th input character
# 74.00053000000005
# dealing with the 227 th input character
# 74.00053000000005
# dealing with the 228 th input character
# 74.00053000000005
# dealing with the 229 th input character
# 75.00053000000005
# dealing with the 230 th input character
# 76.00053000000005
# dealing with the 231 th input character
# 76.00054000000006
# dealing with the 232 th input character
# 77.00054000000006
# dealing with the 233 th input character
# 77.00055000000006
# dealing with the 234 th input character
# 78.00055000000006
# dealing with the 235 th input character
# 79.00055000000006
# dealing with the 236 th input character
# 79.00055000000006
# dealing with the 237 th input character
# 79.00055000000006
# dealing with the 238 th input character
# 79.00055000000006
# dealing with the 239 th input character
# 80.00055000000006
# dealing with the 240 th input character
# 80.00056000000006
# dealing with the 241 th input character
# 80.00057000000007
# dealing with the 242 th input character
# 81.00057000000007
# dealing with the 243 th input character
# 81.00057000000007
# dealing with the 244 th input character
# 82.00057000000007
# dealing with the 245 th input character
# 82.00057000000007
# dealing with the 246 th input character
# 83.00057000000007
# dealing with the 247 th input character
# 84.00057000000007
# dealing with the 248 th input character
# 84.00057000000007
# dealing with the 249 th input character
# 84.00058000000007
# dealing with the 250 th input character
# 85.00058000000007
# dealing with the 251 th input character
# 85.00058000000007
# dealing with the 252 th input character
# 85.00059000000007
# dealing with the 253 th input character
# 85.00060000000008
# dealing with the 254 th input character
# 85.00060000000008
# dealing with the 255 th input character
# 85.00061000000008
# dealing with the 256 th input character
# 86.00061000000008
# dealing with the 257 th input character
# 87.00061000000008
# dealing with the 258 th input character
# 87.00061000000008
# dealing with the 259 th input character
# 87.00061000000008
# dealing with the 260 th input character
# 86.00061000000008
# dealing with the 261 th input character
# 86.00062000000008
# dealing with the 262 th input character
# 86.00062000000008
# dealing with the 263 th input character
# 87.00062000000008
# dealing with the 264 th input character
# 88.00062000000008
# dealing with the 265 th input character
# 87.00062000000008
# dealing with the 266 th input character
# 88.00062000000008
# dealing with the 267 th input character
# 89.00062000000008
# dealing with the 268 th input character
# 90.00062000000008
# dealing with the 269 th input character
# 91.00062000000008
# dealing with the 270 th input character
# 91.00062000000008
# dealing with the 271 th input character
# 91.00062000000008
# dealing with the 272 th input character
# 91.00063000000009
# dealing with the 273 th input character
# 91.00063000000009
# dealing with the 274 th input character
# 91.00063000000009
# dealing with the 275 th input character
# 92.00063000000009
# dealing with the 276 th input character
# 93.00063000000009
# dealing with the 277 th input character
# 93.00064000000009
# dealing with the 278 th input character
# 94.00064000000009
# dealing with the 279 th input character
# 94.00064000000009
# dealing with the 280 th input character
# 94.00064000000009
# dealing with the 281 th input character
# 94.00064000000009
# dealing with the 282 th input character
# 94.00065000000009
# dealing with the 283 th input character
# 94.0006600000001
# dealing with the 284 th input character
# 94.0006600000001
# dealing with the 285 th input character
# 94.0006600000001
# dealing with the 286 th input character
# 95.0006600000001
# dealing with the 287 th input character
# 95.0006600000001
# dealing with the 288 th input character
# 96.0006600000001
# dealing with the 289 th input character
# 96.0006700000001
# dealing with the 290 th input character
# 96.0006800000001
# dealing with the 291 th input character
# 96.0006800000001
# dealing with the 292 th input character
# 97.0006800000001
# dealing with the 293 th input character
# 97.0006900000001
# dealing with the 294 th input character
# 97.0006900000001
# dealing with the 295 th input character
# 97.0006900000001
# dealing with the 296 th input character
# 98.0006900000001
# dealing with the 297 th input character
# 98.0006900000001
# dealing with the 298 th input character
# 98.00070000000011
# dealing with the 299 th input character
# 99.00070000000011
# dealing with the 300 th input character
# 99.00070000000011
# dealing with the 301 th input character
# 100.00070000000011
# dealing with the 302 th input character
# 100.00070000000011
# dealing with the 303 th input character
# 100.00070000000011
# dealing with the 304 th input character
# 100.00071000000011
# dealing with the 305 th input character
# 101.00071000000011
# dealing with the 306 th input character
# 101.00071000000011
# dealing with the 307 th input character
# 101.00071000000011
# dealing with the 308 th input character
# 101.00071000000011
# dealing with the 309 th input character
# 101.00072000000011
# dealing with the 310 th input character
# 102.00072000000011
# dealing with the 311 th input character
# 102.00072000000011
# dealing with the 312 th input character
# 102.00072000000011
# dealing with the 313 th input character
# 103.00072000000011
# dealing with the 314 th input character
# 103.00073000000012
# dealing with the 315 th input character
# 104.00073000000012
# dealing with the 316 th input character
# 104.00073000000012
# dealing with the 317 th input character
# 104.00074000000012
# dealing with the 318 th input character
# 104.00074000000012
# dealing with the 319 th input character
# 104.00075000000012
# dealing with the 320 th input character
# 105.00075000000012
# dealing with the 321 th input character
# 105.00075000000012
# dealing with the 322 th input character
# 105.00075000000012
# dealing with the 323 th input character
# 106.00075000000012
# dealing with the 324 th input character
# 106.00075000000012
# dealing with the 325 th input character
# 106.00075000000012
# dealing with the 326 th input character
# 106.00076000000013
# dealing with the 327 th input character
# 107.00076000000013
# dealing with the 328 th input character
# 107.00076000000013
# dealing with the 329 th input character
# 108.00076000000013
# dealing with the 330 th input character
# 107.00076000000013
# dealing with the 331 th input character
# 108.00076000000013
# dealing with the 332 th input character
# 109.00076000000013
# dealing with the 333 th input character
# 110.00076000000013
# dealing with the 334 th input character
# 110.00077000000013
# dealing with the 335 th input character
# 111.00077000000013
# dealing with the 336 th input character
# 111.00077000000013
# dealing with the 337 th input character
# 111.00078000000013
# dealing with the 338 th input character
# 111.00079000000014
# dealing with the 339 th input character
# 112.00079000000014
# dealing with the 340 th input character
# 112.00079000000014
# dealing with the 341 th input character
# 113.00079000000014
# dealing with the 342 th input character
# 112.00079000000014
# dealing with the 343 th input character
# 113.00079000000014
# dealing with the 344 th input character
# 114.00079000000014
# dealing with the 345 th input character
# 114.00080000000014
# dealing with the 346 th input character
# 115.00080000000014
# dealing with the 347 th input character
# 115.00080000000014
# dealing with the 348 th input character
# 115.00080000000014
# dealing with the 349 th input character
# 116.00080000000014
# dealing with the 350 th input character
# 117.00080000000014
# dealing with the 351 th input character
# 117.00080000000014
# dealing with the 352 th input character
# 118.00080000000014
# dealing with the 353 th input character
# 119.00080000000014
# dealing with the 354 th input character
# 119.00080000000014
# dealing with the 355 th input character
# 119.00081000000014
# dealing with the 356 th input character
# 119.00081000000014
# dealing with the 357 th input character
# 119.00082000000015
# dealing with the 358 th input character
# 120.00082000000015
# dealing with the 359 th input character
# 120.00082000000015
# dealing with the 360 th input character
# 121.00082000000015
# dealing with the 361 th input character
# 120.00082000000015
# dealing with the 362 th input character
# 120.00083000000015
# dealing with the 363 th input character
# 120.00083000000015
# dealing with the 364 th input character
# 121.00083000000015
# dealing with the 365 th input character
# 122.00083000000015
# dealing with the 366 th input character
# 121.00083000000015
# dealing with the 367 th input character
# 122.00083000000015
# dealing with the 368 th input character
# 123.00083000000015
# dealing with the 369 th input character
# 124.00083000000015
# dealing with the 370 th input character
# 125.00083000000015
# dealing with the 371 th input character
# 125.00083000000015
# dealing with the 372 th input character
# 125.00083000000015
# dealing with the 373 th input character
# 126.00083000000015
# the min cost for this sentence is 126.00083000000015
# dealing with the 1 th input character
# 1.0
# dealing with the 2 th input character
# 0.0
# dealing with the 3 th input character
# 1e-05
# dealing with the 4 th input character
# 1.0
# dealing with the 5 th input character
# 1.00002
# dealing with the 6 th input character
# 1.00003
# dealing with the 7 th input character
# 1.00003
# dealing with the 8 th input character
# 1.00004
# dealing with the 9 th input character
# 2.00001
# dealing with the 10 th input character
# 2.00002
# dealing with the 11 th input character
# 1.00005
# dealing with the 12 th input character
# 1.0000600000000002
# dealing with the 13 th input character
# 2.00005
# dealing with the 14 th input character
# 2.0000600000000004
# dealing with the 15 th input character
# 1.0000700000000002
# dealing with the 16 th input character
# 2.00007
# dealing with the 17 th input character
# 2.00007
# dealing with the 18 th input character
# 2.0000800000000005
# dealing with the 19 th input character
# 3.00008
# dealing with the 20 th input character
# 3.00008
# dealing with the 21 th input character
# 3.0000900000000006
# dealing with the 22 th input character
# 3.0000900000000006
# dealing with the 23 th input character
# 4.00009
# dealing with the 24 th input character
# 3.0001000000000007
# dealing with the 25 th input character
# 3.0001100000000007
# dealing with the 26 th input character
# 4.000100000000001
# dealing with the 27 th input character
# 3.000120000000001
# dealing with the 28 th input character
# 3.000130000000001
# dealing with the 29 th input character
# 3.000130000000001
# dealing with the 30 th input character
# 3.000140000000001
# dealing with the 31 th input character
# 3.000140000000001
# dealing with the 32 th input character
# 3.000140000000001
# dealing with the 33 th input character
# 4.000140000000001
# dealing with the 34 th input character
# 3.000150000000001
# dealing with the 35 th input character
# 4.0001500000000005
# dealing with the 36 th input character
# 4.000150000000001
# dealing with the 37 th input character
# 4.00016
# dealing with the 38 th input character
# 5.00016
# dealing with the 39 th input character
# 5.00016
# dealing with the 40 th input character
# 5.00016
# dealing with the 41 th input character
# 5.00017
# dealing with the 42 th input character
# 5.00017
# dealing with the 43 th input character
# 6.00017
# dealing with the 44 th input character
# 5.000179999999999
# dealing with the 45 th input character
# 5.000189999999999
# dealing with the 46 th input character
# 6.000179999999999
# dealing with the 47 th input character
# 6.000189999999999
# dealing with the 48 th input character
# 6.000189999999999
# dealing with the 49 th input character
# 6.000199999999999
# dealing with the 50 th input character
# 6.000199999999999
# dealing with the 51 th input character
# 6.000209999999998
# dealing with the 52 th input character
# 6.000209999999998
# dealing with the 53 th input character
# 7.000199999999999
# dealing with the 54 th input character
# 7.000219999999998
# dealing with the 55 th input character
# 7.000219999999998
# dealing with the 56 th input character
# 7.000219999999998
# dealing with the 57 th input character
# 7.0002299999999975
# dealing with the 58 th input character
# 7.0002299999999975
# dealing with the 59 th input character
# 7.0002299999999975
# dealing with the 60 th input character
# 8.000229999999998
# dealing with the 61 th input character
# 8.000239999999998
# dealing with the 62 th input character
# 8.000239999999998
# dealing with the 63 th input character
# 9.000239999999998
# dealing with the 64 th input character
# 9.000239999999998
# dealing with the 65 th input character
# 9.000239999999998
# dealing with the 66 th input character
# 10.000239999999998
# dealing with the 67 th input character
# 9.000249999999998
# dealing with the 68 th input character
# 10.000249999999998
# dealing with the 69 th input character
# 10.000259999999997
# dealing with the 70 th input character
# 11.000259999999997
# dealing with the 71 th input character
# 10.000259999999997
# dealing with the 72 th input character
# 11.000259999999997
# dealing with the 73 th input character
# 11.000259999999997
# dealing with the 74 th input character
# 10.000269999999997
# the min cost for this sentence is 10.000269999999997
# dealing with the 1 th input character
# 1.0
# dealing with the 2 th input character
# 1.0
# dealing with the 3 th input character
# 1.0
# dealing with the 4 th input character
# 2.0
# dealing with the 5 th input character
# 2.0
# dealing with the 6 th input character
# 2.0
# dealing with the 7 th input character
# 2.00001
# dealing with the 8 th input character
# 3.00001
# dealing with the 9 th input character
# 2.00002
# dealing with the 10 th input character
# 3.00002
# dealing with the 11 th input character
# 3.00003
# dealing with the 12 th input character
# 3.00003
# dealing with the 13 th input character
# 4.000030000000001
# dealing with the 14 th input character
# 4.000030000000001
# dealing with the 15 th input character
# 4.00004
# dealing with the 16 th input character
# 4.00004
# dealing with the 17 th input character
# 4.00005
# dealing with the 18 th input character
# 5.000030000000001
# dealing with the 19 th input character
# 5.00004
# dealing with the 20 th input character
# 5.0000599999999995
# dealing with the 21 th input character
# 5.0000599999999995
# dealing with the 22 th input character
# 6.00005
# dealing with the 23 th input character
# 6.000069999999999
# dealing with the 24 th input character
# 6.000069999999999
# dealing with the 25 th input character
# 6.000079999999999
# dealing with the 26 th input character
# 7.0000599999999995
# dealing with the 27 th input character
# 7.000089999999998
# dealing with the 28 th input character
# 7.000089999999998
# dealing with the 29 th input character
# 8.000089999999998
# dealing with the 30 th input character
# 7.000099999999998
# dealing with the 31 th input character
# 8.000089999999998
# dealing with the 32 th input character
# 8.000099999999998
# dealing with the 33 th input character
# 9.000099999999998
# dealing with the 34 th input character
# 9.000109999999998
# dealing with the 35 th input character
# 9.000109999999998
# dealing with the 36 th input character
# 9.000119999999997
# dealing with the 37 th input character
# 10.000119999999997
# dealing with the 38 th input character
# 10.000119999999997
# dealing with the 39 th input character
# 10.000119999999997
# dealing with the 40 th input character
# 11.000119999999997
# dealing with the 41 th input character
# 12.000119999999997
# dealing with the 42 th input character
# 11.000119999999997
# dealing with the 43 th input character
# 12.000119999999997
# dealing with the 44 th input character
# 12.000129999999997
# dealing with the 45 th input character
# 13.000129999999997
# dealing with the 46 th input character
# 13.000129999999997
# dealing with the 47 th input character
# 13.000129999999997
# dealing with the 48 th input character
# 13.000139999999996
# dealing with the 49 th input character
# 14.000139999999996
# dealing with the 50 th input character
# 14.000139999999996
# dealing with the 51 th input character
# 14.000139999999996
# dealing with the 52 th input character
# 14.000139999999996
# dealing with the 53 th input character
# 14.000149999999996
# dealing with the 54 th input character
# 15.000149999999996
# dealing with the 55 th input character
# 15.000149999999996
# dealing with the 56 th input character
# 16.000149999999998
# dealing with the 57 th input character
# 16.000149999999998
# dealing with the 58 th input character
# 16.000149999999998
# the min cost for this sentence is 16.000149999999998
# dealing with the 1 th input character
# 0.0
# dealing with the 2 th input character
# 1.0
# dealing with the 3 th input character
# 0.0
# dealing with the 4 th input character
# 1.0
# dealing with the 5 th input character
# 1.00001
# dealing with the 6 th input character
# 1.00001
# dealing with the 7 th input character
# 1.00001
# dealing with the 8 th input character
# 1.0000200000000001
# dealing with the 9 th input character
# 1.0000200000000001
# dealing with the 10 th input character
# 2.00002
# dealing with the 11 th input character
# 2.00002
# dealing with the 12 th input character
# 2.00003
# dealing with the 13 th input character
# 2.00003
# dealing with the 14 th input character
# 3.00003
# dealing with the 15 th input character
# 3.0000400000000003
# dealing with the 16 th input character
# 3.0000400000000003
# dealing with the 17 th input character
# 4.00004
# dealing with the 18 th input character
# 4.00004
# dealing with the 19 th input character
# 4.00005
# dealing with the 20 th input character
# 4.00005
# dealing with the 21 th input character
# 5.00005
# dealing with the 22 th input character
# 5.00005
# dealing with the 23 th input character
# 5.00005
# dealing with the 24 th input character
# 6.00005
# dealing with the 25 th input character
# 5.0000599999999995
# dealing with the 26 th input character
# 6.0000599999999995
# dealing with the 27 th input character
# 6.000069999999999
# dealing with the 28 th input character
# 6.000069999999999
# dealing with the 29 th input character
# 6.000069999999999
# dealing with the 30 th input character
# 6.000079999999999
# dealing with the 31 th input character
# 6.000089999999998
# dealing with the 32 th input character
# 7.000079999999999
# dealing with the 33 th input character
# 7.000089999999998
# dealing with the 34 th input character
# 7.000089999999998
# dealing with the 35 th input character
# 7.000089999999998
# dealing with the 36 th input character
# 8.000089999999998
# dealing with the 37 th input character
# 8.000099999999998
# dealing with the 38 th input character
# 8.000099999999998
# dealing with the 39 th input character
# 8.000109999999998
# dealing with the 40 th input character
# 8.000109999999998
# dealing with the 41 th input character
# 9.000109999999998
# dealing with the 42 th input character
# 8.000109999999998
# dealing with the 43 th input character
# 9.000109999999998
# dealing with the 44 th input character
# 9.000119999999997
# dealing with the 45 th input character
# 9.000119999999997
# dealing with the 46 th input character
# 10.000119999999997
# dealing with the 47 th input character
# 10.000119999999997
# dealing with the 48 th input character
# 9.000119999999997
# dealing with the 49 th input character
# 10.000119999999997
# dealing with the 50 th input character
# 10.000119999999997
# dealing with the 51 th input character
# 11.000119999999997
# dealing with the 52 th input character
# 11.000129999999997
# dealing with the 53 th input character
# 11.000129999999997
# dealing with the 54 th input character
# 11.000129999999997
# dealing with the 55 th input character
# 11.000139999999996
# dealing with the 56 th input character
# 12.000129999999997
# dealing with the 57 th input character
# 12.000139999999996
# dealing with the 58 th input character
# 13.000139999999996
# dealing with the 59 th input character
# 13.000149999999996
# dealing with the 60 th input character
# 14.000149999999996
# dealing with the 61 th input character
# 14.000149999999996
# dealing with the 62 th input character
# 14.000149999999996
# dealing with the 63 th input character
# 14.000149999999996
# dealing with the 64 th input character
# 14.000159999999996
# dealing with the 65 th input character
# 15.000159999999996
# dealing with the 66 th input character
# 15.000169999999995
# dealing with the 67 th input character
# 15.000169999999995
# dealing with the 68 th input character
# 15.000169999999995
# dealing with the 69 th input character
# 15.000179999999995
# dealing with the 70 th input character
# 16.000179999999993
# dealing with the 71 th input character
# 16.000179999999993
# dealing with the 72 th input character
# 16.000179999999993
# dealing with the 73 th input character
# 16.000189999999993
# dealing with the 74 th input character
# 16.000199999999992
# dealing with the 75 th input character
# 16.000199999999992
# dealing with the 76 th input character
# 16.000209999999992
# dealing with the 77 th input character
# 16.000209999999992
# dealing with the 78 th input character
# 17.000209999999992
# dealing with the 79 th input character
# 17.00021999999999
# dealing with the 80 th input character
# 18.00021999999999
# dealing with the 81 th input character
# 18.00021999999999
# dealing with the 82 th input character
# 18.00021999999999
# dealing with the 83 th input character
# 18.00022999999999
# dealing with the 84 th input character
# 18.00023999999999
# dealing with the 85 th input character
# 18.00024999999999
# dealing with the 86 th input character
# 19.00024999999999
# the min cost for this sentence is 19.00024999999999
# Over all cost for this file with n_best equal to 10 is 171.00150000000014

# %%
total_cost
# Out:
# 171.00150000000014

# %% [markdown]
# # Analysis of the result

# %% [markdown]
# For the first long sentence, it is too hard to deal with it. Therefore its own cost is 126. The rest sentences' costs are 10, 16 and 19.
#
#
# Compared with unsegmented0. There are indeed more errors as second total_cost is larger than the first one.
