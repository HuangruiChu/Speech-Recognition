# %% [markdown]
# # Author： Huangrui Chu
#
#  Bi HMM

# %%
#Import packages
import IPython.display as ipd
import numpy as np
import pyaudio, wave
import math
import copy
import matplotlib.pyplot as plt
from numpy.matlib import repmat
from scipy.fftpack import dct

# %%
def getMFCC2(wavename):#without normalization
    import numpy as np
    import scipy.io.wavfile as wav
    from python_speech_features import mfcc
    fs, audio = wav.read(wavename)
    feature_mfcc = mfcc(audio, samplerate=fs)
    mfcc=[]
    mfcc.append(np.hstack([feature_mfcc[0],feature_mfcc[0],feature_mfcc[0]]))
    for i in range(1,len(feature_mfcc)-1):
        delta=np.zeros(13)
        for j in range(13):
            delta[j]=feature_mfcc[i+1][j]-feature_mfcc[i-1][j]
        mfcc.append(np.hstack([feature_mfcc[i],delta]))
    mfcc.append(np.hstack([feature_mfcc[-1],feature_mfcc[-1],feature_mfcc[-1]]))

    for i in range(1,len(mfcc)-1):
        acc=np.zeros(13)
        for j in range(13):
            acc[j]=mfcc[i+1][13+j]-mfcc[i-1][13+j]
        mfcc[i]=np.hstack([mfcc[i],acc])
    mfccs=np.array(mfcc)
    std=np.std(mfccs)
    var=np.var(mfccs,1)
    for i in range(len(mfccs)):
        for j in range(39):
            mfccs[i][j]=mfccs[i][j]/var[i]
    return mfccs

# %%
def getMFCC3(wavename):#with normalization
    import librosa
    audio, sr = librosa.load(wavename,sr=None)
    mfccs = librosa.feature.mfcc(y=audio, sr=sr,n_mfcc=39)
    std=np.std(mfccs)
    var=np.var(mfccs,1)
    for i in range(len(mfccs)):
        for j in range(39):
            mfccs[i][j]=mfccs[i][j]/var[i]
    return mfccs

# %%
def create_test_dataset(foldername,start_instance,end_instance):
    #we could also use this function for project 1,2,3 for testing our algorithm
    #INPUT:
        #foldername: the name of folder where Huangrui save the audio files
        #end-start:the number of instance we are expected to use as the templates.
    #OUTPUT:
        #templates: we can easily fetch the template for the corresponding digit using:
                #len(templates)%10+digit
    templates=[]
    for i_th_instance in range(start_instance,end_instance):
        for digit in range(0,10):
            #print(str(digit )+'_'+str(i_th_instance)+'.wav')
            mfcc=getMFCC2(foldername+"/"+str(digit )+'_'+str(i_th_instance)+'.wav')
            templates.append(mfcc)
    return templates

# %%
def create_silence_dataset(foldername,start_instance,end_instance):
    #we could also use this function for project 1,2,3 for testing our algorithm
    #INPUT:
        #foldername: the name of folder where Huangrui save the audio files
        #end-start:the number of instance we are expected to use as the templates.
    #OUTPUT:
        #templates: we can easily fetch the template for the corresponding digit using:
                #len(templates)%10+digit
    templates=[]
    for i_th_instance in range(start_instance,end_instance):
        #print(str(digit )+'_'+str(i_th_instance)+'.wav')
        mfcc=getMFCC2(foldername+"/"+"silence"+str(i_th_instance)+'.wav')
        templates.append(mfcc)
    return templates

# %% [markdown]
# # GMM HMM

# %%
#class of mix info from KMeans
class mixInfo:
    """docstring for mixInfo"""
    def __init__(self):
        self.Gaussian_mean = []#每个gaussian distribution的 mean vector
        self.Gaussian_var = [] #每个gaussian distribution的 diagnol covarience
        self.Gaussian_weight = []#每个gaussian distribution 的权重（其和为1）
        self.Num_of_Gaussian = 0 #几个gaussian distribution
class hmmInfo:
    '''hmm model param'''
    def __init__(self):
        self.init = [] #初始矩阵
        self.transition_cost = []
        self.mix = [] #高斯混合模型参数,有几个state，里面就有几个mix
        self.N = 0 #状态数

# %%
def log_gaussian(mu,squared_sigma,input_vector):
    #Author: Huangrui Chu, 
    #Calculate the cost using log gaussian
    part1=0.5*np.sum(np.log((2*np.pi)*(squared_sigma)),axis=1)
    part2=0.5*np.sum(np.square((input_vector-mu))/squared_sigma,axis=1)
    cost= part1+part2
    return cost

def gaussian(mu,squared_sigma,input_vector):
    #Author: Huangrui Chu, 
    #Calculate the probability, we only return a number!!!!
    #为了方便 我这边的一个numpy 推广就先应用到mu 上吧 毕竟我后面是一帧一帧的去分析
    #print(type(squared_sigma))
    #d=input_vector.shape[0]
    d=2
    part0=np.prod(squared_sigma,axis=1)# Huangrui use this to give the product of squared_sigma 1,2,...39
    part1=np.sqrt((2*np.pi)**d *part0)
    front=1/part1
    part2=0.5*np.sum((mu-input_vector)**2/squared_sigma,axis=1)
    expo=np.exp(-part2)
    p=front*expo
    #p=np.exp(log_gaussian(mu,squared_sigma,x))
    return p

def mixture_log_gaussian(mix,input_vector):
    weight=mix.Gaussian_weight
    mu = mix.Gaussian_mean
    squared_sigma = mix.Gaussian_var
    cost=log_gaussian(mu,squared_sigma,input_vector)
#     print(cost)
#     print(weight)
    weighted_cost=np.sum(weight*cost)
    return weighted_cost

# %%
mu=np.zeros([2,39])
mu[0]=1
mu[1]=1
squared_sigma=np.zeros([2,39])
squared_sigma[0]+=1
squared_sigma[1]+=1
input_vector=np.zeros([39])+1
a=gaussian(mu,squared_sigma,input_vector)
print(a)
# Out:
# [0.15915494 0.15915494]

# %%
def bi_hmm_traceback(D):
    #start from the last state and last frame For TRIPHONE!!!!!!!!!!!!
    current_state,current_frame=np.array(D.shape)-1
    #insert the last frame's state
    x=[current_state]
    
    #print(current_frame+1)
    # we do not need the frame 0, which is the fine
    while current_state>0 and current_frame>1:
        #move to the previous frame
        current_frame-=1
        #print(current_state)
        if current_state>1:
            to_check=[D[current_state][current_frame-1],
                      D[current_state-1][current_frame-1]]
            track=np.argmin(to_check)
        else:
            track=0
            
        if track==0:
            #which means, last frame still in the same stage
            x.insert(0,current_state)
        elif track==1:
            current_state-=1
            x.insert(0,current_state)
    
    #print(x)
    return x

# %%
class GMMHMM(object):
    #please input all the templates for one specific word
    def __init__(self,templates,Gaussian_distribution_number=[4,4,4,4,4]):
        self.templates=templates
        #len should be state_number
        self.Gaussian_distribution_number=Gaussian_distribution_number
        self.state_number=len(self.Gaussian_distribution_number)
        self.node_in_each_state=[]
        self.node_state=[]
        self.hmm =None
    
    def update_node_in_each_state(self,show_result=False):
        self.node_in_each_state=[]#state number decide sublist number
        # self.node_in_each_state[0] is empty
        for state in range(self.state_number+1):
            self.node_in_each_state.append([])

        for k in range(len(self.templates)):#templates number
            # the i th vector of the k th training sequence
            for i in range(len(self.node_state[k])):
                j=int(self.node_state[k][i])#the state of the i th vector
                self.node_in_each_state[j].append(self.templates[k][i])
    
    def compute_transition_cost(self,show_result=False):
        # 6 PPT p.g 53  return the transition cost matrix
        #have five states+fine(which means Huangrui Chu set 6 states here)
        shift_likehood=np.zeros((self.state_number+1,self.state_number+1))
        self.state_node_num=np.zeros(self.state_number+1)
        #fetch all the initial state
        initial_states=[]
        for k in range(len(self.node_state)):
            shift_likehood[0][self.node_state[k][0]]+=1

       # count the state transition of all the nodes
        for k in range(len(self.node_state)):
            for i in range(len(self.node_state[k])-1):
                current_node=self.node_state[k][i]
                next_node=self.node_state[k][i+1]
                shift_likehood[current_node][next_node]+=1 
                self.state_node_num[current_node]+=1
            #last node case        
            shift_likehood[self.node_state[k][-2]][self.node_state[k][-1]]+=1
            self.state_node_num[self.node_state[k][-1]]+=1
        
        if show_result:
            print("The num of nodes in different states are {}".format(self.state_node_num))
        #It is sometimes useful to permit entry directly into later states
        for j in range(self.state_number+1):
            #N is the total number of training sequences
            N=len(self.node_state)
            #N_0j is the number of training sequences for which
            #the first data vector was in the j th state
            N_0j=shift_likehood[0][j]
            shift_likehood[0][j]=N_0j/N
            if N_0j==0:
                shift_likehood[0][j]=np.inf
            else:
                shift_likehood[0][j]=-np.log(shift_likehood[0][j])

        #6 PPT p.g 55
        for j in range(1,self.state_number+1):
            for k in range(j,self.state_number+1):
                shift_likehood[j][k]=shift_likehood[j][k]/self.state_node_num[j]
                #transition probability---->transition cost
                #T_ij in 6 PPT p.g 58
                if shift_likehood[j][k]!=0:
                    shift_likehood[j][k]=-np.log(shift_likehood[j][k])
                else:
                    shift_likehood[j][k]=np.inf
        self.hmm.transition_cost=np.array(shift_likehood)
    
    def GMMKmeans_WithEM(self,nodes_for_Kmeans,num_Gaussian_distribution):
        #initialize with mean, var and weight, with one cluster
        num_templates=len(nodes_for_Kmeans)
        means=[]
        covs=[]
        weights=[1]
        mean=np.mean(nodes_for_Kmeans,axis=0)
        cov=np.diagonal(np.cov(np.array(nodes_for_Kmeans).T),offset=0, axis1=0, axis2=1)
        means.append(mean)
        covs.append(cov)
        
        current_num_of_cluster=1
        episolom=0.04
        #initial should be 1 mean
        mix = mixInfo()
        mix.Gaussian_var = np.array(covs)
        mix.Gaussian_mean = np.array(means)
        mix.Num_of_Gaussian = current_num_of_cluster
        mix.Gaussian_weight = np.array(weights)
            
        while num_Gaussian_distribution>current_num_of_cluster:
            #now split
            new_means=[]
            new_covs=[]
            current_num_of_cluster=current_num_of_cluster*2
            new_clusters=[]
            for cluster in range(len(means)):
                #append newly two cluster center
                new_clusters.append([])
                new_clusters.append([])
                #get splitted mean and cov
                new_mean1=means[cluster]*(1-episolom)
                new_mean2=means[cluster]*(1+episolom)
                new_cov1=covs[cluster]*(1-episolom)
                new_cov2=covs[cluster]*(1+episolom)
                new_means.append(new_mean1)
                new_means.append(new_mean2)
                new_covs.append(new_cov1)
                new_covs.append(new_cov2)
            #now assign the templated into new clusters
            new_means=np.array(new_means)
            new_covs=np.array(new_covs)
            for node in nodes_for_Kmeans:
                d=log_gaussian(new_means,new_covs,node)
                cluster=np.argmin(d)
                new_clusters[cluster].append(node)
            #now, according to the new clustered result, we get updated weight,
            #mean and cov
            means=[]
            covs=[]
            weights=[]
            #
            #print("For {} clusters, each cluster has following nodes".format(current_num_of_cluster))
            for cluster in new_clusters:
                #print(len(cluster))
                mean=np.mean(cluster,axis=0)
                cov=np.cov(np.array(cluster).T)
                cov=np.diagonal(cov,offset=0, axis1=0, axis2=1)
                weight=len(cluster)/num_templates
                means.append(mean)
                covs.append(cov)
                weights.append(weight)
            #print(np.sum(weights))
            print("get {} means".format(current_num_of_cluster))
            # now, we put all the information to mix
            mix = mixInfo()
            mix.Gaussian_var = np.array(covs)
            mix.Gaussian_mean = np.array(means)
            mix.Num_of_Gaussian = current_num_of_cluster
            mix.Gaussian_weight = np.array(weights)
            #use EM to update
            print("Using EM")
            mix=self.EM(nodes_for_Kmeans,mix)
            means=mix.Gaussian_mean
            covs=mix.Gaussian_var
            weights=mix.Gaussian_weight
            #print("Updated weights are {}".format( weights))
        return mix
    
    
    def EM(self,nodes,mix):
        #Author: Huangrui Chu
        #input:
              #nodes are current state the templates for EM
              #curren state mix will be updated
        #EM is to update the information of one state's GMM
        num_guassian_distribution=mix.Num_of_Gaussian
        iteration=0
        while True:
            #aaa=[0,0]
            iteration+=1
            mu=mix.Gaussian_mean
            squared_sigma=mix.Gaussian_var
            alpha=mix.Gaussian_weight
            P_l_X_i_s=[]
            #这边可以利用 numpy 计算优化！！！
            for x_i in nodes:
                all_costs_of_x_i=gaussian(mu,squared_sigma,x_i)  
                weighted_costs_of_x_i=alpha*all_costs_of_x_i
                summed_weighted_cost=np.sum(weighted_costs_of_x_i)
                P_l_X_i_s.append(weighted_costs_of_x_i/summed_weighted_cost)
            #updata alpha: 
            array_P_l_X_i_s=np.array(P_l_X_i_s)
            new_alpha=np.sum(array_P_l_X_i_s,axis=0)/len(P_l_X_i_s)
            #updata mu:
            new_mu=[]
            new_squared_sigma=[]
            array_nodes=np.array(nodes)
            #use np.dot to do the quick sum
            part1=np.dot(array_P_l_X_i_s.T,array_nodes)
            part2=np.sum(P_l_X_i_s,axis=0)
            for l in range(num_guassian_distribution):
                mu_l=part1[l]/part2[l]
                new_mu.append(mu_l)
                #updata squred_cov l:
                part3=array_nodes-mu_l
                p_l=array_P_l_X_i_s[:,l]
                cov_l=np.dot((part3.T*p_l),part3)/part2[l]
                cov_l_diagonal=np.diagonal(cov_l, offset=0, axis1=0, axis2=1)
                new_squared_sigma.append(cov_l_diagonal)
            #Huangrui refer to this blog for the converge condition
            #https://blog.csdn.net/Elenstone/article/details/105752321
            err=0
            err_alpha=0
            for z in range(num_guassian_distribution):
                err += np.sum(abs(mu[z]-new_mu[z]))      #计算误差
                err_alpha += abs(alpha[z]-new_alpha[z])
#             print(err)
#             print(err_alpha)
#             print()
            #Now, CHR has successfully updata the mean,cov, weight for mix of current_mix
            #let us record this mix
            mix.Gaussian_mean=np.array(new_mu)
            mix.Gaussian_var=np.array(new_squared_sigma)
            mix.Gaussian_weight=np.array(new_alpha)
            if (err<=0.001) and (err_alpha<0.001):     #达到精度退出迭代
                print(err,err_alpha)
                print("Use {} iterations of EM to converge".format(iteration))
                break
        return mix    

    def inithmm(self):
        self.hmm = hmmInfo()
        self.hmm.init = np.zeros((self.state_number,1))
        self.hmm.init[0] = 1
        self.hmm.N = self.state_number
        #update node_in_each_state,node_state
        #initialization of all state is evenly segmented
        self.node_state=[]#each node in which state, all templates together
        for k in range(len(self.templates)):#templates number
            #now, it is the k th training sequence we are look at
            #for initial part, each state have even number of nodes
            n_node=len(self.templates[k])//self.state_number
            num_left_nodes=len(self.templates[k])%self.state_number
            #n_node is the N_kj
            # to store the node state of k th sequence
            current_sample_node_state=np.zeros(len(self.templates[k])).astype(int) 
            #now, initialize the node state for each node in the k th sequence
            for i in range(1,self.state_number+1):
                current_sample_node_state[n_node*(i-1):n_node*i]+=i
            #left nodes be the last state:
            if num_left_nodes!=0:
                current_sample_node_state[-num_left_nodes:]+=self.state_number
            self.node_state.append(current_sample_node_state)
            #to check my initial node state assignment
            #print(np.bincount(self.node_state[k], weights=None, minlength=0))
        #update node in different state
        self.update_node_in_each_state(show_result=True)
        #Markov chain(calculate current edge score)
        self.compute_transition_cost()
        #Now, we have evenly distributed all the mfcc vector to different states
        #next, let us use gaussian to simulate the nodes
        GMMS=[]
        for state in range(self.state_number):
            print("Initilizinng the state {}".format(state+1))
            current_state_nodes=self.node_in_each_state[state+1]#here Huangrui add plus 1
            #becasue huangrui consider the initial state fine
            #kmeans = KMeans(n_clusters = K,random_state=0).fit(np.array(current_state_nodes))
            curren_state_mix=self.GMMKmeans_WithEM(current_state_nodes,self.Gaussian_distribution_number[state])
            GMMS.append(curren_state_mix)
        self.hmm.mix=GMMS   
    
    
    def trainhmm(self):
        self.inithmm()
        #complete set up by iteratively update the model vectors,covariance
        #and transition score
        previous_best_distance=-np.inf
        current_best_distance=0
        for j in range(1,100):
            #update the node state
            for k in range(len(self.templates)):
                distance,self.node_state[k]=self.GMM_bi_HMM_dtw(self.templates[k],get_track=True)
                current_best_distance+=distance
            #Once we get the new segment, we updata Markov chain(
            self.compute_transition_cost(show_result=True)
            #according to the new segment, get new node in each state
            self.update_node_in_each_state(show_result=True)
            #according to the updated node state, update hmm
            GMMS=[]
            for state in range(self.state_number):
                print("Update GMM of state {}".format(state+1))
                current_state_nodes=self.node_in_each_state[state+1]#here Huangrui add plus 1
                #becasue huangrui consider the initial state fine
                #kmeans = KMeans(n_clusters = K,random_state=0).fit(np.array(current_state_nodes))
                curren_state_mix=self.GMMKmeans_WithEM(current_state_nodes,self.Gaussian_distribution_number[state])
                GMMS.append(curren_state_mix)
            self.hmm.mix=GMMS  
            #Convergence is achieved when the total best-alignment error for
            #all training sequences does not change significantly with further
            #refinement of the model
            difference= previous_best_distance-current_best_distance
    #         print("current difference")
    #         print(difference)
            previous_best_distance=current_best_distance
    #         print("updated previous best distance")
    #         print(previous_best_distance)
            current_best_distance=0
            if abs(difference)<0.0015:
                print("Use {} iterators to updata HMM".format(j))
                break
        #now, since our one Guassian is converged, let me add the transition for the end point, that is:
        #at the end of the state, what is its probability it goes to non_emitting node
        #to do this, we only need to know how many nodes there are at the end of the state 
        #and how many templates we use to train the model
        new_transition=np.zeros((self.state_number+2,self.state_number+2))
        num_nodes_at_last_state=self.state_node_num[self.state_number]
        num_templates=len(self.templates)
        probability_of_get_into_non_emitting_state=num_templates/num_nodes_at_last_state
        log_probability=np.log(probability_of_get_into_non_emitting_state)
        new_transition[:self.state_number+1,:self.state_number+1]=self.hmm.transition_cost
        new_transition[self.state_number+1,self.state_number+1]=log_probability
        self.hmm.transition_cost=new_transition
        #最后再添加就好！！！！！！！！！！！！！
    
    def GMM_bi_HMM_dtw(self,data,get_track=False):
        #Author: Huangrui Chu
        #Input, T is the transition_score
        #yes, we use cost!!!!!!!!
        #Output: the path, how we align each node
        # insert fin at the beginning of the template and data
        T=self.hmm.transition_cost
        zeros=np.zeros([39])
        ones=np.zeros([39])+1
        mix_of_all_states=[]
        #create a fine GMM 
        fine_GMM=mixInfo()
        fine_GMM.Gaussian_mean.append(zeros)
        #fine_GMM.Gaussian_mean.append(zeros)
        fine_GMM.Gaussian_var.append(ones)
        #fine_GMM.Gaussian_var.append(ones)
        fine_GMM.Gaussian_weight=[1]
        #translate from list to np array
        fine_GMM.Gaussian_mean=np.array(fine_GMM.Gaussian_mean)
        fine_GMM.Gaussian_var=np.array(fine_GMM.Gaussian_var)
        fine_GMM.Num_of_Gaussian = 1
        mix_of_all_states.append(fine_GMM)
        for current_mix in self.hmm.mix:
            mix_of_all_states.append(current_mix)
        data=np.vstack([zeros,data])
        #print(data.shape)

        t=len(mix_of_all_states) # here, t should be the number of states+1 we set
        d=len(data)#means input frame j
        #create empty best path cost matrix "P" 
        P=np.zeros([t,d])
        #to fetch the data, we use P[i][j],i for template and j for input data
    #     • P i,j = best path cost from origin to node [i,j]
    #     • C i,j = local node cost of aligning template frame i to input frame j
    #     • T i,j,k,l = Edge cost from node (i,j) to node (k,l)

        for j in range(0,d): #input frame j
            for i in range(t): # i th template frame aligns with j-th input frame
                #6 PPT p.g. 65
                Cij= mixture_log_gaussian(mix_of_all_states[i],data[j])
                #print(Cij)
                if i-1>=0:
                    P[i][j]=min(P[i][j-1]+T[i][i],P[i-1][j-1]+T[i-1][i])+Cij
                else:
                    P[i][j]=P[i][j]+Cij

        #Use DTW cost / frame of input speech, instead of total DTW cost, before determining threshold
        # 5 PPT  p.g 32
        P=P/d
    #     print(P.shape)
    #     print(P[-1][-1])
    #     print(P)
        distance=P[-1][-1]
        if get_track:
            return distance,bi_hmm_traceback(P)
        else:
            return distance

# %%
def get_all_digit_templates(foldername,start_instance,end_instance):
    all_digit_templates=[]
    for digit in range(0,10):
        print("Huangrui is creating model vector for digit {} using {} sequences" .format(
            digit,end_instance-start_instance))
        templates=[]
        for i_th_instance in range(start_instance,end_instance):
            #print(str(digit )+'_'+str(i_th_instance)+'.wav')
            mfcc=getMFCC2(foldername+"/"+str(digit )+'_'+str(i_th_instance)+'.wav')
            templates.append(mfcc)
        all_digit_templates.append(templates)
    return  all_digit_templates

# %%
foldername="../new_data"
start_instance=0
end_instance=5
all_digit_templates=get_all_digit_templates(foldername,start_instance,end_instance)
# Out:
# Huangrui is creating model vector for digit 0 using 5 sequences
# Huangrui is creating model vector for digit 1 using 5 sequences
# Huangrui is creating model vector for digit 2 using 5 sequences
# Huangrui is creating model vector for digit 3 using 5 sequences
# Huangrui is creating model vector for digit 4 using 5 sequences
# Huangrui is creating model vector for digit 5 using 5 sequences
# Huangrui is creating model vector for digit 6 using 5 sequences
# Huangrui is creating model vector for digit 7 using 5 sequences
# Huangrui is creating model vector for digit 8 using 5 sequences
# Huangrui is creating model vector for digit 9 using 5 sequences

# %%
foldername="../new_data"
test_start_instance=5
test_end_instance=10
all_digit_test=create_test_dataset(foldername,test_start_instance,test_end_instance)

# %%
def get_all_digit_GMMHMM(all_digit_templates):
    GMMHMMs=[]
    #IF I use [1,1,1,1,1] then it becomes Problem2
    Gaussian_distribution_number=[4,4,4]
    for digit in range(0,10):
        print("Huangrui is training the digit {} GMMHMM".format(digit))
        current_digit_templates=all_digit_templates[digit]
        current_digit_GMMHMM= GMMHMM(current_digit_templates,Gaussian_distribution_number)
        current_digit_GMMHMM.trainhmm()
        GMMHMMs.append(current_digit_GMMHMM)
    return GMMHMMs

# %%
def recognize_current_input(input_file,GMMHMMs):
    smallest_distance=[1000000,0]
    for digit in range(10):
        distance=GMMHMMs[digit].GMM_bi_HMM_dtw(input_file)
        if distance<smallest_distance[0]:
            smallest_distance[0]=distance
            smallest_distance[1]=digit
    recoginized_result=smallest_distance[1]
    return recoginized_result

# %%
def getGMM_HMM_accuracy(GMMHMMs,test_data):
    #K-means HMM recognition
    import numpy as np
    #main
    accuracy=0
    for j in range(len(test_data)):
        current_digit=j%10
        recoginized_result=recognize_current_input(test_data[j],GMMHMMs)
        if current_digit==recoginized_result:
            accuracy+=1
        print(current_digit,'recognized as:',recoginized_result)
    print('accuracy:',accuracy/len(test_data))

# %%
GMMHMMs=get_all_digit_GMMHMM(all_digit_templates)
# Out:
# Huangrui is training the digit 0 GMMHMM
# Initilizinng the state 1
# get 2 means
# Using EM
# 0.000814056052302845 0.00021014584216227927
# Use 10 iterations of EM to converge
# get 4 means
# Using EM
# 0.000520525257479025 2.3170320845616876e-05
# Use 20 iterations of EM to converge
# Initilizinng the state 2
# get 2 means
# Using EM
# 0.0009482282050622731 0.0005460633918319968
# Use 31 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008494711851572469 0.0002517706419868093
# Use 50 iterations of EM to converge
# Initilizinng the state 3
# get 2 means
# Using EM
# 0.0006716703539785677 7.838300059898051e-05
# Use 59 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008496165563917575 0.00037782670150782877
# Use 55 iterations of EM to converge
# The num of nodes in different states are [  0. 273. 291. 311.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007496982744276562 0.00019485875094554794
# Use 14 iterations of EM to converge
# get 4 means
# Using EM
# 0.00028668564253865895 1.4912966685862172e-05
# Use 19 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0007327438733921818 0.0005302194441749175
# Use 13 iterations of EM to converge
# get 4 means
# Using EM
# 0.000823330627212766 0.000213257983104842
# Use 17 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.00048666640745635736 9.637631963657634e-05
# Use 81 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007041530231819283 1.713846688398274e-05
# Use 19 iterations of EM to converge
# The num of nodes in different states are [  0. 311. 249. 315.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0008710344186120035 0.00020830459887738462
# Use 22 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009177382784610949 0.00021359660717951146
# Use 35 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0007638611913439227 0.00042909198776380775
# Use 13 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008953659951287033 0.00015752218041545363
# Use 31 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009759683012841013 0.00016522251204334482
# Use 45 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009112333016400487 0.00019658776166890657
# Use 43 iterations of EM to converge
# The num of nodes in different states are [  0. 337. 231. 307.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0003796026353722879 0.00011176128083700831
# Use 11 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008593779065650063 0.00011295054176210795
# Use 35 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0007224768968938275 0.0003296124652688026
# Use 23 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009876639573609416 5.2385401353466365e-05
# Use 85 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009301806239358854 0.00016663757721827044
# Use 66 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007961346033032214 7.102803788309325e-05
# Use 19 iterations of EM to converge
# The num of nodes in different states are [  0. 339. 225. 311.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.00026142519441808436 7.691185576147452e-05
# Use 11 iterations of EM to converge
# get 4 means
# Using EM
# 0.000928422148449848 0.00010719491560567951
# Use 35 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009535806804605117 0.00023428176076667473
# Use 18 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009306465066857726 0.00022849524706557156
# Use 108 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.00048666640745635736 9.637631963657634e-05
# Use 81 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007041530231819283 1.713846688398274e-05
# Use 19 iterations of EM to converge
# The num of nodes in different states are [  0. 339. 225. 311.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.00026142519441808436 7.691185576147452e-05
# Use 11 iterations of EM to converge
# get 4 means
# Using EM
# 0.000928422148449848 0.00010719491560567951
# Use 35 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009535806804605117 0.00023428176076667473
# Use 18 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009306465066857726 0.00022849524706557156
# Use 108 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.00048666640745635736 9.637631963657634e-05
# Use 81 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007041530231819283 1.713846688398274e-05
# Use 19 iterations of EM to converge
# The num of nodes in different states are [  0. 339. 225. 311.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.00026142519441808436 7.691185576147452e-05
# Use 11 iterations of EM to converge
# get 4 means
# Using EM
# 0.000928422148449848 0.00010719491560567951
# Use 35 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009535806804605117 0.00023428176076667473
# Use 18 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009306465066857726 0.00022849524706557156
# Use 108 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.00048666640745635736 9.637631963657634e-05
# Use 81 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007041530231819283 1.713846688398274e-05
# Use 19 iterations of EM to converge
# Use 6 iterators to updata HMM
# Huangrui is training the digit 1 GMMHMM
# Initilizinng the state 1
# get 2 means
# Using EM
# 0.0004925117026252359 0.00012373644660340632
# Use 10 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008134415460631124 0.00014030841252135606
# Use 32 iterations of EM to converge
# Initilizinng the state 2
# get 2 means
# Using EM
# 0.0006523251923728926 0.00018624467787980992
# Use 16 iterations of EM to converge
# get 4 means
# Using EM
# 0.0005589161781704137 8.319545588711397e-05
# Use 22 iterations of EM to converge
# Initilizinng the state 3
# get 2 means
# Using EM
# 0.00043859922909778487 2.0782981037761883e-05
# Use 21 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009806980931939646 0.0005195898159093687
# Use 23 iterations of EM to converge
# The num of nodes in different states are [  0. 343. 221. 381.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007209639069677431 0.00017082046807820328
# Use 13 iterations of EM to converge
# get 4 means
# Using EM
# 0.0005846396558148945 7.011074278059914e-05
# Use 21 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009671073378149845 0.00023696019933866497
# Use 19 iterations of EM to converge
# get 4 means
# Using EM
# 0.0002944557317371612 3.112914917505205e-05
# Use 13 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009590061198668464 8.149415920939707e-05
# Use 30 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008554727700919203 0.0002569523251903516
# Use 40 iterations of EM to converge
# The num of nodes in different states are [  0. 382. 181. 382.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007938745716734202 0.00017624977773322836
# Use 12 iterations of EM to converge
# get 4 means
# Using EM
# 0.000977980210304746 0.000244356113345251
# Use 55 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.00037030537853895325 9.143589052595935e-05
# Use 12 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007748549311578797 9.65882739484003e-05
# Use 67 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009841239433950773 7.666000995459887e-05
# Use 35 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008570099558069653 0.0002704701308397714
# Use 39 iterations of EM to converge
# The num of nodes in different states are [  0. 403. 163. 379.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0009389521900723509 0.00020090946080492111
# Use 10 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009617492274855759 0.0001199088280667282
# Use 44 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0004244590051252054 0.00010094009362038303
# Use 23 iterations of EM to converge
# get 4 means
# Using EM
# 0.0005254467926474757 0.0001478474988767936
# Use 50 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0008472481190026401 8.341411734516524e-05
# Use 28 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008223095481453059 0.0002704888706058922
# Use 36 iterations of EM to converge
# The num of nodes in different states are [  0. 439. 130. 376.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0008443358933811685 0.00018373906058355427
# Use 9 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009074571244307226 0.00023186568865010693
# Use 25 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009295330472505511 0.0004306581667123388
# Use 30 iterations of EM to converge
# get 4 means
# Using EM
# 0.000890765565181021 0.0002098056937923365
# Use 72 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009880034574738835 7.565379470596267e-05
# Use 35 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008811908875257419 0.00027290852361291223
# Use 45 iterations of EM to converge
# The num of nodes in different states are [  0. 446. 130. 369.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0006154498812994963 0.00017212588497111936
# Use 10 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008685318262896903 0.00023176399899726974
# Use 27 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0008235209169276531 0.0003649025518259186
# Use 26 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008586312123047414 0.00011405893043767157
# Use 35 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009546368422272345 8.815890784037717e-05
# Use 29 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008943486179222118 0.0002015776423581056
# Use 49 iterations of EM to converge
# The num of nodes in different states are [  0. 449. 121. 375.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0008105718753400684 0.00022748200551619968
# Use 11 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009640275005384025 0.00020487520812215165
# Use 33 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009494283614975118 0.0003068683955300133
# Use 27 iterations of EM to converge
# get 4 means
# Using EM
# 0.0004329864998558092 2.4154847174551186e-05
# Use 38 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.000988126928268071 9.20611439056418e-05
# Use 27 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008340208220999801 0.00022223083414744937
# Use 45 iterations of EM to converge
# The num of nodes in different states are [  0. 450. 125. 370.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0008037532758413883 0.00022898942374011133
# Use 11 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008373067385074065 0.0001192693141605361
# Use 41 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0008688583541786173 0.0003529150274294568
# Use 53 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008159135933456311 0.00012161030996035715
# Use 17 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0007196028776780238 6.750468231950246e-05
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008918418456152939 0.00019279292564696598
# Use 53 iterations of EM to converge
# The num of nodes in different states are [  0. 452. 124. 369.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007690972756760863 0.00023416573400730778
# Use 10 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009390550607814091 0.0002562261804858468
# Use 40 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0007816804072779497 0.0004068725021818542
# Use 32 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009548755795217973 0.00010334201217221395
# Use 26 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009546368422272345 8.815890784037717e-05
# Use 29 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008943486179222118 0.0002015776423581056
# Use 49 iterations of EM to converge
# The num of nodes in different states are [  0. 452. 124. 369.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007690972756760863 0.00023416573400730778
# Use 10 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009390550607814091 0.0002562261804858468
# Use 40 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0007816804072779497 0.0004068725021818542
# Use 32 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009548755795217973 0.00010334201217221395
# Use 26 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009546368422272345 8.815890784037717e-05
# Use 29 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008943486179222118 0.0002015776423581056
# Use 49 iterations of EM to converge
# The num of nodes in different states are [  0. 452. 124. 369.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007690972756760863 0.00023416573400730778
# Use 10 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009390550607814091 0.0002562261804858468
# Use 40 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0007816804072779497 0.0004068725021818542
# Use 32 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009548755795217973 0.00010334201217221395
# Use 26 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009546368422272345 8.815890784037717e-05
# Use 29 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008943486179222118 0.0002015776423581056
# Use 49 iterations of EM to converge
# Use 10 iterators to updata HMM
# Huangrui is training the digit 2 GMMHMM
# Initilizinng the state 1
# get 2 means
# Using EM
# 0.00045621629417145104 9.747279033245349e-05
# Use 16 iterations of EM to converge
# get 4 means
# Using EM
# 0.0004772820236413807 2.6275840445816323e-05
# Use 17 iterations of EM to converge
# Initilizinng the state 2
# get 2 means
# Using EM
# 0.0009263806088975345 0.0007099484116097066
# Use 13 iterations of EM to converge
# get 4 means
# Using EM
# 0.00099864229829979 0.00025809286197553405
# Use 56 iterations of EM to converge
# Initilizinng the state 3
# get 2 means
# Using EM
# 0.0009634604588470224 0.00017979663385217504
# Use 39 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009375777276526122 0.00019490644749228792
# Use 33 iterations of EM to converge
# The num of nodes in different states are [  0. 218. 326. 301.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0005573080072403819 0.00013999431133993046
# Use 16 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007543849439774705 5.437126839590023e-05
# Use 16 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009920172771144685 0.000281453107380758
# Use 12 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009964695298904356 0.00012040046982830788
# Use 43 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009278240061481177 0.00030620927620950145
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009717773584748162 0.00012502023507332538
# Use 30 iterations of EM to converge
# The num of nodes in different states are [  0. 200. 325. 320.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0008832532736891996 0.0001951013167080795
# Use 25 iterations of EM to converge
# get 4 means
# Using EM
# 0.0004157452014921187 2.712635135232455e-05
# Use 35 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0006867149144354626 0.0001199864889043778
# Use 19 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007397797437177987 0.0001023029963688471
# Use 112 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009956209873548565 0.0003564343499117828
# Use 47 iterations of EM to converge
# get 4 means
# Using EM
# 0.000584597131141376 0.00013654215371140116
# Use 25 iterations of EM to converge
# The num of nodes in different states are [  0. 186. 323. 336.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007309507422601169 0.00017130003584614473
# Use 8 iterations of EM to converge
# get 4 means
# Using EM
# 0.0003281018796395422 2.3991587286428806e-05
# Use 41 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0008782970595852203 0.0005409582941104385
# Use 79 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007016154271105813 0.00018950947782664374
# Use 25 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009453972168481928 0.0002918074505245949
# Use 37 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008966414602802327 7.910705735204165e-05
# Use 33 iterations of EM to converge
# The num of nodes in different states are [  0. 179. 322. 344.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0006713181213641567 0.0001371944636847089
# Use 9 iterations of EM to converge
# get 4 means
# Using EM
# 0.00031940094250731434 2.421353397874526e-05
# Use 41 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0008885609068779279 0.0006438473080759843
# Use 44 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009465788275425505 0.00023565730294586307
# Use 21 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.00030629673994029026 6.740125766663274e-05
# Use 28 iterations of EM to converge
# get 4 means
# Using EM
# 0.0006697151410092882 8.835617696702214e-05
# Use 30 iterations of EM to converge
# The num of nodes in different states are [  0. 179. 313. 353.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0006713181213641567 0.0001371944636847089
# Use 9 iterations of EM to converge
# get 4 means
# Using EM
# 0.00031940094250731434 2.421353397874526e-05
# Use 41 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009295878939180503 0.0006252793847374982
# Use 41 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008447880475724628 0.0002591314697125563
# Use 22 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009235850819566651 0.00016454930489240294
# Use 17 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009627895198824981 0.00017647487559214678
# Use 45 iterations of EM to converge
# The num of nodes in different states are [  0. 179. 313. 353.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0006713181213641567 0.0001371944636847089
# Use 9 iterations of EM to converge
# get 4 means
# Using EM
# 0.00031940094250731434 2.421353397874526e-05
# Use 41 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009295878939180503 0.0006252793847374982
# Use 41 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008447880475724628 0.0002591314697125563
# Use 22 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009235850819566651 0.00016454930489240294
# Use 17 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009627895198824981 0.00017647487559214678
# Use 45 iterations of EM to converge
# The num of nodes in different states are [  0. 179. 313. 353.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0006713181213641567 0.0001371944636847089
# Use 9 iterations of EM to converge
# get 4 means
# Using EM
# 0.00031940094250731434 2.421353397874526e-05
# Use 41 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0009295878939180503 0.0006252793847374982
# Use 41 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008447880475724628 0.0002591314697125563
# Use 22 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009235850819566651 0.00016454930489240294
# Use 17 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009627895198824981 0.00017647487559214678
# Use 45 iterations of EM to converge
# Use 7 iterators to updata HMM
# Huangrui is training the digit 3 GMMHMM
# Initilizinng the state 1
# get 2 means
# Using EM
# 0.0008982455494276303 0.00018278565767182453
# Use 9 iterations of EM to converge
# get 4 means
# Using EM
# 0.00060365397560211 5.8904317903507586e-05
# Use 38 iterations of EM to converge
# Initilizinng the state 2
# get 2 means
# Using EM
# 0.0007045603775840101 0.0002558785214571424
# Use 15 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009160132449077949 0.00025470420667300653
# Use 116 iterations of EM to converge
# Initilizinng the state 3
# get 2 means
# Using EM
# 0.0008771452862223674 0.00020499218277447717
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.000925734430288106 8.469198690171098e-05
# Use 43 iterations of EM to converge
# The num of nodes in different states are [  0. 298. 395. 292.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0006007354234586383 0.00011183540497855526
# Use 7 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007610514515211542 0.00011424363440493135
# Use 24 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0006884259309770456 0.0006677263865143002
# Use 12 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009232876241772887 0.0001201461363591616
# Use 49 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009511786843437553 0.0003343155867962522
# Use 12 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009338907425318448 0.00026496675138516085
# Use 36 iterations of EM to converge
# The num of nodes in different states are [  0. 293. 408. 284.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.00025024570720691246 4.770822371963357e-05
# Use 7 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009221646695613568 0.00011800151488350341
# Use 59 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.000956455821832345 0.0006870510958277842
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009373129886074154 0.00016049046831234648
# Use 46 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0008345733008840491 0.0002996158503215107
# Use 84 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009966095706449144 0.0002567446185970379
# Use 40 iterations of EM to converge
# The num of nodes in different states are [  0. 293. 408. 284.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.00025024570720691246 4.770822371963357e-05
# Use 7 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009221646695613568 0.00011800151488350341
# Use 59 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.000956455821832345 0.0006870510958277842
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009373129886074154 0.00016049046831234648
# Use 46 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0008345733008840491 0.0002996158503215107
# Use 84 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009966095706449144 0.0002567446185970379
# Use 40 iterations of EM to converge
# The num of nodes in different states are [  0. 293. 408. 284.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.00025024570720691246 4.770822371963357e-05
# Use 7 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009221646695613568 0.00011800151488350341
# Use 59 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.000956455821832345 0.0006870510958277842
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009373129886074154 0.00016049046831234648
# Use 46 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0008345733008840491 0.0002996158503215107
# Use 84 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009966095706449144 0.0002567446185970379
# Use 40 iterations of EM to converge
# Use 4 iterators to updata HMM
# Huangrui is training the digit 4 GMMHMM
# Initilizinng the state 1
# get 2 means
# Using EM
# 0.0005509718487288668 7.278382494702029e-06
# Use 5 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007565228626245792 5.509152314261967e-05
# Use 11 iterations of EM to converge
# Initilizinng the state 2
# get 2 means
# Using EM
# 0.0009517810519299079 0.000421631475327644
# Use 18 iterations of EM to converge
# get 4 means
# Using EM
# 0.0007946585615148611 0.0001516187624774068
# Use 35 iterations of EM to converge
# Initilizinng the state 3
# get 2 means
# Using EM
# 0.0003474219196428726 8.347600154656742e-05
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008591136092501592 7.304474515482107e-05
# Use 75 iterations of EM to converge
# The num of nodes in different states are [  0. 452. 198. 285.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007447702885973759 0.00016742118372520265
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009822518463948036 0.0001468419321726533
# Use 25 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0008661549161643197 0.000348089333886914
# Use 16 iterations of EM to converge
# get 4 means
# Using EM
# 0.0005814854567524341 0.00016722140377992134
# Use 16 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009277145747511215 0.00034739117987375723
# Use 17 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008218022570774666 9.233375018487255e-05
# Use 15 iterations of EM to converge
# The num of nodes in different states are [  0. 602.  63. 270.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0006834586861798133 0.00015439852361459616
# Use 13 iterations of EM to converge
# get 4 means
# Using EM
# 0.0005859269013176267 0.0001210862297870291
# Use 14 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0005150070820565401 0.00026337432640471947
# Use 14 iterations of EM to converge
# get 4 means
# Using EM
# 0.0002181817391207725 4.394110833658149e-05
# Use 14 iterations of EM to converge
# Update GMM of state 3
# get 2 means
# Using EM
# 0.0009626096861715967 0.0003836728368223352
# Use 24 iterations of EM to converge
# get 4 means
# Using EM
# 0.0009525397348651765 0.0003123044651405088
# Use 78 iterations of EM to converge
# The num of nodes in different states are [  0. 682.   5. 248.]
# Update GMM of state 1
# get 2 means
# Using EM
# 0.0007497481339831393 0.0001739918021030351
# Use 12 iterations of EM to converge
# get 4 means
# Using EM
# 0.0008997953128405514 0.00014052722748471302
# Use 14 iterations of EM to converge
# Update GMM of state 2
# get 2 means
# Using EM
# 0.0 0.0
# Use 1 iterations of EM to converge
# get 4 means
# Using EM
# <ipython-input-10-47916d5ee23a>:128: RuntimeWarning: Degrees of freedom <= 0 for slice
#   cov=np.cov(np.array(cluster).T)
# C:\Users\chuhr\anaconda3\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\chuhr\anaconda3\lib\site-packages\numpy\lib\function_base.py:2480: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-acd04f3471ae> in <module>
# ----> 1 GMMHMMs=get_all_digit_GMMHMM(all_digit_templates)
#
# <ipython-input-33-98bdc790fa04> in get_all_digit_GMMHMM(all_digit_templates)
#       7         current_digit_templates=all_digit_templates[digit]
#       8         current_digit_GMMHMM= GMMHMM(current_digit_templates,Gaussian_distribution_number)
# ----> 9         current_digit_GMMHMM.trainhmm()
#      10         GMMHMMs.append(current_digit_GMMHMM)
#      11     return GMMHMMs
#
# <ipython-input-10-47916d5ee23a> in trainhmm(self)
#     275                 #becasue huangrui consider the initial state fine
#     276                 #kmeans = KMeans(n_clusters = K,random_state=0).fit(np.array(current_state_nodes))
# --> 277                 curren_state_mix=self.GMMKmeans_WithEM(current_state_nodes,self.Gaussian_distribution_number[state])
#     278                 GMMS.append(curren_state_mix)
#     279             self.hmm.mix=GMMS
#
# <ipython-input-10-47916d5ee23a> in GMMKmeans_WithEM(self, nodes_for_Kmeans, num_Gaussian_distribution)
#     142             #use EM to update
#     143             print("Using EM")
# --> 144             mix=self.EM(nodes_for_Kmeans,mix)
#     145             means=mix.Gaussian_mean
#     146             covs=mix.Gaussian_var
#
# <ipython-input-10-47916d5ee23a> in EM(self, nodes, mix)
#     179             array_nodes=np.array(nodes)
#     180             #use np.dot to do the quick sum
# --> 181             part1=np.dot(array_P_l_X_i_s.T,array_nodes)
#     182             part2=np.sum(P_l_X_i_s,axis=0)
#     183             for l in range(num_guassian_distribution):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
getGMM_HMM_accuracy(GMMHMMs,all_digit_test)
